# %%
"""
check_nmr_stats.py
Простой скрипт для просмотра статистики NMR-ансамблей
"""

import torch
from collections import defaultdict
from pathlib import Path

# ====================== КОНФИГУРАЦИЯ ======================
REGISTRY_PATH = "/home/domain/data/aristowi/mlp_dataset_laproteina/latents/registry_with_full_coords.pt"   # ← поменяй путь, если нужно

# ====================== ОСНОВНОЙ КОД ======================
def print_nmr_statistics():
    print("Загружаем registry.pt...")
    registry = torch.load(REGISTRY_PATH, map_location="cpu")
    
    # Фильтруем только NMR записи
    nmr_entries = {k: v for k, v in registry.items() if v.get("experiment_type") == "NMR"}
    
    # Группируем по базовому PDB ID (убираем _model_XXX)
    by_base = defaultdict(list)
    for full_id in nmr_entries.keys():
        base = full_id.split('_model')[0]
        by_base[base].append(full_id)
    
    total_original_files = len(by_base)                    # сколько оригинальных NMR .pdb файлов было
    total_models = len(nmr_entries)                        # сколько всего моделей после разбиения
    
    print("\n" + "="*70)
    print("NMR АНСАМБЛИ — СТАТИСТИКА")
    print("="*70)
    print(f"Оригинальных NMR PDB файлов скачано:          {total_original_files:6d}")
    print(f"Моделей после разбиения на отдельные файлы:    {total_models:6d}")
    print(f"Среднее кол-во моделей на один ансамбль:       {total_models / total_original_files:.2f}")
    print(f"Максимальное кол-во моделей в одном ансамбле:  {max((len(m) for m in by_base.values()), default=0)}")
    print(f"Минимальное кол-во моделей в одном ансамбле:   {min((len(m) for m in by_base.values()), default=0)}")
    print(f"Ансамблей с ≥2 моделями (полезны для пар):     {sum(1 for m in by_base.values() if len(m) >= 2)}")
    print("="*70)
    
    # Топ-10 самых больших ансамблей
    print("\nТоп-10 NMR ансамблей с наибольшим количеством моделей:")
    top10 = sorted(by_base.items(), key=lambda x: len(x[1]), reverse=True)[:10]
    for base, models_list in top10:
        print(f"  {base:8s}  →  {len(models_list):3d} моделей")
    
    # Распределение по количеству моделей
    from collections import Counter
    model_counts = Counter(len(models) for models in by_base.values())
    print("\nРаспределение ансамблей по количеству моделей:")
    for num_models in sorted(model_counts.keys()):
        print(f"  {num_models:2d} моделей  →  {model_counts[num_models]:4d} ансамблей")

if __name__ == "__main__":
    print_nmr_statistics()
# Out:
# Загружаем registry.pt...
#
# ======================================================================
# NMR АНСАМБЛИ — СТАТИСТИКА
# ======================================================================
# Оригинальных NMR PDB файлов скачано:            6809
# Моделей после разбиения на отдельные файлы:    134882
# Среднее кол-во моделей на один ансамбль:       19.81
# Максимальное кол-во моделей в одном ансамбле:  640
# Минимальное кол-во моделей в одном ансамбле:   2
# Ансамблей с ≥2 моделями (полезны для пар):     6809
# ======================================================================
#
# Топ-10 NMR ансамблей с наибольшим количеством моделей:
#   2KOX      →  640 моделей
#   2LJ5      →  301 моделей
#   6V5D      →  176 моделей
#   2K0E      →  160 моделей
#   2NR2      →  144 моделей
#   1XQQ      →  128 моделей
#   2K39      →  116 моделей
#   2JU4      →  100 моделей
#   2M8N      →  100 моделей
#   2M8P      →  100 моделей
#
# Распределение ансамблей по количеству моделей:
#    2 моделей  →     8 ансамблей
#    3 моделей  →     7 ансамблей
#    4 моделей  →    20 ансамблей
#    5 моделей  →    26 ансамблей
#    6 моделей  →     7 ансамблей
#    7 моделей  →    10 ансамблей
#    8 моделей  →    13 ансамблей
#    9 моделей  →    13 ансамблей
#   10 моделей  →   751 ансамблей
#   11 моделей  →    24 ансамблей
#   12 моделей  →    47 ансамблей
#   13 моделей  →     9 ансамблей
#   14 моделей  →    34 ансамблей
#   15 моделей  →   206 ансамблей
#   16 моделей  →    50 ансамблей
#   17 моделей  →    27 ансамблей
#   18 моделей  →    42 ансамблей
#   19 моделей  →    53 ансамблей
#   20 моделей  →  4640 ансамблей
#   21 моделей  →    89 ансамблей
#   22 моделей  →    30 ансамблей
#   23 моделей  →    19 ансамблей
#   24 моделей  →    39 ансамблей
#   25 моделей  →   143 ансамблей
#   26 моделей  →    23 ансамблей
#   27 моделей  →     5 ансамблей
#   28 моделей  →    12 ансамблей
#   29 моделей  →    17 ансамблей
#   30 моделей  →   206 ансамблей
#   31 моделей  →    23 ансамблей
#   32 моделей  →    21 ансамблей
#   33 моделей  →     9 ансамблей
#   34 моделей  →     7 ансамблей
#   35 моделей  →    26 ансамблей
#   36 моделей  →     7 ансамблей
#   37 моделей  →     2 ансамблей
#   38 моделей  →     6 ансамблей
#   39 моделей  →     6 ансамблей
#   40 моделей  →    53 ансамблей
#   41 моделей  →     2 ансамблей
#   42 моделей  →     5 ансамблей
#   43 моделей  →     4 ансамблей
#   44 моделей  →     4 ансамблей
#   45 моделей  →     3 ансамблей
#   46 моделей  →     2 ансамблей
#   47 моделей  →     5 ансамблей
#   48 моделей  →     2 ансамблей
#   49 моделей  →     4 ансамблей
#   50 моделей  →    22 ансамблей
#   51 моделей  →     1 ансамблей
#   52 моделей  →     1 ансамблей
#   55 моделей  →     3 ансамблей
#   56 моделей  →     1 ансамблей
#   58 моделей  →     1 ансамблей
#   60 моделей  →     3 ансамблей
#   65 моделей  →     1 ансамблей
#   68 моделей  →     1 ансамблей
#   70 моделей  →     1 ансамблей
#   78 моделей  →     1 ансамблей
#   100 моделей  →     5 ансамблей
#   116 моделей  →     1 ансамблей
#   128 моделей  →     1 ансамблей
#   144 моделей  →     1 ансамблей
#   160 моделей  →     1 ансамблей
#   176 моделей  →     1 ансамблей
#   301 моделей  →     1 ансамблей
#   640 моделей  →     1 ансамблей

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# ⚙️ Настройки
DATASET_PATH = "train_pairs_clean.pt"
RMSD_KEY     = "rmsd"

# 📦 Загрузка
data = torch.load(DATASET_PATH, map_location="cpu")
if RMSD_KEY in data:
    rmsd = data[RMSD_KEY]
elif "pairs" in data:
    rmsd = [p.get(RMSD_KEY, p.get("rmsd")) for p in data["pairs"]]
    rmsd = [r for r in rmsd if r is not None]
else:
    rmsd = data

if isinstance(rmsd, torch.Tensor): rmsd = rmsd.numpy()
rmsd = np.array(rmsd, dtype=float)
rmsd = rmsd[np.isfinite(rmsd) & (rmsd >= 0)]
print(f"✅ Загружено {len(rmsd)} значений. Mean: {rmsd.mean():.3f}, Median: {np.median(rmsd):.3f}")

# 🎨 Рисуем (чистый matplotlib + numpy)
fig, ax = plt.subplots(figsize=(9, 5))
ax.set_facecolor("#F8F9FA")

# 1. Гистограмма
counts, bins, _ = ax.hist(rmsd, bins=60, density=True, alpha=0.6, 
                          color="#2E86AB", edgecolor="white", label="Гистограмма")

# 2. Ручное сглаживание (замена KDE без scipy)
bin_centers = (bins[:-1] + bins[1:]) / 2
sigma = (bins[1] - bins[0]) * 3  # ширина окна сглаживания
smooth_density = np.zeros_like(bin_centers)
for i, x in enumerate(bin_centers):
    weights = np.exp(-0.5 * ((bin_centers - x) / sigma) ** 2)
    weights /= weights.sum()
    smooth_density[i] = np.sum(counts * weights)

ax.plot(bin_centers, smooth_density, color="#A23B72", linewidth=2.5, label="Сглаженная плотность")

# 3. Статистика
med, mean = np.median(rmsd), np.mean(rmsd)
ax.axvline(med, color="#F18F01", ls="--", lw=1.5, label=f"Median = {med:.2f} Å")
ax.axvline(mean, color="#2E86AB", ls=":", lw=1.5, label=f"Mean = {mean:.2f} Å")

# 4. Процентили
p90, p95, p99 = np.percentile(rmsd, [90, 95, 99])
text = f"P90: {p90:.2f} Å\nP95: {p95:.2f} Å\nP99: {p99:.2f} Å"
props = dict(boxstyle='round', facecolor='white', alpha=0.85, edgecolor='#2E86AB')
ax.text(0.98, 0.98, text, transform=ax.transAxes, va='top', ha='right', bbox=props, fontsize=9)

# Оформление
ax.set_xlabel("RMSD (Å)", fontsize=11)
ax.set_ylabel("Плотность", fontsize=11)
ax.set_title("Распределение RMSD (numpy-only)", fontsize=13, pad=12, fontweight="bold")
ax.legend(frameon=True, loc="upper right")
ax.grid(True, ls="--", alpha=0.3)
ax.set_ylim(bottom=0)

plt.tight_layout()
plt.savefig("rmsd_distribution_numpy_only.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# ✅ Загружено 7413 значений. Mean: 5.423, Median: 4.554

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np

# Загрузка
train_pairs = torch.load("train_pairs_clean.pt", map_location="cpu")
registry = torch.load("/home/domain/data/aristowi/mlp_dataset_laproteina/latents/registry_with_full_coords.pt", map_location="cpu")

# Проверка структуры первого элемента registry
print("Структура registry:")
first_key = list(registry.keys())[0]
print(f"Ключ: {first_key}")
print(f"Тип значения: {type(registry[first_key])}")

if isinstance(registry[first_key], dict):
    print(f"Ключи в записи: {registry[first_key].keys()}")

# Извлечение длин (адаптируйте под вашу структуру)
protein_lengths = []
unique_proteins = set()

for pair in train_pairs["pairs"]:
    for protein_id in [pair["a"], pair["b"]]:
        if protein_id not in unique_proteins:
            unique_proteins.add(protein_id)
            
            if protein_id in registry:
                # Варианты извлечения длины:
                entry = registry[protein_id]
                
                # Вариант 1: по координатам
                if isinstance(entry, dict) and "coords" in entry:
                    length = entry["coords"].shape[0]
                
                # Вариант 2: по последовательности
                elif isinstance(entry, dict) and "sequence" in entry:
                    length = len(entry["sequence"])
                
                # Вариант 3: если entry - это тензор координат
                elif isinstance(entry, torch.Tensor):
                    length = entry.shape[0]
                
                else:
                    print(f"Неизвестная структура для {protein_id}")
                    continue
                
                protein_lengths.append(length)

print(f"Уникальных белков: {len(unique_proteins)}")
print(f"Белков с найденной длиной: {len(protein_lengths)}")

# 🔹 ВЫЧИСЛЕНИЕ МОДЫ (наиболее частое значение)
protein_lengths_array = np.array(protein_lengths)
# Для целочисленных данных используем bincount
counts = np.bincount(protein_lengths_array.astype(int))
mode_value = np.argmax(counts)
mode_count = counts[mode_value]
print(f"📊 Мода (наиболее частая длина): {mode_value} остатков (встречается {mode_count} раз)")

# Построение графика
plt.figure(figsize=(10, 6))
plt.hist(protein_lengths, bins=50, color="lightgreen", edgecolor='black', alpha=0.7)

# Линия среднего (красный пунктир)
mean_val = np.mean(protein_lengths)
plt.axvline(mean_val, color='red', linestyle='--', linewidth=2, label=f'Mean: {mean_val:.1f}')

# 🔹 ЛИНИЯ МОДЫ (синий штрихпунктир)
plt.axvline(mode_value, color='blue', linestyle='-.', linewidth=2, label=f'Mode: {mode_value}')

plt.xlabel('Protein length (number of residues)', fontsize=11)
plt.ylabel('Number of proteins', fontsize=11)
plt.title("Distribution of proteins' length in dataset", fontsize=13, fontweight='bold', pad=15)
plt.legend(fontsize=10, frameon=True, shadow=False)
plt.grid(axis='y', alpha=0.3, linestyle=':', linewidth=0.5)
plt.tight_layout()

# 🔹 СОХРАНЕНИЕ КАРТИНКИ
plt.savefig("protein_length_distribution.png", dpi=300, bbox_inches='tight', facecolor='white')
print("✅ График сохранён: protein_length_distribution.png")

plt.show()
# Out:
# Структура registry:
# Ключ: 107l
# Тип значения: <class 'dict'>
# Ключи в записи: dict_keys(['z', 'coords', 'n', 'pdb_id', 'sequence', 'experiment_type'])
# Уникальных белков: 5306
# Белков с найденной длиной: 5306
# 📊 Мода (наиболее частая длина): 64 остатков (встречается 123 раз)
# ✅ График сохранён: protein_length_distribution.png

# %%
#!/usr/bin/env python3
"""
Анализ распределения аминокислот в датасете MLP.
"""
import torch
from collections import Counter
import matplotlib.pyplot as plt

# Настройка стиля для красивого графика
plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['font.size'] = 10
plt.rcParams['axes.labelsize'] = 11
plt.rcParams['axes.titlesize'] = 13
plt.rcParams['xtick.labelsize'] = 9
plt.rcParams['ytick.labelsize'] = 9

# Пути к файлам
REGISTRY_PATH = "/home/domain/data/aristowi/mlp_dataset_laproteina/latents/registry_with_full_coords.pt"
PAIRS_PATH = "/home/domain/aristowi/la-proteina-main/mlp_model_dataset/train_pairs_clean.pt"

# Маппинг индексов в однобуквенные коды (как у тебя в MLPDataset)
INT_TO_AA = {
    0:"A", 1:"R", 2:"N", 3:"D", 4:"C", 5:"Q", 6:"E", 7:"G", 8:"H", 9:"I",
    10:"L", 11:"K", 12:"M", 13:"F", 14:"P", 15:"S", 16:"T", 17:"W", 18:"Y", 19:"V"
}

def analyze_aa_distribution():
    print("🔍 Загрузка данных...")
    
    # Загружаем registry (может быть большим, используем mmap если нужно)
    registry = torch.load(REGISTRY_PATH, map_location="cpu")
    pairs_data = torch.load(PAIRS_PATH, map_location="cpu")
    pairs = pairs_data["pairs"]
    
    print(f"📦 Registry: {len(registry)} записей")
    print(f"📦 Пар в датасете: {len(pairs)}")
    
    # Счётчик аминокислот
    aa_counter = Counter()
    total_residues = 0
    
    print("🔄 Подсчёт аминокислот...")
    for idx, pair in enumerate(pairs):
        if idx % 1000 == 0 and idx > 0:
            print(f"   Обработано {idx}/{len(pairs)} пар...")
        
        # Получаем индексы белков из пары
        id_a, id_b = registry[pair["a"]], registry[pair["b"]]
        
        # Собираем последовательности (если есть)
        for entry in [id_a, id_b]:
            seq_str = entry.get("sequence", "")
            if isinstance(seq_str, str) and seq_str:
                for aa in seq_str.upper():
                    if aa in INT_TO_AA.values():  # только канонические 20 АК
                        aa_counter[aa] += 1
                        total_residues += 1
    
    # 📊 Статистика
    print(f"\n✅ Всего остатков: {total_residues:,}")
    print(f"✅ Уникальных АК: {len(aa_counter)}/20\n")
    
    # Сортируем по частоте
    sorted_aa = sorted(aa_counter.items(), key=lambda x: x[1], reverse=True)
    
    print("📈 Распределение аминокислот:")
    print(f"{'АК':<4} {'Количество':>12} {'Частота (%)':>14} {'Ожид.*':>10}")
    print("-" * 45)
    
    # Ожидаемая частота при равномерном распределении
    expected_freq = 100.0 / 20
    
    for aa, count in sorted_aa:
        freq = 100.0 * count / total_residues
        print(f"{aa:<4} {count:>12,} {freq:>13.2f}% {expected_freq:>9.2f}%")
    
    # 🎨 Визуализация (ОДИН ГРАФИК)
    fig, ax = plt.subplots(figsize=(12, 6))
    
    # Данные для графика
    aa_names = [aa for aa, _ in sorted_aa]
    aa_freqs = [100.0 * aa_counter[aa] / total_residues for aa in aa_names]
    
    # Красивая цветовая схема (градиент от синего к бирюзовому)
    colors = plt.cm.Blues_r([0.3 + 0.7 * i / len(aa_names) for i in range(len(aa_names))])
    
    # Построение столбчатой диаграммы
    bars = ax.bar(range(len(aa_names)), aa_freqs, 
                  color=colors, 
                  edgecolor='navy', 
                  linewidth=1.2,
                  alpha=0.9)
    
    # Подписи осей и заголовок
    ax.set_xlabel("Amino acid", fontsize=11, fontweight='medium')
    ax.set_ylabel("Frequency, %", fontsize=11, fontweight='medium')
    ax.set_title("Distribution of amino acids in dataset", 
                 fontsize=14, fontweight='bold', pad=20)
    
    # Настройка осей
    ax.set_xticks(range(len(aa_names)))
    ax.set_xticklabels(aa_names, rotation=45, ha='right', fontsize=10)
    ax.set_axisbelow(True)  # Сетка позади столбцов
    
    # Улучшенная сетка
    ax.grid(axis='y', linestyle='--', alpha=0.4, linewidth=0.8)
    ax.grid(axis='x', linestyle=':', alpha=0.2, linewidth=0.5)
    
    # Лёгкая тень для столбцов
    for bar in bars:
        bar.set_edgecolor('white')
        bar.set_linewidth(0.8)
    
    # Автоматическая подгонка макета
    plt.tight_layout()
    
    # Сохранение и отображение
    plt.savefig("aa_distribution.png", dpi=300, bbox_inches='tight', facecolor='white')
    print("\n📊 График сохранён в 'aa_distribution.png'")
    plt.show()
    
    # ⚠️ Предупреждение о дисбалансе
    max_freq = max(aa_freqs)
    min_freq = min(aa_freqs)
    imbalance_ratio = max_freq / (min_freq + 1e-6)
    
    if imbalance_ratio > 5:
        print(f"\n⚠️  ВНИМАНИЕ: Дисбаланс классов = {imbalance_ratio:.1f}×")
        print("   Рассмотрите добавление class_weights в cross_entropy!")
    else:
        print(f"\n✅ Дисбаланс классов умеренный: {imbalance_ratio:.1f}×")

if __name__ == "__main__":
    analyze_aa_distribution()
# Out:
# 🔍 Загрузка данных...
# 📦 Registry: 181812 записей
# 📦 Пар в датасете: 7413
# 🔄 Подсчёт аминокислот...
#    Обработано 1000/7413 пар...
#    Обработано 2000/7413 пар...
#    Обработано 3000/7413 пар...
#    Обработано 4000/7413 пар...
#    Обработано 5000/7413 пар...
#    Обработано 6000/7413 пар...
#    Обработано 7000/7413 пар...
#
# ✅ Всего остатков: 1,784,388
# ✅ Уникальных АК: 20/20
#
# 📈 Распределение аминокислот:
# АК     Количество    Частота (%)     Ожид.*
# ---------------------------------------------
# G         140,092          7.85%      5.00%
# L         137,394          7.70%      5.00%
# E         135,802          7.61%      5.00%
# A         128,966          7.23%      5.00%
# S         127,544          7.15%      5.00%
# K         122,982          6.89%      5.00%
# D         107,194          6.01%      5.00%
# V         105,022          5.89%      5.00%
# T          97,210          5.45%      5.00%
# R          92,238          5.17%      5.00%
# I          84,614          4.74%      5.00%
# P          82,796          4.64%      5.00%
# Q          76,816          4.30%      5.00%
# N          72,578          4.07%      5.00%
# F          63,060          3.53%      5.00%
# Y          53,130          2.98%      5.00%
# H          50,676          2.84%      5.00%
# C          44,030          2.47%      5.00%
# M          42,854          2.40%      5.00%
# W          19,390          1.09%      5.00%
#
# 📊 График сохранён в 'aa_distribution.png'
# ⚠️  ВНИМАНИЕ: Дисбаланс классов = 7.2×
#    Рассмотрите добавление class_weights в cross_entropy!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import warnings
warnings.filterwarnings("ignore")

# ─────────────────────────────────────────────────────────────────────────────
# НАСТРОЙКИ
# ─────────────────────────────────────────────────────────────────────────────
METRICS_CSV = "./csv_logs/mlp_mixer/version_55/metrics.csv"   # ← путь к файлу

plt.rcParams.update({
    "font.family":      "DejaVu Sans",
    "font.size":        11,
    "axes.titlesize":   12,
    "axes.labelsize":   11,
    "xtick.labelsize":  10,
    "ytick.labelsize":  10,
    "legend.fontsize":  10,
    "axes.spines.top":  False,
    "axes.spines.right":False,
    "axes.grid":        True,
    "grid.alpha":       0.35,
    "grid.linestyle":   "--",
    "figure.dpi":       110,
    "savefig.dpi":      200,
    "savefig.bbox":     "tight",
})

TRAIN_COLOR = "#2563EB"   # синий
VAL_COLOR   = "#DC2626"   # красный
TEST_COLOR  = "#16A34A"   # зелёный

# ─────────────────────────────────────────────────────────────────────────────
# ЗАГРУЗКА ДАННЫХ
# ─────────────────────────────────────────────────────────────────────────────
df = pd.read_csv(METRICS_CSV)

# Train: одна строка на эпоху — берём _epoch-колонки + редкие без суффикса
train_epoch_cols = [c for c in df.columns if c.startswith("train/") and c.endswith("_epoch")]
train_bare_cols  = [c for c in df.columns if c.startswith("train/")
                    and not c.endswith("_epoch") and not c.endswith("_step")]

all_train_cols = train_epoch_cols + train_bare_cols
train = (
    df[["epoch"] + all_train_cols]
    .dropna(subset=all_train_cols, how="all")
    .groupby("epoch").first()
    .reset_index()
)
train.columns = [c.replace("_epoch", "") if c.endswith("_epoch") else c
                 for c in train.columns]

# Val: одна строка на эпоху
val_cols = [c for c in df.columns if c.startswith("val/")]
val = (
    df[["epoch"] + val_cols]
    .dropna(subset=val_cols, how="all")
    .groupby("epoch").first()
    .reset_index()
)

# Test: одна строка
test_cols = [c for c in df.columns if c.startswith("test/")]
test_row = (
    df[test_cols]
    .dropna(how="all")
    .iloc[-1]
)

ep_t = train["epoch"]
ep_v = val["epoch"]

print(f"Train: {len(train)} эпох | Val: {len(val)} эпох | Test: 1 строка")
print(f"Диапазон эпох: {ep_v.min()} – {ep_v.max()}")


# ─────────────────────────────────────────────────────────────────────────────
# ВСПОМОГАТЕЛЬНЫЕ ФУНКЦИИ
# ─────────────────────────────────────────────────────────────────────────────
def plot_pair(ax, ep_t, t_series, ep_v, v_series,
              ylabel, title, ylim=None):
    """Рисует пару train/val кривых на одной оси."""
    mask_t = t_series.notna()
    mask_v = v_series.notna()

    if mask_t.any():
        ax.plot(ep_t[mask_t], t_series[mask_t],
                color=TRAIN_COLOR, lw=2, label="Train")
    if mask_v.any():
        ax.plot(ep_v[mask_v], v_series[mask_v],
                color=VAL_COLOR, lw=2, label="Validation", ls="--")

    ax.set_title(title, fontweight="bold", pad=6)
    ax.set_xlabel("Epoch")
    ax.set_ylabel(ylabel)
    if ylim:
        ax.set_ylim(*ylim)
    ax.legend(frameon=True)


def pvalue_str(p):
    """Форматирует p-value в читаемый вид."""
    p_str = f"p = {p}"
    return p_str


def scatter_with_stats(ax, x_vals, y_vals, epoch_vals, xlabel, ylabel, title, cmap):
    """
    Scatter plot с линией тренда, коэффициентом Пирсона и p-value.
    Возвращает объект scatter для colorbar.
    """
    sc = ax.scatter(
        x_vals, y_vals,
        c=epoch_vals, cmap=cmap,
        s=70, edgecolors="white", lw=0.5, zorder=3
    )

    # Линия тренда
    z = np.polyfit(x_vals, y_vals, 1)
    x_line = np.linspace(x_vals.min(), x_vals.max(), 200)
    ax.plot(x_line, np.poly1d(z)(x_line),
            color="black", lw=1.5, ls="--", alpha=0.6, zorder=4, label="Trend")

    # Pearson r и p-value
    r, p = stats.pearsonr(x_vals, y_vals)
    annotation = f"r = {r:.3f}\n{pvalue_str(p)}"
    ax.text(0.05, 0.95, annotation,
            transform=ax.transAxes,
            fontsize=10, fontweight="bold",
            verticalalignment="top",
            bbox=dict(boxstyle="round,pad=0.3", facecolor="white",
                      edgecolor="gray", alpha=0.85))

    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_title(title, fontweight="bold")
    ax.legend(frameon=True, loc="lower right", fontsize=9)
    return sc


# ═════════════════════════════════════════════════════════════════════════════
# FIGURE 1: Кривые обучения — 4 панели
# ═════════════════════════════════════════════════════════════════════════════
fig, axes = plt.subplots(2, 2, figsize=(14, 9))

plot_pair(axes[0, 0],
          ep_t, train["train/total_loss"],
          ep_v, val["val/total_loss"],
          ylabel="Loss", title="Total Loss")

plot_pair(axes[0, 1],
          ep_t, train["train/seq_top1_acc"],
          ep_v, val["val/seq_top1_acc"],
          ylabel="Accuracy", title="Sequence Top-1 Accuracy",
          ylim=(0.0, 1.05))

plot_pair(axes[1, 0],
          ep_t, train["train/loss_fafe"],
          ep_v, val["val/loss_fafe"],
          ylabel="Loss", title="FAFE Loss (Frame Aligned Frame Error)")

plot_pair(axes[1, 1],
          ep_t, train["train/geom_angle_deg"],
          ep_v, val["val/geom_angle_deg"],
          ylabel="Degrees (°)", title="Backbone Angular Error")

plt.tight_layout()
plt.savefig("Fig1_Training_Curves.png")
plt.show()


# ═════════════════════════════════════════════════════════════════════════════
# FIGURE 2: Калибровка уверенности
# ═════════════════════════════════════════════════════════════════════════════
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle("Confidence Calibration", fontsize=14, fontweight="bold")

# Панель A: Train/Val conf_acc_gap
ax = axes[0]
mask_t = train["train/conf_acc_gap"].notna()
mask_v = val["val/conf_acc_gap"].notna()
if mask_t.any():
    ax.plot(ep_t[mask_t], train["train/conf_acc_gap"][mask_t],
            color=TRAIN_COLOR, lw=2, label="Train")
if mask_v.any():
    ax.plot(ep_v[mask_v], val["val/conf_acc_gap"][mask_v],
            color=VAL_COLOR, lw=2, ls="--", label="Validation")
ax.axhline(0, color="black", lw=1, ls=":", alpha=0.7, label="Perfect calibration")
ax.set_title("Confidence–Accuracy Gap\n(0 = perfectly calibrated)", fontweight="bold")
ax.set_xlabel("Epoch")
ax.set_ylabel("Avg. Confidence − Top-1 Accuracy")
ax.legend(frameon=True)

# Панель B: Val confidence vs val accuracy
ax = axes[1]
mask_c = val["val/avg_confidence"].notna()
mask_a = val["val/seq_top1_acc"].notna()
if mask_c.any():
    ax.plot(ep_v[mask_c], val["val/avg_confidence"][mask_c],
            color="#7C3AED", lw=2, label="Avg. Confidence")
if mask_a.any():
    ax.plot(ep_v[mask_a], val["val/seq_top1_acc"][mask_a],
            color=VAL_COLOR, lw=2, ls="--", label="Top-1 Accuracy")
ax.set_title("Validation: Confidence vs Accuracy", fontweight="bold")
ax.set_xlabel("Epoch")
ax.set_ylabel("Value")
ax.set_ylim(0, 1.05)
ax.legend(frameon=True)

plt.tight_layout()
plt.savefig("Fig2_Calibration.png")
plt.show()


# ═════════════════════════════════════════════════════════════════════════════
# FIGURE 3: Scatter — точность vs качество структуры (по эпохам)
# ═════════════════════════════════════════════════════════════════════════════
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle("Sequence Quality vs Structure Quality  (each point = one epoch)",
             fontsize=14, fontweight="bold")

cmap = plt.cm.plasma

# 3A: Top-1 Acc vs Angular Error
mask = val["val/seq_top1_acc"].notna() & val["val/geom_angle_deg"].notna()
sc = scatter_with_stats(
    ax=axes[0],
    x_vals=val["val/seq_top1_acc"][mask].values,
    y_vals=val["val/geom_angle_deg"][mask].values,
    epoch_vals=ep_v[mask].values,
    xlabel="Top-1 Sequence Accuracy",
    ylabel="Backbone Angle Error (°)",
    title="Sequence Accuracy vs Backbone Angular Error",
    cmap=cmap,
)
plt.colorbar(sc, ax=axes[0], label="Epoch")

# 3B: Top-1 Acc vs BLOSUM62
mask = val["val/seq_top1_acc"].notna() & val["val/blosum62_score"].notna()
sc = scatter_with_stats(
    ax=axes[1],
    x_vals=val["val/seq_top1_acc"][mask].values,
    y_vals=val["val/blosum62_score"][mask].values,
    epoch_vals=ep_v[mask].values,
    xlabel="Top-1 Sequence Accuracy",
    ylabel="BLOSUM62 Score",
    title="Sequence Accuracy vs BLOSUM62 Score",
    cmap=cmap,
)
plt.colorbar(sc, ax=axes[1], label="Epoch")

plt.tight_layout()
plt.savefig("Fig3_Scatter.png")
plt.show()


# ═════════════════════════════════════════════════════════════════════════════
# FIGURE 4: Энтропия, уверенность и BLOSUM по эпохам
# ═════════════════════════════════════════════════════════════════════════════
fig, ax1 = plt.subplots(figsize=(10, 5))
fig.suptitle("Distribution Stabilization over Training", fontsize=14, fontweight="bold")

color_ent = "#DC2626"
mask = val["val/pred_entropy"].notna()
ax1.plot(ep_v[mask], val["val/pred_entropy"][mask],
         color=color_ent, lw=2.5, label="Prediction Entropy")
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Prediction Entropy", color=color_ent)
ax1.tick_params(axis="y", labelcolor=color_ent)
ax1.set_ylim(bottom=0)

ax2 = ax1.twinx()
ax2.spines["right"].set_visible(True)

mask_b = val["val/blosum62_score"].notna()
mask_c = val["val/avg_confidence"].notna()
mask_a = val["val/seq_top1_acc"].notna()

ax2.plot(ep_v[mask_b], val["val/blosum62_score"][mask_b],
         color="#7C3AED", lw=2, ls="--", label="BLOSUM62 Score")
ax2.plot(ep_v[mask_c], val["val/avg_confidence"][mask_c],
         color="#2563EB", lw=2, ls="-.", label="Avg. Confidence")
ax2.plot(ep_v[mask_a], val["val/seq_top1_acc"][mask_a],
         color="#16A34A", lw=2, ls=":", label="Top-1 Accuracy")
ax2.set_ylabel("Score / Accuracy", color="#7C3AED")
ax2.tick_params(axis="y", labelcolor="#7C3AED")
ax2.set_ylim(0, 1.1)

h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()
ax1.legend(h1 + h2, l1 + l2, loc="center right", frameon=True)

plt.tight_layout()
plt.savefig("Fig4_Entropy_BLOSUM.png")
plt.show()


# ═════════════════════════════════════════════════════════════════════════════
# FIGURE 5: Top-K точность по эпохам
# ═════════════════════════════════════════════════════════════════════════════
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle("Top-K Sequence Accuracy", fontsize=14, fontweight="bold")

topk_colors = {"Top-1": "#DC2626", "Top-3": "#2563EB"}
topk_val_cols = {
    "Top-1": "val/seq_top1_acc",
    "Top-3": "val/seq_top3_acc",
}
topk_train_cols = {
    "Top-1": "train/seq_top1_acc",
    "Top-3": "train/seq_top3_acc",
}

# Панель A: Validation
ax = axes[0]
for label, col in topk_val_cols.items():
    if col in val.columns:
        mask = val[col].notna()
        ax.plot(ep_v[mask], val[col][mask],
                color=topk_colors[label], lw=2, label=label)
ax.set_title("Validation", fontweight="bold")
ax.set_xlabel("Epoch")
ax.set_ylabel("Accuracy")
ax.set_ylim(0.0, 1.05)
ax.legend(frameon=True)

# Панель B: Train vs Val
ax = axes[1]
for label in ["Top-1", "Top-3"]:
    col = topk_train_cols[label]
    if col in train.columns:
        mask = train[col].notna()
        ax.plot(ep_t[mask], train[col][mask],
                color=topk_colors[label], lw=2, label=f"Train {label}")
for label in ["Top-1", "Top-3"]:
    col = topk_val_cols[label]
    if col in val.columns:
        mask = val[col].notna()
        ax.plot(ep_v[mask], val[col][mask],
                color=topk_colors[label], lw=2, ls="--", label=f"Val {label}")
ax.set_title("Train vs Validation (Top-1 & Top-3)", fontweight="bold")
ax.set_xlabel("Epoch")
ax.set_ylabel("Accuracy")
ax.set_ylim(0.0, 1.05)
ax.legend(frameon=True, ncol=2)

plt.tight_layout()
plt.savefig("Fig5_TopK.png")
plt.show()


# ═════════════════════════════════════════════════════════════════════════════
# FIGURE 6: Итоговые метрики на тестовой выборке (bar chart)
# ═════════════════════════════════════════════════════════════════════════════
metrics_higher = {
    "Top-1 Accuracy":  test_row.get("test/seq_top1_acc",   np.nan),
    "Top-3 Accuracy":  test_row.get("test/seq_top3_acc",   np.nan),
    "BLOSUM62 Score":  test_row.get("test/blosum62_score",  np.nan),
    "Avg. Confidence": test_row.get("test/avg_confidence",  np.nan),
}
metrics_lower = {
    "FAFE Loss":          test_row.get("test/loss_fafe",       np.nan),
    "Sequence Loss":      test_row.get("test/loss_seq",        np.nan),
    "Prediction Entropy": test_row.get("test/pred_entropy",    np.nan),
    "Angle Error (°)":    test_row.get("test/geom_angle_deg",  np.nan),
    "Conf.–Acc. Gap": abs(test_row.get("test/conf_acc_gap", np.nan)),
}

fig, axes = plt.subplots(1, 2, figsize=(15, 5))
fig.suptitle("Final Test Metrics", fontsize=14, fontweight="bold")

def _bar_panel(ax, metrics_dict, title, color):
    keys = [k for k, v in metrics_dict.items() if pd.notna(v)]
    vals = [metrics_dict[k] for k in keys]
    bars = ax.bar(keys, vals, color=color, edgecolor="black", lw=0.7, width=0.55)
    for bar, val in zip(bars, vals):
        ax.text(bar.get_x() + bar.get_width() / 2,
                bar.get_height() + max(vals) * 0.02,
                f"{val:.4f}",
                ha="center", va="bottom", fontsize=9.5, fontweight="bold")
    ax.set_title(title, fontweight="bold")
    ax.set_ylabel("Value")
    ax.set_ylim(0, max(vals) * 1.18)
    ax.tick_params(axis="x", rotation=30)

_bar_panel(axes[0], metrics_higher, "↑ Higher is Better", "#2563EB")
_bar_panel(axes[1], metrics_lower,  "↓ Lower is Better",  "#DC2626")

plt.tight_layout()
plt.savefig("Fig6_Test_Metrics.png")
plt.show()

print("\n✅ Все 6 графиков построены и сохранены.")
# Out:
# Train: 40 эпох | Val: 40 эпох | Test: 1 строка
# Диапазон эпох: 0 – 39
# ✅ Все 6 графиков построены и сохранены.

# %%
CONFIG = {
    "exp_mlp_on": "../inference/inference_ucond_tri_result_mlpon_0909",      # Папка с режимом α=0.9, MLP ✅
    "exp_mlp_off_09": "../inference/inference_ucond_tri",   # Папка с режимом α=0.9, MLP ❌
    "exp_avg_05": "../inference/inference_ucond_tri_result_mlpoff_0505",           # Папка с режимом α=0.5, MLP ❌
    "output_dir": "./analysis_output",          # Куда сохранять отчёты и графики
    "pdb_ext": "*.pdb"       
}               # Расширение файлов структур

# %%
# %matplotlib inline
import os, warnings, re
from pathlib import Path
from typing import Dict, Optional
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats as scipy_stats

warnings.filterwarnings("ignore")

# ==========================================================
# ⚙️ КОНФИГУРАЦИЯ (ИЗМЕНИТЕ ПУТИ)
# ==========================================================
CONFIG = {
    "exp_mlp_on": "../inference/inference_ucond_tri_result_mlpon_0909",      # Папка с режимом α=0.9, MLP ✅
    "exp_mlp_off_09": "../inference/inference_ucond_tri",   # Папка с режимом α=0.9, MLP ❌
    "exp_avg_05": "../inference/inference_ucond_tri_result_mlpoff_0505",           # Папка с режимом α=0.5, MLP ❌
    "output_dir": "./analysis_output",          # Куда сохранять отчёты и графики
    "pdb_ext": "*.pdb"       
}
os.makedirs(CONFIG["output_dir"], exist_ok=True)

# ==========================================================
# 🔧 НАДЁЖНЫЕ УТИЛИТЫ (Прямое чтение ATOM, без Bio.PDB)
# ==========================================================
def read_sequence_from_pdb(pdb_path: str, verbose: bool = False) -> Optional[str]:
    """Читает последовательность напрямую из ATOM записей (CA). Работает на любых сгенерированных PDB."""
    seq = []
    t1 = {'ALA':'A','ARG':'R','ASN':'N','ASP':'D','CYS':'C','GLN':'Q','GLU':'E','GLY':'G',
          'HIS':'H','ILE':'I','LEU':'L','LYS':'K','MET':'M','PHE':'F','PRO':'P','SER':'S',
          'THR':'T','TRP':'W','TYR':'Y','VAL':'V'}
    try:
        with open(pdb_path, 'r') as f:
            for line in f:
                if line.startswith("ATOM") and len(line) > 20:
                    atom_name = line[12:16].strip()
                    res_name = line[17:20].strip()
                    if atom_name == "CA" and res_name in t1:
                        seq.append(t1[res_name])
        result = "".join(seq)
        if verbose: print(f"  📄 {os.path.basename(pdb_path)}: прочитано {len(result)} ост. | seq[:20]={result[:20]}")
        return result if result else None
    except Exception as e:
        if verbose: print(f"  ❌ Ошибка чтения {pdb_path}: {e}")
        return None

def read_ca_coords_from_pdb(pdb_path: str) -> Optional[np.ndarray]:
    """Читает координаты Cα напрямую из ATOM записей."""
    coords = []
    try:
        with open(pdb_path, 'r') as f:
            for line in f:
                if line.startswith("ATOM") and line[12:16].strip() == "CA":
                    try:
                        x = float(line[30:38])
                        y = float(line[38:46])
                        z = float(line[46:54])
                        coords.append([x, y, z])
                    except: pass
        return np.array(coords, dtype=np.float32) if coords else None
    except: return None

def compute_seq_identity(seq_a: str, seq_b: str) -> float:
    if not seq_a or not seq_b: return 0.0
    n = min(len(seq_a), len(seq_b))
    if n == 0: return 0.0
    # Жёсткое попарное сравнение
    matches = sum(1 for a, b in zip(seq_a[:n], seq_b[:n]) if a == b)
    return (matches / n) * 100.0

def compute_rmsd(coords_a: np.ndarray, coords_b: np.ndarray) -> float:
    if coords_a is None or coords_b is None or len(coords_a) != len(coords_b) or len(coords_a) == 0:
        return np.nan
    ca, cb = coords_a - coords_a.mean(axis=0), coords_b - coords_b.mean(axis=0)
    H = ca.T @ cb
    U, S, Vt = np.linalg.svd(H)
    R = Vt.T @ U.T
    if np.linalg.det(R) < 0: Vt[-1, :] *= -1; R = Vt.T @ U.T
    return np.sqrt(np.mean(np.sum((ca - cb @ R)**2, axis=1)))

def load_experiment_data(root_path: str, ext: str = "*.pdb", debug: bool = True) -> pd.DataFrame:
    records, root = [], Path(root_path)
    if not root.exists(): 
        print(f"⚠️ Папка не найдена: {root_path}")
        return pd.DataFrame()
    
    subdirs = sorted([d for d in root.iterdir() if d.is_dir()])
    print(f"\n📂 Сканирование: {root_path} ({len(subdirs)} папок)")
    
    processed, failed = 0, 0
    for idx, subdir in enumerate(subdirs):
        files = sorted(list(subdir.glob(ext)))
        if len(files) < 2:
            failed += 1
            continue
            
        # Жёсткий поиск файлов A и B
        f_a = next((f for f in files if re.search(r'[_\-]a', f.stem, re.I)), files[0])
        f_b = next((f for f in files if re.search(r'[_\-]b', f.stem, re.I)), files[1] if len(files)>1 else None)
        
        if not f_b: failed += 1; continue
        
        if debug and idx < 5:
            print(f"\n🔍 Парсинг пары {idx} ({subdir.name}):")
            
        s_a = read_sequence_from_pdb(str(f_a), verbose=debug and idx < 5)
        s_b = read_sequence_from_pdb(str(f_b), verbose=debug and idx < 5)
        c_a = read_ca_coords_from_pdb(str(f_a))
        c_b = read_ca_coords_from_pdb(str(f_b))
        
        if s_a and s_b and c_a is not None and c_b is not None:
            sid = compute_seq_identity(s_a, s_b)
            rmsd = compute_rmsd(c_a, c_b)
            records.append({
                'sample_id': subdir.name, 'seq_identity': sid,
                'rmsd_ca': rmsd, 'len_a': len(s_a), 'len_b': len(s_b)
            })
            processed += 1
            if debug and idx < 5:
                print(f"  ✅ SeqID={sid:.1f}% | RMSD={rmsd:.2f}Å")
                if sid == 100.0:
                    print(f"  ⚠️ ВНИМАНИЕ: 100% совпадение! Проверьте файлы: {f_a.name} vs {f_b.name}")
        else:
            failed += 1
            if debug and idx < 5: print(f"  ❌ Не удалось прочитать метрики (s_a={s_a is not None}, s_b={s_b is not None})")
            
    df = pd.DataFrame(records)
    print(f"📊 Итог: обработано {processed}, пропущено {failed}")
    return df

# ==========================================================
# 📊 СТАТИСТИКА, ОТЧЁТ И ГРАФИКИ
# ==========================================================
def run_statistics(dfs: Dict[str, pd.DataFrame]) -> Dict:
    res = {}
    group_names = list(dfs.keys())
    n_groups = len(group_names)
    for metric in ['seq_identity', 'rmsd_ca']:
        groups = [df[metric].dropna().values for df in dfs.values()]
        groups = [g for g in groups if len(g) > 0]
        p_overall = scipy_stats.kruskal(*groups).pvalue if len(groups) >= 2 else 1.0
        pairwise_results = []
        n_tests = n_groups * (n_groups - 1) // 2
        alpha_bonf = 0.05 / n_tests if n_tests > 0 else 0.05
        for i in range(n_groups):
            for j in range(i + 1, n_groups):
                g1 = dfs[group_names[i]][metric].dropna()
                g2 = dfs[group_names[j]][metric].dropna()
                if len(g1) > 0 and len(g2) > 0:
                    stat, p_raw = scipy_stats.mannwhitneyu(g1, g2, alternative='two-sided')
                    pairwise_results.append({
                        'Group1': group_names[i], 'Group2': group_names[j],
                        'MeanDiff': g1.mean() - g2.mean(),
                        'P-raw': p_raw, 'P-bonf': min(1.0, p_raw * n_tests), 'Reject': p_raw < alpha_bonf
                    })
        res[metric] = {'p_overall': p_overall, 'pairwise': pd.DataFrame(pairwise_results)}
    return res

def generate_report_and_plots(dfs: Dict[str, pd.DataFrame], stats_res: Dict, out_dir: str):
    """Форматирует p-value точно: 4 знака для обычных значений, научная нотация для очень малых."""
    
    def format_pvalue(p: float) -> str:
        """Точное форматирование p-value."""
        if p >= 0.0001:
            return f"{p:.4f}"
        elif p > 0:
            return f"{p:.2e}"  # Научная нотация: 1.23e-05
        else:
            return "0.0000"
    
    report_path = os.path.join(out_dir, "analysis_report.txt")
    with open(report_path, 'w', encoding='utf-8') as f:
        f.write("🔬 АНАЛИЗ ПАРНЫХ СТРУКТУР (A vs B)\n" + "="*50 + "\n")
        
        for metric, label in [('seq_identity', 'Sequence Identity (%)'), ('rmsd_ca', 'RMSD Cα (Å)')]:
            f.write(f"\n{label} (Kruskal-Wallis p={format_pvalue(stats_res[metric]['p_overall'])}):\n")
            for name, df in dfs.items():
                if metric in df.columns and len(df) > 0:
                    f.write(f"  • {name}: {df[metric].mean():.2f} ± {df[metric].std():.2f} (n={len(df)})\n")
                    
            f.write("  Попарные сравнения (Mann-Whitney U + Bonferroni α=0.0167):\n")
            pdf = stats_res[metric]['pairwise']
            if pdf.empty: 
                f.write("    Недостаточно данных.\n")
            else:
                for _, r in pdf.iterrows():
                    sig = "✅ ЗНАЧИМО" if r['Reject'] else "❌ НЕ ЗНАЧИМО"
                    # Форматируем оба p-value точно
                    p_raw = format_pvalue(r['P-raw'])
                    p_bonf = format_pvalue(r['P-bonf'])
                    f.write(f"    {r['Group1']} vs {r['Group2']}: Δ={r['MeanDiff']:+.3f}, p={p_raw} (bonf={p_bonf}) → {sig}\n")
    
    print(f"✅ Отчёт сохранён: {report_path}")

    # Графики (без изменений)
    fig, axes = plt.subplots(1, 2, figsize=(14, 6))
    colors = sns.color_palette("Set2", len(dfs))
    for i, (metric, title, ylabel) in enumerate([
        ('seq_identity', 'Sequence Identity (A vs B)', 'Identity %'),
        ('rmsd_ca', 'RMSD Cα (A vs B)', 'RMSD (Å)')
    ]):
        ax = axes[i]
        data, labels = [], []
        for name, df in dfs.items():
            if metric in df.columns:
                data.extend(df[metric].tolist())
                labels.extend([name] * len(df))
        if len(data) > 0:
            plot_df = pd.DataFrame({'val': data, 'mode': labels})
            sns.boxplot(x='mode', y='val', data=plot_df, ax=ax, palette=colors)
            sns.stripplot(x='mode', y='val', data=plot_df, ax=ax, color='black', alpha=0.3, size=4)
        ax.set_title(title); ax.set_ylabel(ylabel); ax.tick_params(axis='x', rotation=30)
    plt.tight_layout()
    plt.savefig(os.path.join(out_dir, "comparison_boxplots.png"), dpi=300)
    plt.show()
# ==========================================================
# 🚀 ЗАПУСК
# ==========================================================
print("📥 Загрузка и верификация данных...")
dfs = {
    "MLP ON (α=0.9)": load_experiment_data(CONFIG["exp_mlp_on"], CONFIG["pdb_ext"], debug=True),
    "MLP OFF (α=0.9)": load_experiment_data(CONFIG["exp_mlp_off_09"], CONFIG["pdb_ext"], debug=True),
    "AVG (α=0.5)": load_experiment_data(CONFIG["exp_avg_05"], CONFIG["pdb_ext"], debug=True),
}

print("\n📋 СВОДКА ПО РЕЖИМАМ:")
for name, df in dfs.items():
    if df.empty: print(f"⚠️ {name}: НЕТ ДАННЫХ!")
    else:
        print(f"✅ {name}: {len(df)} пар")
        print(f"   SeqID: min={df['seq_identity'].min():.1f}%, max={df['seq_identity'].max():.1f}%, mean={df['seq_identity'].mean():.1f}%")
        print(f"   RMSD:  min={df['rmsd_ca'].min():.2f} Å, max={df['rmsd_ca'].max():.2f} Å, mean={df['rmsd_ca'].mean():.2f} Å")

print("\n📊 Статистика и графики...")
stats_res = run_statistics(dfs)
generate_report_and_plots(dfs, stats_res, CONFIG["output_dir"])
print("\n🏁 Анализ завершён!")
# Out:
# 📥 Загрузка и верификация данных...
#
# 📂 Сканирование: ../inference/inference_ucond_tri_result_mlpon_0909 (100 папок)
#
# 🔍 Парсинг пары 0 (job_0_n_120_id_0):
#   📄 job_0_n_120_id_0_pathA.pdb: прочитано 120 ост. | seq[:20]=MKNEELINLLEELKPDAIIL
#   📄 job_0_n_120_id_0_pathB.pdb: прочитано 120 ост. | seq[:20]=MKNEELINLLEELKPDAIIL
#   ✅ SeqID=97.5% | RMSD=13.83Å
#
# 🔍 Парсинг пары 1 (job_0_n_120_id_1):
#   📄 job_0_n_120_id_1_pathA.pdb: прочитано 120 ост. | seq[:20]=MNEKEKKLLEDAINHLLKQE
#   📄 job_0_n_120_id_1_pathB.pdb: прочитано 120 ост. | seq[:20]=MNIKEKKLLEDAINHLLKQE
#   ✅ SeqID=95.8% | RMSD=14.25Å
#
# 🔍 Парсинг пары 2 (job_0_n_120_id_10):
#   📄 job_0_n_120_id_10_pathA.pdb: прочитано 120 ост. | seq[:20]=MREQQEEVIEYLLEKGYKVT
#   📄 job_0_n_120_id_10_pathB.pdb: прочитано 120 ост. | seq[:20]=MREQQEEVIEYLLEVGYKVT
#   ✅ SeqID=99.2% | RMSD=13.63Å
#
# 🔍 Парсинг пары 3 (job_0_n_120_id_11):
#   📄 job_0_n_120_id_11_pathA.pdb: прочитано 120 ост. | seq[:20]=MTKIRDLLDEIEDEEDREEL
#   📄 job_0_n_120_id_11_pathB.pdb: прочитано 120 ост. | seq[:20]=MTKIRDLLDEIEAEEDREEL
#   ✅ SeqID=98.3% | RMSD=12.64Å
#
# 🔍 Парсинг пары 4 (job_0_n_120_id_12):
#   📄 job_0_n_120_id_12_pathA.pdb: прочитано 120 ост. | seq[:20]=MNPNEKDEYGRTPLHIAAEN
#   📄 job_0_n_120_id_12_pathB.pdb: прочитано 120 ост. | seq[:20]=MNPNEKDEYGRTPLHIAAEN
#   ✅ SeqID=96.7% | RMSD=12.69Å
# 📊 Итог: обработано 100, пропущено 0
#
# 📂 Сканирование: ../inference/inference_ucond_tri (100 папок)
#
# 🔍 Парсинг пары 0 (job_0_n_120_id_0):
#   📄 job_0_n_120_id_0_pathA.pdb: прочитано 120 ост. | seq[:20]=MKTEELLNLLEELKPDAIIL
#   📄 job_0_n_120_id_0_pathB.pdb: прочитано 120 ост. | seq[:20]=MARLKIIETEDGRKIAVLHI
#   ✅ SeqID=9.2% | RMSD=13.79Å
#
# 🔍 Парсинг пары 1 (job_0_n_120_id_1):
#   📄 job_0_n_120_id_1_pathA.pdb: прочитано 120 ост. | seq[:20]=MNRKEKELLENAINHLLEQN
#   📄 job_0_n_120_id_1_pathB.pdb: прочитано 120 ост. | seq[:20]=MNKEQLEKVKEFFLEFKKKS
#   ✅ SeqID=14.2% | RMSD=13.86Å
#
# 🔍 Парсинг пары 2 (job_0_n_120_id_10):
#   📄 job_0_n_120_id_10_pathA.pdb: прочитано 120 ост. | seq[:20]=MREQQEEIIEYLLEKGYKVT
#   📄 job_0_n_120_id_10_pathB.pdb: прочитано 120 ост. | seq[:20]=MYEEIEKNYKKIELEELPEK
#   ✅ SeqID=10.0% | RMSD=13.65Å
#
# 🔍 Парсинг пары 3 (job_0_n_120_id_11):
#   📄 job_0_n_120_id_11_pathA.pdb: прочитано 120 ост. | seq[:20]=MTKIRDLLEEIEDEEDREEL
#   📄 job_0_n_120_id_11_pathB.pdb: прочитано 120 ост. | seq[:20]=MEEEITPEDVLEMLDEGESI
#   ✅ SeqID=14.2% | RMSD=12.68Å
#
# 🔍 Парсинг пары 4 (job_0_n_120_id_12):
#   📄 job_0_n_120_id_12_pathA.pdb: прочитано 120 ост. | seq[:20]=MNPNEKDEYGRTPLHIAAEN
#   📄 job_0_n_120_id_12_pathB.pdb: прочитано 120 ост. | seq[:20]=MELEQKLREKGIRAEVVNPR
#   ✅ SeqID=10.0% | RMSD=12.69Å
# 📊 Итог: обработано 100, пропущено 0
#
# 📂 Сканирование: ../inference/inference_ucond_tri_result_mlpoff_0505 (100 папок)
#
# 🔍 Парсинг пары 0 (job_0_n_120_id_0):
#   📄 job_0_n_120_id_0_pathA.pdb: прочитано 120 ост. | seq[:20]=MTEKLQQQLAREPEPEAVIL
#   📄 job_0_n_120_id_0_pathB.pdb: прочитано 120 ост. | seq[:20]=MILKLQVQLATEPGKCAVIL
#   ✅ SeqID=71.7% | RMSD=14.53Å
#
# 🔍 Парсинг пары 1 (job_0_n_120_id_1):
#   📄 job_0_n_120_id_1_pathA.pdb: прочитано 120 ост. | seq[:20]=MNEQEKEILQEALEALLEED
#   📄 job_0_n_120_id_1_pathB.pdb: прочитано 120 ост. | seq[:20]=MNEQEKEILQEAIEALLEED
#   ✅ SeqID=83.3% | RMSD=14.01Å
#
# 🔍 Парсинг пары 2 (job_0_n_120_id_10):
#   📄 job_0_n_120_id_10_pathA.pdb: прочитано 120 ост. | seq[:20]=MAEQTEKIVRKLIEKGELSI
#   📄 job_0_n_120_id_10_pathB.pdb: прочитано 120 ост. | seq[:20]=MLEQTEKIVRVLNEKGELSI
#   ✅ SeqID=76.7% | RMSD=13.80Å
#
# 🔍 Парсинг пары 3 (job_0_n_120_id_11):
#   📄 job_0_n_120_id_11_pathA.pdb: прочитано 120 ост. | seq[:20]=MHVIEDLLDELLMIQNQIKL
#   📄 job_0_n_120_id_11_pathB.pdb: прочитано 120 ост. | seq[:20]=MMVICDLLDLLLEIQEGIKE
#   ✅ SeqID=80.8% | RMSD=12.63Å
#
# 🔍 Парсинг пары 4 (job_0_n_120_id_12):
#   📄 job_0_n_120_id_12_pathA.pdb: прочитано 120 ост. | seq[:20]=MQVNLKNPTVGESEQVLEET
#   📄 job_0_n_120_id_12_pathB.pdb: прочитано 120 ост. | seq[:20]=MQVELPNPTVGENAEVIEEK
#   ✅ SeqID=75.0% | RMSD=13.17Å
# 📊 Итог: обработано 100, пропущено 0
#
# 📋 СВОДКА ПО РЕЖИМАМ:
# ✅ MLP ON (α=0.9): 100 пар
#    SeqID: min=92.5%, max=100.0%, mean=97.0%
#    RMSD:  min=5.14 Å, max=16.90 Å, mean=13.22 Å
# ✅ MLP OFF (α=0.9): 100 пар
#    SeqID: min=4.2%, max=25.0%, mean=12.9%
#    RMSD:  min=4.93 Å, max=16.95 Å, mean=13.19 Å
# ✅ AVG (α=0.5): 100 пар
#    SeqID: min=65.0%, max=87.5%, mean=76.1%
#    RMSD:  min=3.40 Å, max=16.92 Å, mean=13.19 Å
#
# 📊 Статистика и графики...
# ✅ Отчёт сохранён: ./analysis_output/analysis_report.txt
# 🏁 Анализ завершён!

# %%
import pymol2

pdb1 = "/home/domain/data/aristowi/mlp_dataset_laproteina/pdb/x-ray/107l.pdb"
pdb2 = "/home/domain/data/aristowi/mlp_dataset_laproteina/pdb/x-ray/1lwg.pdb"

with pymol2.PyMOL() as p:
    p.cmd.load(pdb1, "mob")
    p.cmd.load(pdb2, "tgt")
    rmsd_super = p.cmd.super("mob", "tgt")[0]
    rmsd_align = p.cmd.align("mob", "tgt")[0]
    print(f"PyMOL super RMSD: {rmsd_super:.3f} Å")
    print(f"PyMOL align RMSD: {rmsd_align:.3f} Å")
# Out:
# PyMOL super RMSD: 0.589 Å
# PyMOL align RMSD: 0.589 Å

# %%
import torch

REGISTRY_PATH = "/home/domain/data/aristowi/mlp_dataset_laproteina/latents/registry_with_full_coords.pt"
registry = torch.load(REGISTRY_PATH, map_location="cpu")

train_data = torch.load("./train_pairs_split.pt", map_location="cpu")
val_data = torch.load("./val_pairs_split.pt", map_location="cpu")

train_pairs = train_data["pairs"]
val_pairs = val_data["pairs"]

# p["a"] и p["b"] — это ключи в registry
print("Train lengths:", [registry[p["a"]]["coords"].shape[0] for p in train_pairs[:5]])
print("Val lengths:",   [registry[p["a"]]["coords"].shape[0] for p in val_pairs[:5]])

# Бонус: проверь статистику длин по всему сплиту
train_lens = [registry[p["a"]]["coords"].shape[0] for p in train_pairs]
val_lens = [registry[p["a"]]["coords"].shape[0] for p in val_pairs]
print(f"Train stats: min={min(train_lens)}, max={max(train_lens)}, mean={sum(train_lens)/len(train_lens):.1f}")
print(f"Val stats:   min={min(val_lens)}, max={max(val_lens)}, mean={sum(val_lens)/len(val_lens):.1f}")
# Out:
# Train lengths: [370, 74, 92, 108, 133]
# Val lengths: [252, 93, 148, 148, 135]
# Train stats: min=60, max=370, mean=120.1
# Val stats:   min=60, max=370, mean=122.5

# %%
registry["1xw3"]["z"].shape
# Out:
# torch.Size([110, 8])

# %%
for key in registry["2DLK_model_016"].keys():
    print(key)
# Out:
# z
# coords
# n
# pdb_id
# sequence
# experiment_type
# coords_37
# atom_mask_37

# %%
import torch

data = torch.load("./train_pairs.pt", map_location="cpu")
registry = torch.load("/home/domain/data/aristowi/mlp_dataset_laproteina/latents/registry_with_full_coords.pt", map_location="cpu")

pairs = data["pairs"]
# Первые 3 пары из multistate (они идут после nmr)
# for a, b in pairs[0 : n_nmr + 3]:
#     print(f"{a} — {b}")
#     print(f"  seq_a: {registry[a]['sequence'], registry[a]['experiment_type']}")
#     print(f"  seq_b: {registry[b]['sequence'], registry[b]['experiment_type']}")
pairs
# Out:
# [{'a': '8J9A_model_005', 'b': '8J9A_model_001', 'type': 'NMR', 'rmsd': 8.414},
#  {'a': '1T3K_model_007', 'b': '1T3K_model_005', 'type': 'NMR', 'rmsd': 2.028},
#  {'a': '8I25_model_013', 'b': '8I25_model_003', 'type': 'NMR', 'rmsd': 6.993},
#  {'a': '2ADZ_model_005', 'b': '2ADZ_model_017', 'type': 'NMR', 'rmsd': 4.729},
#  {'a': '5TP5_model_003', 'b': '5TP5_model_001', 'type': 'NMR', 'rmsd': 9.783},
#  {'a': '2KQ8_model_006', 'b': '2KQ8_model_009', 'type': 'NMR', 'rmsd': 2.319},
#  {'a': '2LAF_model_007', 'b': '2LAF_model_006', 'type': 'NMR', 'rmsd': 2.187},
#  {'a': '1TXB_model_006', 'b': '1TXB_model_004', 'type': 'NMR', 'rmsd': 3.26},
#  {'a': '1G90_model_006', 'b': '1G90_model_000', 'type': 'NMR', 'rmsd': 2.386},
#  {'a': '8P7G_model_005', 'b': '8P7G_model_014', 'type': 'NMR', 'rmsd': 2.291},
#  {'a': '1BOD_model_014', 'b': '1BOD_model_009', 'type': 'NMR', 'rmsd': 2.046},
#  {'a': '2L7P_model_008', 'b': '2L7P_model_002', 'type': 'NMR', 'rmsd': 8.675},
#  {'a': '2JQY_model_004', 'b': '2JQY_model_000', 'type': 'NMR', 'rmsd': 2.457},
#  {'a': '6U1O_model_008', 'b': '6U1O_model_001', 'type': 'NMR', 'rmsd': 4.475},
#  {'a': '2KJY_model_017', 'b': '2KJY_model_004', 'type': 'NMR', 'rmsd': 4.322},
#  {'a': '2MAF_model_000', 'b': '2MAF_model_006', 'type': 'NMR', 'rmsd': 5.263},
#  {'a': '1TIV_model_006', 'b': '1TIV_model_003', 'type': 'NMR', 'rmsd': 6.82},
#  {'a': '2DHY_model_009', 'b': '2DHY_model_003', 'type': 'NMR', 'rmsd': 2.693},
#  {'a': '2RV6_model_010', 'b': '2RV6_model_011', 'type': 'NMR', 'rmsd': 4.636},
#  {'a': '6BQI_model_009', 'b': '6BQI_model_001', 'type': 'NMR', 'rmsd': 10.01},
#  {'a': '8JR6_model_001', 'b': '8JR6_model_000', 'type': 'NMR', 'rmsd': 2.027},
#  {'a': '2KUI_model_009', 'b': '2KUI_model_021', 'type': 'NMR', 'rmsd': 8.336},
#  {'a': '8SKX_model_014', 'b': '8SKX_model_013', 'type': 'NMR', 'rmsd': 2.03},
#  {'a': '6QAM_model_007', 'b': '6QAM_model_001', 'type': 'NMR', 'rmsd': 3.282},
#  {'a': '2M2B_model_010', 'b': '2M2B_model_006', 'type': 'NMR', 'rmsd': 2.252},
#  {'a': '1CO1_model_004', 'b': '1CO1_model_006', 'type': 'NMR', 'rmsd': 2.594},
#  {'a': '3GF1_model_004', 'b': '3GF1_model_003', 'type': 'NMR', 'rmsd': 3.486},
#  {'a': '1HD4_model_022', 'b': '1HD4_model_014', 'type': 'NMR', 'rmsd': 4.59},
#  {'a': '1KN7_model_005', 'b': '1KN7_model_015', 'type': 'NMR', 'rmsd': 11.652},
#  {'a': '2N7L_model_007', 'b': '2N7L_model_010', 'type': 'NMR', 'rmsd': 2.493},
#  {'a': '2LM7_model_005', 'b': '2LM7_model_006', 'type': 'NMR', 'rmsd': 7.425},
#  {'a': '1JFJ_model_003', 'b': '1JFJ_model_018', 'type': 'NMR', 'rmsd': 11.388},
#  {'a': '2LMT_model_001', 'b': '2LMT_model_012', 'type': 'NMR', 'rmsd': 8.569},
#  {'a': '2LCP_model_013', 'b': '2LCP_model_016', 'type': 'NMR', 'rmsd': 2.181},
#  {'a': '2D7L_model_014', 'b': '2D7L_model_008', 'type': 'NMR', 'rmsd': 2.308},
#  {'a': '2CRU_model_017', 'b': '2CRU_model_015', 'type': 'NMR', 'rmsd': 5.998},
#  {'a': '6ACV_model_007', 'b': '6ACV_model_018', 'type': 'NMR', 'rmsd': 4.381},
#  {'a': '1WYS_model_004', 'b': '1WYS_model_000', 'type': 'NMR', 'rmsd': 4.609},
#  {'a': '9X71_model_006', 'b': '9X71_model_005', 'type': 'NMR', 'rmsd': 2.338},
#  {'a': '1FYB_model_007', 'b': '1FYB_model_001', 'type': 'NMR', 'rmsd': 10.897},
#  {'a': '2KUI_model_004', 'b': '2KUI_model_000', 'type': 'NMR', 'rmsd': 8.817},
#  {'a': '2N6L_model_003', 'b': '2N6L_model_001', 'type': 'NMR', 'rmsd': 5.771},
#  {'a': '2RSO_model_006', 'b': '2RSO_model_001', 'type': 'NMR', 'rmsd': 11.493},
#  {'a': '2LY1_model_016', 'b': '2LY1_model_013', 'type': 'NMR', 'rmsd': 10.72},
#  {'a': '5WOY_model_006', 'b': '5WOY_model_009', 'type': 'NMR', 'rmsd': 2.172},
#  {'a': '7QJF_model_002', 'b': '7QJF_model_014', 'type': 'NMR', 'rmsd': 2.101},
#  {'a': '2L26_model_007', 'b': '2L26_model_005', 'type': 'NMR', 'rmsd': 3.171},
#  {'a': '2LF0_model_014', 'b': '2LF0_model_009', 'type': 'NMR', 'rmsd': 2.088},
#  {'a': '1ZMZ_model_018', 'b': '1ZMZ_model_002', 'type': 'NMR', 'rmsd': 2.326},
#  {'a': '1R79_model_019', 'b': '1R79_model_017', 'type': 'NMR', 'rmsd': 2.438},
#  {'a': '2KUI_model_009', 'b': '2KUI_model_024', 'type': 'NMR', 'rmsd': 3.317},
#  {'a': '2K3P_model_001', 'b': '2K3P_model_000', 'type': 'NMR', 'rmsd': 2.258},
#  {'a': '1IRP_model_002', 'b': '1IRP_model_005', 'type': 'NMR', 'rmsd': 2.3},
#  {'a': '2KLU_model_019', 'b': '2KLU_model_007', 'type': 'NMR', 'rmsd': 10.365},
#  {'a': '2KW9_model_015', 'b': '2KW9_model_004', 'type': 'NMR', 'rmsd': 6.033},
#  {'a': '2DJA_model_011', 'b': '2DJA_model_007', 'type': 'NMR', 'rmsd': 3.701},
#  {'a': '1E88_model_010', 'b': '1E88_model_003', 'type': 'NMR', 'rmsd': 6.044},
#  {'a': '2K8I_model_003', 'b': '2K8I_model_004', 'type': 'NMR', 'rmsd': 2.765},
#  {'a': '2KS6_model_017', 'b': '2KS6_model_001', 'type': 'NMR', 'rmsd': 3.032},
#  {'a': '5MSL_model_005', 'b': '5MSL_model_008', 'type': 'NMR', 'rmsd': 8.079},
#  {'a': '2DLK_model_016', 'b': '2DLK_model_007', 'type': 'NMR', 'rmsd': 9.516},
#  {'a': '2MTS_model_005', 'b': '2MTS_model_003', 'type': 'NMR', 'rmsd': 2.296},
#  {'a': '2LOO_model_000', 'b': '2LOO_model_018', 'type': 'NMR', 'rmsd': 3.042},
#  {'a': '2L1U_model_016', 'b': '2L1U_model_006', 'type': 'NMR', 'rmsd': 2.24},
#  {'a': '2JT8_model_002', 'b': '2JT8_model_008', 'type': 'NMR', 'rmsd': 10.493},
#  {'a': '2KQ2_model_005', 'b': '2KQ2_model_017', 'type': 'NMR', 'rmsd': 5.013},
#  {'a': '6P6C_model_001', 'b': '6P6C_model_009', 'type': 'NMR', 'rmsd': 8.778},
#  {'a': '2CQW_model_019', 'b': '2CQW_model_015', 'type': 'NMR', 'rmsd': 8.517},
#  {'a': '2MKJ_model_006', 'b': '2MKJ_model_007', 'type': 'NMR', 'rmsd': 2.179},
#  {'a': '2NXU_model_004', 'b': '2NXU_model_008', 'type': 'NMR', 'rmsd': 2.519},
#  {'a': '2N6D_model_018', 'b': '2N6D_model_008', 'type': 'NMR', 'rmsd': 2.04},
#  {'a': '2L5V_model_005', 'b': '2L5V_model_010', 'type': 'NMR', 'rmsd': 5.601},
#  {'a': '2N45_model_010', 'b': '2N45_model_001', 'type': 'NMR', 'rmsd': 2.362},
#  {'a': '2MCZ_model_015', 'b': '2MCZ_model_018', 'type': 'NMR', 'rmsd': 2.322},
#  {'a': '2LFI_model_018', 'b': '2LFI_model_014', 'type': 'NMR', 'rmsd': 2.047},
#  {'a': '2KZ5_model_011', 'b': '2KZ5_model_002', 'type': 'NMR', 'rmsd': 2.125},
#  {'a': '1UEO_model_019', 'b': '1UEO_model_015', 'type': 'NMR', 'rmsd': 5.019},
#  {'a': '8RLZ_model_006', 'b': '8RLZ_model_008', 'type': 'NMR', 'rmsd': 3.499},
#  {'a': '7FBV_model_014', 'b': '7FBV_model_008', 'type': 'NMR', 'rmsd': 4.118},
#  {'a': '8TB1_model_009', 'b': '8TB1_model_001', 'type': 'NMR', 'rmsd': 2.303},
#  {'a': '2KQ2_model_014', 'b': '2KQ2_model_018', 'type': 'NMR', 'rmsd': 3.46},
#  {'a': '1V65_model_019', 'b': '1V65_model_016', 'type': 'NMR', 'rmsd': 9.391},
#  {'a': '2GDX_model_010', 'b': '2GDX_model_014', 'type': 'NMR', 'rmsd': 2.236},
#  {'a': '2KFW_model_008', 'b': '2KFW_model_002', 'type': 'NMR', 'rmsd': 7.872},
#  {'a': '2K9C_model_010', 'b': '2K9C_model_004', 'type': 'NMR', 'rmsd': 2.087},
#  {'a': '1POQ_model_014', 'b': '1POQ_model_011', 'type': 'NMR', 'rmsd': 2.209},
#  {'a': '5MN3_model_006', 'b': '5MN3_model_004', 'type': 'NMR', 'rmsd': 4.77},
#  {'a': '2ME0_model_006', 'b': '2ME0_model_003', 'type': 'NMR', 'rmsd': 2.914},
#  {'a': '6QH2_model_008', 'b': '6QH2_model_018', 'type': 'NMR', 'rmsd': 3.266},
#  {'a': '2DA3_model_003', 'b': '2DA3_model_013', 'type': 'NMR', 'rmsd': 5.414},
#  {'a': '1U3N_model_010', 'b': '1U3N_model_019', 'type': 'NMR', 'rmsd': 4.169},
#  {'a': '8J8I_model_002', 'b': '8J8I_model_007', 'type': 'NMR', 'rmsd': 10.637},
#  {'a': '2D21_model_012', 'b': '2D21_model_005', 'type': 'NMR', 'rmsd': 4.285},
#  {'a': '2LGQ_model_019', 'b': '2LGQ_model_017', 'type': 'NMR', 'rmsd': 5.851},
#  {'a': '2MSN_model_016', 'b': '2MSN_model_018', 'type': 'NMR', 'rmsd': 2.598},
#  {'a': '2L6L_model_001', 'b': '2L6L_model_004', 'type': 'NMR', 'rmsd': 9.615},
#  {'a': '2N8Z_model_005', 'b': '2N8Z_model_019', 'type': 'NMR', 'rmsd': 4.614},
#  {'a': '7FBV_model_010', 'b': '7FBV_model_008', 'type': 'NMR', 'rmsd': 8.86},
#  {'a': '2ME0_model_006', 'b': '2ME0_model_004', 'type': 'NMR', 'rmsd': 2.16},
#  {'a': '1FJE_model_004', 'b': '1FJE_model_013', 'type': 'NMR', 'rmsd': 2.4},
#  {'a': '1MFN_model_005', 'b': '1MFN_model_013', 'type': 'NMR', 'rmsd': 9.05},
#  {'a': '2MA5_model_015', 'b': '2MA5_model_012', 'type': 'NMR', 'rmsd': 2.402},
#  {'a': '1WGF_model_015', 'b': '1WGF_model_003', 'type': 'NMR', 'rmsd': 11.457},
#  {'a': '5MSL_model_001', 'b': '5MSL_model_008', 'type': 'NMR', 'rmsd': 7.097},
#  {'a': '2DLK_model_000', 'b': '2DLK_model_018', 'type': 'NMR', 'rmsd': 7.534},
#  {'a': '1WHE_model_014', 'b': '1WHE_model_018', 'type': 'NMR', 'rmsd': 2.416},
#  {'a': '5LW4_model_000', 'b': '5LW4_model_006', 'type': 'NMR', 'rmsd': 2.415},
#  {'a': '5TP5_model_015', 'b': '5TP5_model_001', 'type': 'NMR', 'rmsd': 9.069},
#  {'a': '1ZTR_model_004', 'b': '1ZTR_model_003', 'type': 'NMR', 'rmsd': 4.099},
#  {'a': '1CO1_model_000', 'b': '1CO1_model_006', 'type': 'NMR', 'rmsd': 2.358},
#  {'a': '2LV2_model_018', 'b': '2LV2_model_007', 'type': 'NMR', 'rmsd': 7.199},
#  {'a': '1DMO_model_020', 'b': '1DMO_model_018', 'type': 'NMR', 'rmsd': 6.56},
#  {'a': '1EZP_model_005', 'b': '1EZP_model_009', 'type': 'NMR', 'rmsd': 2.379},
#  {'a': '1JFJ_model_010', 'b': '1JFJ_model_003', 'type': 'NMR', 'rmsd': 7.749},
#  {'a': '1U5M_model_019', 'b': '1U5M_model_005', 'type': 'NMR', 'rmsd': 5.101},
#  {'a': '5NCA_model_010', 'b': '5NCA_model_006', 'type': 'NMR', 'rmsd': 3.929},
#  {'a': '1WFE_model_013', 'b': '1WFE_model_001', 'type': 'NMR', 'rmsd': 3.827},
#  {'a': '1UG2_model_003', 'b': '1UG2_model_004', 'type': 'NMR', 'rmsd': 11.06},
#  {'a': '1A91_model_004', 'b': '1A91_model_006', 'type': 'NMR', 'rmsd': 2.105},
#  {'a': '2LJU_model_003', 'b': '2LJU_model_017', 'type': 'NMR', 'rmsd': 5.31},
#  {'a': '2DK4_model_014', 'b': '2DK4_model_016', 'type': 'NMR', 'rmsd': 2.301},
#  {'a': '6SDW_model_003', 'b': '6SDW_model_017', 'type': 'NMR', 'rmsd': 2.501},
#  {'a': '1WFE_model_011', 'b': '1WFE_model_001', 'type': 'NMR', 'rmsd': 11.514},
#  {'a': '1HQI_model_008', 'b': '1HQI_model_006', 'type': 'NMR', 'rmsd': 3.308},
#  {'a': '6GDK_model_003', 'b': '6GDK_model_018', 'type': 'NMR', 'rmsd': 10.394},
#  {'a': '2KN6_model_011', 'b': '2KN6_model_002', 'type': 'NMR', 'rmsd': 10.129},
#  {'a': '7BUL_model_005', 'b': '7BUL_model_003', 'type': 'NMR', 'rmsd': 8.73},
#  {'a': '1EZO_model_000', 'b': '1EZO_model_005', 'type': 'NMR', 'rmsd': 2.991},
#  {'a': '2JVL_model_014', 'b': '2JVL_model_002', 'type': 'NMR', 'rmsd': 4.743},
#  {'a': '6QH2_model_013', 'b': '6QH2_model_014', 'type': 'NMR', 'rmsd': 3.72},
#  {'a': '7KW9_model_018', 'b': '7KW9_model_012', 'type': 'NMR', 'rmsd': 3.307},
#  {'a': '2JRF_model_006', 'b': '2JRF_model_010', 'type': 'NMR', 'rmsd': 4.139},
#  {'a': '1RMJ_model_006', 'b': '1RMJ_model_002', 'type': 'NMR', 'rmsd': 3.181},
#  {'a': '2J4N_model_002', 'b': '2J4N_model_003', 'type': 'NMR', 'rmsd': 3.318},
#  {'a': '2K2B_model_000', 'b': '2K2B_model_010', 'type': 'NMR', 'rmsd': 2.552},
#  {'a': '1WYS_model_019', 'b': '1WYS_model_017', 'type': 'NMR', 'rmsd': 2.73},
#  {'a': '2JXW_model_011', 'b': '2JXW_model_017', 'type': 'NMR', 'rmsd': 3.63},
#  {'a': '2JTO_model_000', 'b': '2JTO_model_005', 'type': 'NMR', 'rmsd': 2.127},
#  {'a': '2K5F_model_017', 'b': '2K5F_model_016', 'type': 'NMR', 'rmsd': 8.802},
#  {'a': '2MT3_model_001', 'b': '2MT3_model_010', 'type': 'NMR', 'rmsd': 3.071},
#  {'a': '2K9P_model_001', 'b': '2K9P_model_005', 'type': 'NMR', 'rmsd': 2.509},
#  {'a': '2N1I_model_018', 'b': '2N1I_model_016', 'type': 'NMR', 'rmsd': 4.126},
#  {'a': '1QRJ_model_004', 'b': '1QRJ_model_001', 'type': 'NMR', 'rmsd': 6.392},
#  {'a': '6UCJ_model_017', 'b': '6UCJ_model_019', 'type': 'NMR', 'rmsd': 2.187},
#  {'a': '1IQ3_model_011', 'b': '1IQ3_model_016', 'type': 'NMR', 'rmsd': 2.184},
#  {'a': '5A4G_model_004', 'b': '5A4G_model_015', 'type': 'NMR', 'rmsd': 10.506},
#  {'a': '1TNW_model_012', 'b': '1TNW_model_015', 'type': 'NMR', 'rmsd': 7.018},
#  {'a': '1WFH_model_010', 'b': '1WFH_model_013', 'type': 'NMR', 'rmsd': 3.101},
#  {'a': '8FA3_model_011', 'b': '8FA3_model_017', 'type': 'NMR', 'rmsd': 4.829},
#  {'a': '2EPA_model_015', 'b': '2EPA_model_009', 'type': 'NMR', 'rmsd': 10.503},
#  {'a': '2K0S_model_002', 'b': '2K0S_model_004', 'type': 'NMR', 'rmsd': 2.92},
#  {'a': '1U96_model_005', 'b': '1U96_model_018', 'type': 'NMR', 'rmsd': 10.733},
#  {'a': '1Q8K_model_005', 'b': '1Q8K_model_003', 'type': 'NMR', 'rmsd': 8.182},
#  {'a': '2LM7_model_003', 'b': '2LM7_model_002', 'type': 'NMR', 'rmsd': 5.113},
#  {'a': '1RIP_model_005', 'b': '1RIP_model_003', 'type': 'NMR', 'rmsd': 2.419},
#  {'a': '2K4T_model_008', 'b': '2K4T_model_004', 'type': 'NMR', 'rmsd': 4.722},
#  {'a': '2FYJ_model_013', 'b': '2FYJ_model_014', 'type': 'NMR', 'rmsd': 2.606},
#  {'a': '7QDE_model_002', 'b': '7QDE_model_006', 'type': 'NMR', 'rmsd': 2.012},
#  {'a': '2JVM_model_006', 'b': '2JVM_model_013', 'type': 'NMR', 'rmsd': 4.193},
#  {'a': '1VEG_model_008', 'b': '1VEG_model_019', 'type': 'NMR', 'rmsd': 2.964},
#  {'a': '2KVL_model_003', 'b': '2KVL_model_007', 'type': 'NMR', 'rmsd': 5.426},
#  {'a': '1TNW_model_017', 'b': '1TNW_model_007', 'type': 'NMR', 'rmsd': 11.251},
#  {'a': '1VZS_model_013', 'b': '1VZS_model_027', 'type': 'NMR', 'rmsd': 3.614},
#  {'a': '2L9Y_model_000', 'b': '2L9Y_model_021', 'type': 'NMR', 'rmsd': 3.149},
#  {'a': '1X64_model_001', 'b': '1X64_model_014', 'type': 'NMR', 'rmsd': 2.183},
#  {'a': '5MN3_model_018', 'b': '5MN3_model_013', 'type': 'NMR', 'rmsd': 3.638},
#  {'a': '2G0U_model_017', 'b': '2G0U_model_003', 'type': 'NMR', 'rmsd': 6.709},
#  {'a': '4BIT_model_005', 'b': '4BIT_model_010', 'type': 'NMR', 'rmsd': 5.854},
#  {'a': '2BW2_model_004', 'b': '2BW2_model_003', 'type': 'NMR', 'rmsd': 2.129},
#  {'a': '6UCJ_model_000', 'b': '6UCJ_model_019', 'type': 'NMR', 'rmsd': 5.74},
#  {'a': '1TVS_model_004', 'b': '1TVS_model_001', 'type': 'NMR', 'rmsd': 10.514},
#  {'a': '1DZ7_model_011', 'b': '1DZ7_model_024', 'type': 'NMR', 'rmsd': 2.414},
#  {'a': '1HQI_model_004', 'b': '1HQI_model_008', 'type': 'NMR', 'rmsd': 2.119},
#  {'a': '2LUY_model_016', 'b': '2LUY_model_014', 'type': 'NMR', 'rmsd': 7.123},
#  {'a': '5MN3_model_006', 'b': '5MN3_model_013', 'type': 'NMR', 'rmsd': 2.106},
#  {'a': '2M0A_model_007', 'b': '2M0A_model_001', 'type': 'NMR', 'rmsd': 2.022},
#  {'a': '1X6F_model_003', 'b': '1X6F_model_007', 'type': 'NMR', 'rmsd': 6.389},
#  {'a': '1HQI_model_004', 'b': '1HQI_model_011', 'type': 'NMR', 'rmsd': 3.482},
#  {'a': '1WIL_model_018', 'b': '1WIL_model_003', 'type': 'NMR', 'rmsd': 4.45},
#  {'a': '1WFF_model_019', 'b': '1WFF_model_014', 'type': 'NMR', 'rmsd': 4.957},
#  {'a': '1WHE_model_012', 'b': '1WHE_model_011', 'type': 'NMR', 'rmsd': 3.752},
#  {'a': '1J8I_model_003', 'b': '1J8I_model_005', 'type': 'NMR', 'rmsd': 10.367},
#  {'a': '1RKJ_model_012', 'b': '1RKJ_model_002', 'type': 'NMR', 'rmsd': 2.368},
#  {'a': '2RSJ_model_015', 'b': '2RSJ_model_014', 'type': 'NMR', 'rmsd': 5.422},
#  {'a': '1TNW_model_015', 'b': '1TNW_model_003', 'type': 'NMR', 'rmsd': 7.302},
#  {'a': '2K5H_model_001', 'b': '2K5H_model_007', 'type': 'NMR', 'rmsd': 9.53},
#  {'a': '6NZL_model_007', 'b': '6NZL_model_013', 'type': 'NMR', 'rmsd': 8.761},
#  {'a': '2LJU_model_005', 'b': '2LJU_model_011', 'type': 'NMR', 'rmsd': 3.368},
#  {'a': '6CUC_model_008', 'b': '6CUC_model_015', 'type': 'NMR', 'rmsd': 2.309},
#  {'a': '2K7Z_model_005', 'b': '2K7Z_model_018', 'type': 'NMR', 'rmsd': 2.817},
#  {'a': '2O3D_model_007', 'b': '2O3D_model_006', 'type': 'NMR', 'rmsd': 2.951},
#  {'a': '1UH6_model_008', 'b': '1UH6_model_007', 'type': 'NMR', 'rmsd': 8.653},
#  {'a': '2LNT_model_001', 'b': '2LNT_model_005', 'type': 'NMR', 'rmsd': 2.271},
#  {'a': '2NXU_model_007', 'b': '2NXU_model_003', 'type': 'NMR', 'rmsd': 2.041},
#  {'a': '2DAS_model_018', 'b': '2DAS_model_002', 'type': 'NMR', 'rmsd': 7.834},
#  {'a': '5MS9_model_014', 'b': '5MS9_model_008', 'type': 'NMR', 'rmsd': 2.728},
#  {'a': '2CSH_model_011', 'b': '2CSH_model_013', 'type': 'NMR', 'rmsd': 9.208},
#  {'a': '7BUL_model_007', 'b': '7BUL_model_013', 'type': 'NMR', 'rmsd': 3.401},
#  {'a': '2RVL_model_001', 'b': '2RVL_model_011', 'type': 'NMR', 'rmsd': 8.508},
#  {'a': '2MDK_model_001', 'b': '2MDK_model_005', 'type': 'NMR', 'rmsd': 2.031},
#  {'a': '2KOG_model_010', 'b': '2KOG_model_017', 'type': 'NMR', 'rmsd': 9.875},
#  {'a': '6RWG_model_001', 'b': '6RWG_model_009', 'type': 'NMR', 'rmsd': 9.642},
#  {'a': '1D1D_model_008', 'b': '1D1D_model_009', 'type': 'NMR', 'rmsd': 2.487},
#  {'a': '7AFR_model_002', 'b': '7AFR_model_015', 'type': 'NMR', 'rmsd': 10.912},
#  {'a': '2ME8_model_011', 'b': '2ME8_model_002', 'type': 'NMR', 'rmsd': 2.672},
#  {'a': '6CUI_model_018', 'b': '6CUI_model_013', 'type': 'NMR', 'rmsd': 8.795},
#  {'a': '8QPD_model_011', 'b': '8QPD_model_018', 'type': 'NMR', 'rmsd': 2.028},
#  {'a': '1LV3_model_000', 'b': '1LV3_model_001', 'type': 'NMR', 'rmsd': 3.691},
#  {'a': '2JOW_model_014', 'b': '2JOW_model_002', 'type': 'NMR', 'rmsd': 2.455},
#  {'a': '1WEU_model_006', 'b': '1WEU_model_019', 'type': 'NMR', 'rmsd': 5.673},
#  {'a': '1WFO_model_015', 'b': '1WFO_model_011', 'type': 'NMR', 'rmsd': 4.283},
#  {'a': '2LUT_model_000', 'b': '2LUT_model_009', 'type': 'NMR', 'rmsd': 10.221},
#  {'a': '6GDK_model_018', 'b': '6GDK_model_013', 'type': 'NMR', 'rmsd': 9.057},
#  {'a': '1X02_model_019', 'b': '1X02_model_011', 'type': 'NMR', 'rmsd': 3.481},
#  {'a': '2K21_model_002', 'b': '2K21_model_006', 'type': 'NMR', 'rmsd': 2.792},
#  {'a': '2M5I_model_012', 'b': '2M5I_model_018', 'type': 'NMR', 'rmsd': 4.246},
#  {'a': '2M1U_model_009', 'b': '2M1U_model_013', 'type': 'NMR', 'rmsd': 9.128},
#  {'a': '1JVR_model_003', 'b': '1JVR_model_007', 'type': 'NMR', 'rmsd': 8.312},
#  {'a': '2CT7_model_008', 'b': '2CT7_model_015', 'type': 'NMR', 'rmsd': 2.211},
#  {'a': '8J8I_model_009', 'b': '8J8I_model_007', 'type': 'NMR', 'rmsd': 5.475},
#  {'a': '2JNC_model_014', 'b': '2JNC_model_011', 'type': 'NMR', 'rmsd': 2.117},
#  {'a': '2KD3_model_000', 'b': '2KD3_model_014', 'type': 'NMR', 'rmsd': 3.122},
#  {'a': '2RSJ_model_018', 'b': '2RSJ_model_008', 'type': 'NMR', 'rmsd': 9.187},
#  {'a': '6JPP_model_009', 'b': '6JPP_model_010', 'type': 'NMR', 'rmsd': 10.755},
#  {'a': '3LRI_model_013', 'b': '3LRI_model_000', 'type': 'NMR', 'rmsd': 3.046},
#  {'a': '2LOR_model_004', 'b': '2LOR_model_002', 'type': 'NMR', 'rmsd': 3.023},
#  {'a': '8DWQ_model_004', 'b': '8DWQ_model_005', 'type': 'NMR', 'rmsd': 2.958},
#  {'a': '2LYS_model_002', 'b': '2LYS_model_019', 'type': 'NMR', 'rmsd': 2.798},
#  {'a': '2KVU_model_013', 'b': '2KVU_model_016', 'type': 'NMR', 'rmsd': 2.727},
#  {'a': '6UCK_model_012', 'b': '6UCK_model_018', 'type': 'NMR', 'rmsd': 2.038},
#  {'a': '2LXE_model_010', 'b': '2LXE_model_014', 'type': 'NMR', 'rmsd': 3.347},
#  {'a': '2FKX_model_013', 'b': '2FKX_model_014', 'type': 'NMR', 'rmsd': 2.633},
#  {'a': '2ITA_model_006', 'b': '2ITA_model_009', 'type': 'NMR', 'rmsd': 2.28},
#  {'a': '2F3V_model_007', 'b': '2F3V_model_006', 'type': 'NMR', 'rmsd': 4.451},
#  {'a': '1LV3_model_011', 'b': '1LV3_model_018', 'type': 'NMR', 'rmsd': 2.003},
#  {'a': '1QU6_model_003', 'b': '1QU6_model_009', 'type': 'NMR', 'rmsd': 4.207},
#  {'a': '2LM7_model_002', 'b': '2LM7_model_006', 'type': 'NMR', 'rmsd': 2.025},
#  {'a': '1EZO_model_004', 'b': '1EZO_model_007', 'type': 'NMR', 'rmsd': 3.598},
#  {'a': '2M9A_model_014', 'b': '2M9A_model_009', 'type': 'NMR', 'rmsd': 7.578},
#  {'a': '6U1O_model_010', 'b': '6U1O_model_002', 'type': 'NMR', 'rmsd': 7.821},
#  {'a': '1V65_model_019', 'b': '1V65_model_012', 'type': 'NMR', 'rmsd': 8.991},
#  {'a': '1BCT_model_005', 'b': '1BCT_model_011', 'type': 'NMR', 'rmsd': 7.141},
#  {'a': '2JNC_model_014', 'b': '2JNC_model_019', 'type': 'NMR', 'rmsd': 2.332},
#  {'a': '5XJK_model_002', 'b': '5XJK_model_016', 'type': 'NMR', 'rmsd': 10.132},
#  {'a': '2LCP_model_011', 'b': '2LCP_model_013', 'type': 'NMR', 'rmsd': 2.373},
#  {'a': '2E6I_model_015', 'b': '2E6I_model_018', 'type': 'NMR', 'rmsd': 2.357},
#  {'a': '2DZL_model_005', 'b': '2DZL_model_006', 'type': 'NMR', 'rmsd': 2.04},
#  {'a': '2KUD_model_004', 'b': '2KUD_model_013', 'type': 'NMR', 'rmsd': 2.404},
#  {'a': '2JQE_model_006', 'b': '2JQE_model_002', 'type': 'NMR', 'rmsd': 3.466},
#  {'a': '1DMO_model_020', 'b': '1DMO_model_017', 'type': 'NMR', 'rmsd': 8.938},
#  {'a': '2KN6_model_012', 'b': '2KN6_model_002', 'type': 'NMR', 'rmsd': 9.695},
#  {'a': '2LOV_model_005', 'b': '2LOV_model_004', 'type': 'NMR', 'rmsd': 11.085},
#  {'a': '2OUT_model_005', 'b': '2OUT_model_010', 'type': 'NMR', 'rmsd': 11.327},
#  {'a': '2JQY_model_006', 'b': '2JQY_model_000', 'type': 'NMR', 'rmsd': 2.377},
#  {'a': '2L3N_model_003', 'b': '2L3N_model_007', 'type': 'NMR', 'rmsd': 7.235},
#  {'a': '2LQL_model_013', 'b': '2LQL_model_002', 'type': 'NMR', 'rmsd': 11.245},
#  {'a': '2MB9_model_009', 'b': '2MB9_model_006', 'type': 'NMR', 'rmsd': 2.493},
#  {'a': '2N47_model_003', 'b': '2N47_model_010', 'type': 'NMR', 'rmsd': 2.175},
#  {'a': '1GGW_model_011', 'b': '1GGW_model_001', 'type': 'NMR', 'rmsd': 10.447},
#  {'a': '2MT3_model_004', 'b': '2MT3_model_010', 'type': 'NMR', 'rmsd': 3.311},
#  {'a': '2JXN_model_007', 'b': '2JXN_model_016', 'type': 'NMR', 'rmsd': 4.799},
#  {'a': '2KN8_model_000', 'b': '2KN8_model_006', 'type': 'NMR', 'rmsd': 5.097},
#  {'a': '2RSO_model_012', 'b': '2RSO_model_001', 'type': 'NMR', 'rmsd': 3.387},
#  {'a': '5KQJ_model_012', 'b': '5KQJ_model_006', 'type': 'NMR', 'rmsd': 3.377},
#  {'a': '2RPC_model_008', 'b': '2RPC_model_012', 'type': 'NMR', 'rmsd': 3.397},
#  {'a': '6BQI_model_007', 'b': '6BQI_model_001', 'type': 'NMR', 'rmsd': 10.379},
#  {'a': '2EPP_model_002', 'b': '2EPP_model_005', 'type': 'NMR', 'rmsd': 3.575},
#  {'a': '2L9N_model_018', 'b': '2L9N_model_017', 'type': 'NMR', 'rmsd': 2.156},
#  {'a': '1WHX_model_001', 'b': '1WHX_model_006', 'type': 'NMR', 'rmsd': 2.406},
#  {'a': '2GZO_model_011', 'b': '2GZO_model_007', 'type': 'NMR', 'rmsd': 2.113},
#  {'a': '1X6F_model_007', 'b': '1X6F_model_018', 'type': 'NMR', 'rmsd': 5.959},
#  {'a': '2KQ2_model_005', 'b': '2KQ2_model_014', 'type': 'NMR', 'rmsd': 2.952},
#  {'a': '2ECI_model_001', 'b': '2ECI_model_017', 'type': 'NMR', 'rmsd': 10.666},
#  {'a': '2M88_model_002', 'b': '2M88_model_008', 'type': 'NMR', 'rmsd': 8.197},
#  {'a': '2EP4_model_005', 'b': '2EP4_model_009', 'type': 'NMR', 'rmsd': 2.086},
#  {'a': '5KES_model_006', 'b': '5KES_model_005', 'type': 'NMR', 'rmsd': 10.402},
#  {'a': '6I9B_model_003', 'b': '6I9B_model_013', 'type': 'NMR', 'rmsd': 2.68},
#  {'a': '2N4A_model_012', 'b': '2N4A_model_015', 'type': 'NMR', 'rmsd': 2.311},
#  {'a': '6U3R_model_001', 'b': '6U3R_model_007', 'type': 'NMR', 'rmsd': 3.973},
#  {'a': '1VEG_model_008', 'b': '1VEG_model_016', 'type': 'NMR', 'rmsd': 3.374},
#  {'a': '2DKL_model_007', 'b': '2DKL_model_017', 'type': 'NMR', 'rmsd': 3.54},
#  {'a': '2RNZ_model_019', 'b': '2RNZ_model_018', 'type': 'NMR', 'rmsd': 4.44},
#  {'a': '2JT3_model_005', 'b': '2JT3_model_002', 'type': 'NMR', 'rmsd': 9.061},
#  {'a': '2KMW_model_019', 'b': '2KMW_model_007', 'type': 'NMR', 'rmsd': 11.592},
#  {'a': '9F4C_model_013', 'b': '9F4C_model_007', 'type': 'NMR', 'rmsd': 4.782},
#  {'a': '2L0A_model_018', 'b': '2L0A_model_001', 'type': 'NMR', 'rmsd': 4.467},
#  {'a': '1WIB_model_004', 'b': '1WIB_model_009', 'type': 'NMR', 'rmsd': 2.26},
#  {'a': '2M48_model_017', 'b': '2M48_model_003', 'type': 'NMR', 'rmsd': 10.171},
#  {'a': '2LOV_model_029', 'b': '2LOV_model_005', 'type': 'NMR', 'rmsd': 9.272},
#  {'a': '1ZR9_model_000', 'b': '1ZR9_model_013', 'type': 'NMR', 'rmsd': 10.398},
#  {'a': '2ITA_model_001', 'b': '2ITA_model_008', 'type': 'NMR', 'rmsd': 2.382},
#  {'a': '2KCX_model_013', 'b': '2KCX_model_012', 'type': 'NMR', 'rmsd': 2.857},
#  {'a': '1X3C_model_009', 'b': '1X3C_model_006', 'type': 'NMR', 'rmsd': 11.103},
#  {'a': '6CJZ_model_001', 'b': '6CJZ_model_000', 'type': 'NMR', 'rmsd': 2.086},
#  {'a': '2K2B_model_010', 'b': '2K2B_model_004', 'type': 'NMR', 'rmsd': 2.969},
#  {'a': '1X5W_model_018', 'b': '1X5W_model_011', 'type': 'NMR', 'rmsd': 6.613},
#  {'a': '7XRW_model_005', 'b': '7XRW_model_009', 'type': 'NMR', 'rmsd': 8.242},
#  {'a': '1TIV_model_004', 'b': '1TIV_model_006', 'type': 'NMR', 'rmsd': 5.504},
#  {'a': '2FKX_model_011', 'b': '2FKX_model_017', 'type': 'NMR', 'rmsd': 3.091},
#  {'a': '2F3V_model_006', 'b': '2F3V_model_004', 'type': 'NMR', 'rmsd': 2.321},
#  {'a': '2LMU_model_013', 'b': '2LMU_model_009', 'type': 'NMR', 'rmsd': 2.825},
#  {'a': '2MLH_model_009', 'b': '2MLH_model_016', 'type': 'NMR', 'rmsd': 6.54},
#  {'a': '2LM7_model_005', 'b': '2LM7_model_002', 'type': 'NMR', 'rmsd': 3.155},
#  {'a': '8BDV_model_007', 'b': '8BDV_model_008', 'type': 'NMR', 'rmsd': 2.016},
#  {'a': '5KES_model_003', 'b': '5KES_model_005', 'type': 'NMR', 'rmsd': 5.449},
#  {'a': '8SHM_model_016', 'b': '8SHM_model_014', 'type': 'NMR', 'rmsd': 6.996},
#  {'a': '2RSI_model_016', 'b': '2RSI_model_017', 'type': 'NMR', 'rmsd': 8.361},
#  {'a': '2LZE_model_014', 'b': '2LZE_model_006', 'type': 'NMR', 'rmsd': 4.139},
#  {'a': '1FYB_model_001', 'b': '1FYB_model_000', 'type': 'NMR', 'rmsd': 11.239},
#  {'a': '1TOZ_model_011', 'b': '1TOZ_model_017', 'type': 'NMR', 'rmsd': 3.214},
#  {'a': '2LZE_model_004', 'b': '2LZE_model_012', 'type': 'NMR', 'rmsd': 4.494},
#  {'a': '2LQL_model_019', 'b': '2LQL_model_013', 'type': 'NMR', 'rmsd': 11.042},
#  {'a': '1BQT_model_004', 'b': '1BQT_model_002', 'type': 'NMR', 'rmsd': 3.376},
#  {'a': '1Z8S_model_002', 'b': '1Z8S_model_003', 'type': 'NMR', 'rmsd': 3.625},
#  {'a': '2LCE_model_009', 'b': '2LCE_model_006', 'type': 'NMR', 'rmsd': 8.535},
#  {'a': '2I2Y_model_000', 'b': '2I2Y_model_002', 'type': 'NMR', 'rmsd': 6.883},
#  {'a': '2CKC_model_016', 'b': '2CKC_model_002', 'type': 'NMR', 'rmsd': 3.555},
#  {'a': '2KRR_model_017', 'b': '2KRR_model_015', 'type': 'NMR', 'rmsd': 10.631},
#  {'a': '2AKL_model_017', 'b': '2AKL_model_010', 'type': 'NMR', 'rmsd': 4.035},
#  {'a': '2ELH_model_006', 'b': '2ELH_model_012', 'type': 'NMR', 'rmsd': 2.204},
#  {'a': '6MZA_model_004', 'b': '6MZA_model_007', 'type': 'NMR', 'rmsd': 4.074},
#  {'a': '2K5F_model_001', 'b': '2K5F_model_017', 'type': 'NMR', 'rmsd': 3.191},
#  {'a': '2N84_model_001', 'b': '2N84_model_007', 'type': 'NMR', 'rmsd': 3.538},
#  {'a': '5XJK_model_018', 'b': '5XJK_model_016', 'type': 'NMR', 'rmsd': 10.188},
#  {'a': '7VZM_model_002', 'b': '7VZM_model_016', 'type': 'NMR', 'rmsd': 2.746},
#  {'a': '6LEK_model_007', 'b': '6LEK_model_003', 'type': 'NMR', 'rmsd': 7.946},
#  {'a': '2KCX_model_003', 'b': '2KCX_model_001', 'type': 'NMR', 'rmsd': 2.217},
#  {'a': '2JOR_model_006', 'b': '2JOR_model_002', 'type': 'NMR', 'rmsd': 2.931},
#  {'a': '2M2A_model_002', 'b': '2M2A_model_001', 'type': 'NMR', 'rmsd': 2.054},
#  {'a': '5NR5_model_014', 'b': '5NR5_model_015', 'type': 'NMR', 'rmsd': 11.354},
#  {'a': '2RSO_model_000', 'b': '2RSO_model_012', 'type': 'NMR', 'rmsd': 3.223},
#  {'a': '3ZBE_model_022', 'b': '3ZBE_model_029', 'type': 'NMR', 'rmsd': 8.252},
#  {'a': '6CWS_model_008', 'b': '6CWS_model_018', 'type': 'NMR', 'rmsd': 9.182},
#  {'a': '5MSL_model_004', 'b': '5MSL_model_008', 'type': 'NMR', 'rmsd': 6.418},
#  {'a': '1U96_model_009', 'b': '1U96_model_007', 'type': 'NMR', 'rmsd': 2.623},
#  {'a': '8SKX_model_014', 'b': '8SKX_model_015', 'type': 'NMR', 'rmsd': 3.246},
#  {'a': '1RIP_model_000', 'b': '1RIP_model_005', 'type': 'NMR', 'rmsd': 4.006},
#  {'a': '6X46_model_004', 'b': '6X46_model_000', 'type': 'NMR', 'rmsd': 7.296},
#  {'a': '2LOO_model_016', 'b': '2LOO_model_000', 'type': 'NMR', 'rmsd': 7.974},
#  {'a': '5MS9_model_008', 'b': '5MS9_model_000', 'type': 'NMR', 'rmsd': 2.317},
#  {'a': '1HD4_model_014', 'b': '1HD4_model_001', 'type': 'NMR', 'rmsd': 9.198},
#  {'a': '2JNF_model_009', 'b': '2JNF_model_002', 'type': 'NMR', 'rmsd': 6.409},
#  {'a': '1URK_model_010', 'b': '1URK_model_008', 'type': 'NMR', 'rmsd': 11.449},
#  {'a': '2K9P_model_015', 'b': '2K9P_model_011', 'type': 'NMR', 'rmsd': 4.201},
#  {'a': '2LMU_model_002', 'b': '2LMU_model_015', 'type': 'NMR', 'rmsd': 3.447},
#  {'a': '5M4T_model_032', 'b': '5M4T_model_033', 'type': 'NMR', 'rmsd': 2.675},
#  {'a': '1K0H_model_002', 'b': '1K0H_model_006', 'type': 'NMR', 'rmsd': 2.555},
#  {'a': '2KN6_model_001', 'b': '2KN6_model_015', 'type': 'NMR', 'rmsd': 4.277},
#  {'a': '7TXX_model_000', 'b': '7TXX_model_017', 'type': 'NMR', 'rmsd': 8.079},
#  {'a': '2MT3_model_019', 'b': '2MT3_model_010', 'type': 'NMR', 'rmsd': 3.388},
#  {'a': '8JR7_model_007', 'b': '8JR7_model_005', 'type': 'NMR', 'rmsd': 2.259},
#  {'a': '5XQ5_model_000', 'b': '5XQ5_model_002', 'type': 'NMR', 'rmsd': 2.14},
#  {'a': '2YTU_model_019', 'b': '2YTU_model_012', 'type': 'NMR', 'rmsd': 8.799},
#  {'a': '8PXW_model_004', 'b': '8PXW_model_014', 'type': 'NMR', 'rmsd': 3.413},
#  {'a': '2BKD_model_007', 'b': '2BKD_model_006', 'type': 'NMR', 'rmsd': 2.988},
#  {'a': '1WIV_model_001', 'b': '1WIV_model_014', 'type': 'NMR', 'rmsd': 3.521},
#  {'a': '2JYU_model_000', 'b': '2JYU_model_004', 'type': 'NMR', 'rmsd': 9.415},
#  {'a': '2HJQ_model_008', 'b': '2HJQ_model_013', 'type': 'NMR', 'rmsd': 6.417},
#  {'a': '6OQH_model_005', 'b': '6OQH_model_006', 'type': 'NMR', 'rmsd': 2.289},
#  {'a': '2NXU_model_003', 'b': '2NXU_model_009', 'type': 'NMR', 'rmsd': 2.4},
#  {'a': '2YUO_model_018', 'b': '2YUO_model_000', 'type': 'NMR', 'rmsd': 5.535},
#  {'a': '9X70_model_005', 'b': '9X70_model_006', 'type': 'NMR', 'rmsd': 2.429},
#  {'a': '2DLP_model_018', 'b': '2DLP_model_007', 'type': 'NMR', 'rmsd': 7.563},
#  {'a': '6BQI_model_007', 'b': '6BQI_model_002', 'type': 'NMR', 'rmsd': 9.898},
#  {'a': '2N6P_model_018', 'b': '2N6P_model_009', 'type': 'NMR', 'rmsd': 2.555},
#  {'a': '2KOG_model_010', 'b': '2KOG_model_011', 'type': 'NMR', 'rmsd': 9.405},
#  {'a': '5NR5_model_014', 'b': '5NR5_model_019', 'type': 'NMR', 'rmsd': 6.611},
#  {'a': '2M5Y_model_009', 'b': '2M5Y_model_011', 'type': 'NMR', 'rmsd': 4.181},
#  {'a': '7NF9_model_009', 'b': '7NF9_model_014', 'type': 'NMR', 'rmsd': 6.83},
#  {'a': '8I25_model_003', 'b': '8I25_model_004', 'type': 'NMR', 'rmsd': 2.566},
#  {'a': '2CTT_model_003', 'b': '2CTT_model_002', 'type': 'NMR', 'rmsd': 3.664},
#  {'a': '1RKJ_model_004', 'b': '1RKJ_model_007', 'type': 'NMR', 'rmsd': 3.55},
#  {'a': '2K32_model_011', 'b': '2K32_model_006', 'type': 'NMR', 'rmsd': 2.64},
#  {'a': '1D4B_model_013', 'b': '1D4B_model_007', 'type': 'NMR', 'rmsd': 10.068},
#  {'a': '5B7X_model_003', 'b': '5B7X_model_000', 'type': 'NMR', 'rmsd': 9.489},
#  {'a': '2KCX_model_012', 'b': '2KCX_model_003', 'type': 'NMR', 'rmsd': 3.253},
#  {'a': '1X6E_model_008', 'b': '1X6E_model_017', 'type': 'NMR', 'rmsd': 3.775},
#  {'a': '1COU_model_017', 'b': '1COU_model_015', 'type': 'NMR', 'rmsd': 2.434},
#  {'a': '2LCP_model_011', 'b': '2LCP_model_016', 'type': 'NMR', 'rmsd': 3.749},
#  {'a': '2L9N_model_016', 'b': '2L9N_model_017', 'type': 'NMR', 'rmsd': 2.93},
#  {'a': '2E6I_model_011', 'b': '2E6I_model_005', 'type': 'NMR', 'rmsd': 4.07},
#  {'a': '1FYB_model_006', 'b': '1FYB_model_001', 'type': 'NMR', 'rmsd': 8.873},
#  {'a': '2LON_model_018', 'b': '2LON_model_005', 'type': 'NMR', 'rmsd': 2.129},
#  {'a': '7BWO_model_009', 'b': '7BWO_model_006', 'type': 'NMR', 'rmsd': 7.757},
#  {'a': '2YUS_model_001', 'b': '2YUS_model_014', 'type': 'NMR', 'rmsd': 5.198},
#  {'a': '1WFF_model_006', 'b': '1WFF_model_013', 'type': 'NMR', 'rmsd': 7.863},
#  {'a': '1TVT_model_003', 'b': '1TVT_model_000', 'type': 'NMR', 'rmsd': 6.854},
#  {'a': '7UGC_model_011', 'b': '7UGC_model_006', 'type': 'NMR', 'rmsd': 2.231},
#  {'a': '2RSM_model_018', 'b': '2RSM_model_008', 'type': 'NMR', 'rmsd': 8.67},
#  {'a': '2LDY_model_010', 'b': '2LDY_model_017', 'type': 'NMR', 'rmsd': 7.294},
#  {'a': '6LEK_model_008', 'b': '6LEK_model_001', 'type': 'NMR', 'rmsd': 6.147},
#  {'a': '1NWV_model_039', 'b': '1NWV_model_016', 'type': 'NMR', 'rmsd': 3.27},
#  {'a': '5YJ5_model_007', 'b': '5YJ5_model_005', 'type': 'NMR', 'rmsd': 10.199},
#  {'a': '2NDJ_model_003', 'b': '2NDJ_model_007', 'type': 'NMR', 'rmsd': 7.205},
#  {'a': '2LMV_model_010', 'b': '2LMV_model_015', 'type': 'NMR', 'rmsd': 9.59},
#  {'a': '1RIP_model_004', 'b': '1RIP_model_003', 'type': 'NMR', 'rmsd': 3.459},
#  {'a': '1WFF_model_014', 'b': '1WFF_model_004', 'type': 'NMR', 'rmsd': 5.479},
#  {'a': '2MP3_model_000', 'b': '2MP3_model_001', 'type': 'NMR', 'rmsd': 8.268},
#  {'a': '1WFL_model_002', 'b': '1WFL_model_000', 'type': 'NMR', 'rmsd': 11.815},
#  {'a': '2NV3_model_017', 'b': '2NV3_model_004', 'type': 'NMR', 'rmsd': 6.699},
#  {'a': '2M7L_model_001', 'b': '2M7L_model_005', 'type': 'NMR', 'rmsd': 6.695},
#  {'a': '2LUY_model_014', 'b': '2LUY_model_005', 'type': 'NMR', 'rmsd': 3.601},
#  {'a': '2LMV_model_010', 'b': '2LMV_model_019', 'type': 'NMR', 'rmsd': 2.675},
#  {'a': '2K2B_model_000', 'b': '2K2B_model_009', 'type': 'NMR', 'rmsd': 2.945},
#  {'a': '2K4T_model_011', 'b': '2K4T_model_008', 'type': 'NMR', 'rmsd': 4.784},
#  {'a': '2F3V_model_006', 'b': '2F3V_model_000', 'type': 'NMR', 'rmsd': 4.284},
#  {'a': '2RN9_model_018', 'b': '2RN9_model_012', 'type': 'NMR', 'rmsd': 7.195},
#  {'a': '6QAM_model_007', 'b': '6QAM_model_014', 'type': 'NMR', 'rmsd': 2.533},
#  {'a': '2KVL_model_003', 'b': '2KVL_model_008', 'type': 'NMR', 'rmsd': 2.428},
#  {'a': '6XRY_model_018', 'b': '6XRY_model_011', 'type': 'NMR', 'rmsd': 11.156},
#  {'a': '2MJN_model_006', 'b': '2MJN_model_001', 'type': 'NMR', 'rmsd': 11.246},
#  {'a': '2K5K_model_002', 'b': '2K5K_model_000', 'type': 'NMR', 'rmsd': 7.519},
#  {'a': '2F40_model_002', 'b': '2F40_model_007', 'type': 'NMR', 'rmsd': 2.052},
#  {'a': '2JRF_model_004', 'b': '2JRF_model_003', 'type': 'NMR', 'rmsd': 2.944},
#  {'a': '1MM4_model_001', 'b': '1MM4_model_009', 'type': 'NMR', 'rmsd': 2.016},
#  {'a': '8AP5_model_013', 'b': '8AP5_model_011', 'type': 'NMR', 'rmsd': 3.972},
#  {'a': '7BWO_model_006', 'b': '7BWO_model_000', 'type': 'NMR', 'rmsd': 6.686},
#  {'a': '1X2Q_model_007', 'b': '1X2Q_model_015', 'type': 'NMR', 'rmsd': 5.866},
#  {'a': '6U1L_model_008', 'b': '6U1L_model_002', 'type': 'NMR', 'rmsd': 4.251},
#  {'a': '2LOV_model_005', 'b': '2LOV_model_034', 'type': 'NMR', 'rmsd': 8.167},
#  {'a': '2LSU_model_017', 'b': '2LSU_model_008', 'type': 'NMR', 'rmsd': 2.682},
#  {'a': '5KTF_model_009', 'b': '5KTF_model_003', 'type': 'NMR', 'rmsd': 4.836},
#  {'a': '2KZ8_model_018', 'b': '2KZ8_model_017', 'type': 'NMR', 'rmsd': 5.556},
#  {'a': '2DMP_model_018', 'b': '2DMP_model_005', 'type': 'NMR', 'rmsd': 2.581},
#  {'a': '2LF0_model_015', 'b': '2LF0_model_013', 'type': 'NMR', 'rmsd': 2.891},
#  {'a': '2N7L_model_007', 'b': '2N7L_model_001', 'type': 'NMR', 'rmsd': 2.648},
#  {'a': '2LUY_model_001', 'b': '2LUY_model_011', 'type': 'NMR', 'rmsd': 6.686},
#  {'a': '2FKX_model_007', 'b': '2FKX_model_017', 'type': 'NMR', 'rmsd': 6.071},
#  {'a': '2KCO_model_003', 'b': '2KCO_model_004', 'type': 'NMR', 'rmsd': 6.407},
#  {'a': '2LY1_model_016', 'b': '2LY1_model_015', 'type': 'NMR', 'rmsd': 9.651},
#  {'a': '1HD4_model_004', 'b': '1HD4_model_013', 'type': 'NMR', 'rmsd': 2.751},
#  {'a': '2DHX_model_017', 'b': '2DHX_model_011', 'type': 'NMR', 'rmsd': 8.547},
#  {'a': '5MS9_model_002', 'b': '5MS9_model_003', 'type': 'NMR', 'rmsd': 2.292},
#  {'a': '6U3S_model_007', 'b': '6U3S_model_009', 'type': 'NMR', 'rmsd': 2.265},
#  {'a': '2D9H_model_004', 'b': '2D9H_model_001', 'type': 'NMR', 'rmsd': 2.05},
#  {'a': '2KQU_model_008', 'b': '2KQU_model_014', 'type': 'NMR', 'rmsd': 2.309},
#  {'a': '2N6P_model_009', 'b': '2N6P_model_019', 'type': 'NMR', 'rmsd': 3.349},
#  {'a': '5ZUZ_model_016', 'b': '5ZUZ_model_000', 'type': 'NMR', 'rmsd': 2.451},
#  {'a': '2KLO_model_018', 'b': '2KLO_model_008', 'type': 'NMR', 'rmsd': 6.196},
#  {'a': '2ME9_model_009', 'b': '2ME9_model_001', 'type': 'NMR', 'rmsd': 4.081},
#  {'a': '2MPW_model_013', 'b': '2MPW_model_021', 'type': 'NMR', 'rmsd': 8.395},
#  {'a': '2LGP_model_013', 'b': '2LGP_model_018', 'type': 'NMR', 'rmsd': 9.901},
#  {'a': '2KPY_model_009', 'b': '2KPY_model_019', 'type': 'NMR', 'rmsd': 5.109},
#  {'a': '2F3J_model_013', 'b': '2F3J_model_008', 'type': 'NMR', 'rmsd': 8.287},
#  {'a': '1ORM_model_016', 'b': '1ORM_model_019', 'type': 'NMR', 'rmsd': 3.367},
#  {'a': '1COU_model_017', 'b': '1COU_model_008', 'type': 'NMR', 'rmsd': 3.018},
#  {'a': '6Z40_model_009', 'b': '6Z40_model_018', 'type': 'NMR', 'rmsd': 2.164},
#  {'a': '7D11_model_016', 'b': '7D11_model_019', 'type': 'NMR', 'rmsd': 10.528},
#  {'a': '5XJK_model_017', 'b': '5XJK_model_008', 'type': 'NMR', 'rmsd': 9.704},
#  {'a': '1RIP_model_003', 'b': '1RIP_model_001', 'type': 'NMR', 'rmsd': 2.242},
#  {'a': '2NA0_model_009', 'b': '2NA0_model_008', 'type': 'NMR', 'rmsd': 4.597},
#  {'a': '1WYS_model_019', 'b': '1WYS_model_004', 'type': 'NMR', 'rmsd': 4.327},
#  {'a': '2M3S_model_016', 'b': '2M3S_model_005', 'type': 'NMR', 'rmsd': 5.724},
#  {'a': '1WIB_model_002', 'b': '1WIB_model_009', 'type': 'NMR', 'rmsd': 2.104},
#  {'a': '2MTS_model_003', 'b': '2MTS_model_009', 'type': 'NMR', 'rmsd': 2.4},
#  {'a': '1TNW_model_000', 'b': '1TNW_model_003', 'type': 'NMR', 'rmsd': 7.974},
#  {'a': '4AR0_model_019', 'b': '4AR0_model_007', 'type': 'NMR', 'rmsd': 2.016},
#  {'a': '2KUD_model_021', 'b': '2KUD_model_013', 'type': 'NMR', 'rmsd': 2.378},
#  {'a': '2KLD_model_003', 'b': '2KLD_model_002', 'type': 'NMR', 'rmsd': 10.733},
#  {'a': '1WGS_model_002', 'b': '1WGS_model_005', 'type': 'NMR', 'rmsd': 11.528},
#  {'a': '1U3N_model_008', 'b': '1U3N_model_014', 'type': 'NMR', 'rmsd': 4.278},
#  {'a': '2YSJ_model_015', 'b': '2YSJ_model_011', 'type': 'NMR', 'rmsd': 3.446},
#  {'a': '2KRR_model_010', 'b': '2KRR_model_012', 'type': 'NMR', 'rmsd': 8.498},
#  {'a': '5MN3_model_018', 'b': '5MN3_model_003', 'type': 'NMR', 'rmsd': 2.919},
#  {'a': '2KVL_model_006', 'b': '2KVL_model_001', 'type': 'NMR', 'rmsd': 5.886},
#  {'a': '2KZ8_model_017', 'b': '2KZ8_model_009', 'type': 'NMR', 'rmsd': 5.026},
#  {'a': '5TP5_model_012', 'b': '5TP5_model_001', 'type': 'NMR', 'rmsd': 4.63},
#  {'a': '7KW9_model_001', 'b': '7KW9_model_012', 'type': 'NMR', 'rmsd': 4.994},
#  {'a': '1PM6_model_008', 'b': '1PM6_model_017', 'type': 'NMR', 'rmsd': 8.249},
#  {'a': '2KUD_model_023', 'b': '2KUD_model_025', 'type': 'NMR', 'rmsd': 2.889},
#  {'a': '5K6P_model_013', 'b': '5K6P_model_017', 'type': 'NMR', 'rmsd': 9.453},
#  {'a': '1VZS_model_031', 'b': '1VZS_model_013', 'type': 'NMR', 'rmsd': 4.194},
#  {'a': '1Q8K_model_003', 'b': '1Q8K_model_012', 'type': 'NMR', 'rmsd': 10.139},
#  {'a': '1TNW_model_000', 'b': '1TNW_model_015', 'type': 'NMR', 'rmsd': 11.431},
#  {'a': '2AQC_model_005', 'b': '2AQC_model_008', 'type': 'NMR', 'rmsd': 4.079},
#  {'a': '5IEC_model_009', 'b': '5IEC_model_003', 'type': 'NMR', 'rmsd': 3.373},
#  {'a': '2CTD_model_000', 'b': '2CTD_model_017', 'type': 'NMR', 'rmsd': 5.626},
#  {'a': '2CSH_model_011', 'b': '2CSH_model_015', 'type': 'NMR', 'rmsd': 4.919},
#  {'a': '5OQK_model_007', 'b': '5OQK_model_009', 'type': 'NMR', 'rmsd': 3.182},
#  {'a': '1WEY_model_001', 'b': '1WEY_model_002', 'type': 'NMR', 'rmsd': 3.721},
#  {'a': '2M0Q_model_007', 'b': '2M0Q_model_002', 'type': 'NMR', 'rmsd': 9.943},
#  {'a': '1Q9G_model_001', 'b': '1Q9G_model_015', 'type': 'NMR', 'rmsd': 2.329},
#  {'a': '8AP5_model_002', 'b': '8AP5_model_011', 'type': 'NMR', 'rmsd': 2.175},
#  {'a': '1U97_model_001', 'b': '1U97_model_009', 'type': 'NMR', 'rmsd': 7.37},
#  {'a': '1F5Y_model_012', 'b': '1F5Y_model_011', 'type': 'NMR', 'rmsd': 6.601},
#  {'a': '2CTF_model_019', 'b': '2CTF_model_014', 'type': 'NMR', 'rmsd': 5.153},
#  {'a': '4BIT_model_016', 'b': '4BIT_model_002', 'type': 'NMR', 'rmsd': 4.774},
#  {'a': '1U97_model_014', 'b': '1U97_model_009', 'type': 'NMR', 'rmsd': 2.867},
#  {'a': '2MA7_model_006', 'b': '2MA7_model_010', 'type': 'NMR', 'rmsd': 9.675},
#  {'a': '4AR0_model_018', 'b': '4AR0_model_010', 'type': 'NMR', 'rmsd': 3.866},
#  {'a': '9X72_model_002', 'b': '9X72_model_008', 'type': 'NMR', 'rmsd': 2.962},
#  {'a': '2EBT_model_007', 'b': '2EBT_model_005', 'type': 'NMR', 'rmsd': 6.888},
#  {'a': '2L9Y_model_013', 'b': '2L9Y_model_009', 'type': 'NMR', 'rmsd': 7.568},
#  {'a': '5B7X_model_007', 'b': '5B7X_model_018', 'type': 'NMR', 'rmsd': 7.363},
#  {'a': '2KCY_model_019', 'b': '2KCY_model_007', 'type': 'NMR', 'rmsd': 6.052},
#  {'a': '2MLH_model_009', 'b': '2MLH_model_013', 'type': 'NMR', 'rmsd': 5.137},
#  {'a': '2N6F_model_003', 'b': '2N6F_model_005', 'type': 'NMR', 'rmsd': 11.161},
#  {'a': '2DMD_model_006', 'b': '2DMD_model_014', 'type': 'NMR', 'rmsd': 9.431},
#  {'a': '1S6I_model_011', 'b': '1S6I_model_009', 'type': 'NMR', 'rmsd': 11.518},
#  {'a': '1TAC_model_009', 'b': '1TAC_model_003', 'type': 'NMR', 'rmsd': 2.593},
#  {'a': '6BQI_model_004', 'b': '6BQI_model_001', 'type': 'NMR', 'rmsd': 10.314},
#  {'a': '6TR0_model_006', 'b': '6TR0_model_001', 'type': 'NMR', 'rmsd': 8.225},
#  {'a': '2KQR_model_011', 'b': '2KQR_model_007', 'type': 'NMR', 'rmsd': 9.525},
#  {'a': '2KVL_model_009', 'b': '2KVL_model_001', 'type': 'NMR', 'rmsd': 3.007},
#  {'a': '2MI2_model_003', 'b': '2MI2_model_009', 'type': 'NMR', 'rmsd': 2.751},
#  {'a': '2MAZ_model_010', 'b': '2MAZ_model_018', 'type': 'NMR', 'rmsd': 2.028},
#  {'a': '2AIV_model_006', 'b': '2AIV_model_001', 'type': 'NMR', 'rmsd': 2.252},
#  {'a': '2MV9_model_002', 'b': '2MV9_model_014', 'type': 'NMR', 'rmsd': 11.249},
#  {'a': '8AP5_model_002', 'b': '8AP5_model_017', 'type': 'NMR', 'rmsd': 3.219},
#  {'a': '1T3K_model_012', 'b': '1T3K_model_005', 'type': 'NMR', 'rmsd': 2.016},
#  {'a': '7BWE_model_007', 'b': '7BWE_model_008', 'type': 'NMR', 'rmsd': 3.099},
#  {'a': '2M5Y_model_009', 'b': '2M5Y_model_015', 'type': 'NMR', 'rmsd': 4.296},
#  {'a': '2N45_model_019', 'b': '2N45_model_004', 'type': 'NMR', 'rmsd': 2.505},
#  {'a': '1U3N_model_019', 'b': '1U3N_model_025', 'type': 'NMR', 'rmsd': 4.304},
#  {'a': '7KW9_model_003', 'b': '7KW9_model_011', 'type': 'NMR', 'rmsd': 10.771},
#  {'a': '1QRJ_model_004', 'b': '1QRJ_model_003', 'type': 'NMR', 'rmsd': 8.581},
#  {'a': '2L7P_model_013', 'b': '2L7P_model_000', 'type': 'NMR', 'rmsd': 5.721},
#  {'a': '1F5Y_model_016', 'b': '1F5Y_model_002', 'type': 'NMR', 'rmsd': 3.835},
#  {'a': '2RM4_model_011', 'b': '2RM4_model_015', 'type': 'NMR', 'rmsd': 2.994},
#  {'a': '6RWG_model_000', 'b': '6RWG_model_008', 'type': 'NMR', 'rmsd': 10.0},
#  {'a': '6P6B_model_001', 'b': '6P6B_model_007', 'type': 'NMR', 'rmsd': 3.117},
#  {'a': '2N11_model_003', 'b': '2N11_model_010', 'type': 'NMR', 'rmsd': 5.868},
#  {'a': '2JNE_model_007', 'b': '2JNE_model_019', 'type': 'NMR', 'rmsd': 2.011},
#  {'a': '2K3P_model_002', 'b': '2K3P_model_001', 'type': 'NMR', 'rmsd': 2.632},
#  {'a': '2RNB_model_018', 'b': '2RNB_model_000', 'type': 'NMR', 'rmsd': 5.596},
#  {'a': '2M4G_model_003', 'b': '2M4G_model_019', 'type': 'NMR', 'rmsd': 8.43},
#  {'a': '1QO6_model_034', 'b': '1QO6_model_024', 'type': 'NMR', 'rmsd': 3.065},
#  {'a': '2JVL_model_007', 'b': '2JVL_model_004', 'type': 'NMR', 'rmsd': 8.31},
#  {'a': '2RSJ_model_004', 'b': '2RSJ_model_014', 'type': 'NMR', 'rmsd': 8.889},
#  {'a': '7P3P_model_003', 'b': '7P3P_model_001', 'type': 'NMR', 'rmsd': 5.327},
#  {'a': '2J4N_model_000', 'b': '2J4N_model_004', 'type': 'NMR', 'rmsd': 2.362},
#  {'a': '1TNW_model_007', 'b': '1TNW_model_015', 'type': 'NMR', 'rmsd': 8.329},
#  {'a': '6EHZ_model_004', 'b': '6EHZ_model_000', 'type': 'NMR', 'rmsd': 4.246},
#  {'a': '2KZ0_model_018', 'b': '2KZ0_model_005', 'type': 'NMR', 'rmsd': 2.05},
#  {'a': '1CFC_model_013', 'b': '1CFC_model_015', 'type': 'NMR', 'rmsd': 5.228},
#  {'a': '8SHM_model_011', 'b': '8SHM_model_005', 'type': 'NMR', 'rmsd': 3.468},
#  {'a': '2M8N_model_042', 'b': '2M8N_model_052', 'type': 'NMR', 'rmsd': 4.63},
#  {'a': '5NR5_model_014', 'b': '5NR5_model_028', 'type': 'NMR', 'rmsd': 4.972},
#  {'a': '2N1I_model_001', 'b': '2N1I_model_000', 'type': 'NMR', 'rmsd': 2.617},
#  {'a': '2J4M_model_002', 'b': '2J4M_model_001', 'type': 'NMR', 'rmsd': 4.149},
#  {'a': '8FA3_model_012', 'b': '8FA3_model_019', 'type': 'NMR', 'rmsd': 8.16},
#  {'a': '2KVL_model_006', 'b': '2KVL_model_003', 'type': 'NMR', 'rmsd': 2.694},
#  {'a': '8X3O_model_003', 'b': '8X3O_model_005', 'type': 'NMR', 'rmsd': 10.216},
#  {'a': '2M5Y_model_015', 'b': '2M5Y_model_011', 'type': 'NMR', 'rmsd': 4.753},
#  {'a': '1IDL_model_019', 'b': '1IDL_model_006', 'type': 'NMR', 'rmsd': 2.637},
#  {'a': '2KO6_model_018', 'b': '2KO6_model_017', 'type': 'NMR', 'rmsd': 5.3},
#  {'a': '1YGM_model_005', 'b': '1YGM_model_003', 'type': 'NMR', 'rmsd': 2.203},
#  {'a': '7VZM_model_012', 'b': '7VZM_model_014', 'type': 'NMR', 'rmsd': 5.914},
#  {'a': '6I9B_model_013', 'b': '6I9B_model_001', 'type': 'NMR', 'rmsd': 9.399},
#  {'a': '2DLK_model_009', 'b': '2DLK_model_011', 'type': 'NMR', 'rmsd': 4.175},
#  {'a': '2LQL_model_009', 'b': '2LQL_model_015', 'type': 'NMR', 'rmsd': 9.772},
#  {'a': '9CJX_model_004', 'b': '9CJX_model_003', 'type': 'NMR', 'rmsd': 2.607},
#  {'a': '6P6C_model_006', 'b': '6P6C_model_002', 'type': 'NMR', 'rmsd': 7.248},
#  {'a': '1AJ3_model_017', 'b': '1AJ3_model_006', 'type': 'NMR', 'rmsd': 2.056},
#  {'a': '2ME9_model_009', 'b': '2ME9_model_005', 'type': 'NMR', 'rmsd': 2.686},
#  {'a': '1NEE_model_001', 'b': '1NEE_model_000', 'type': 'NMR', 'rmsd': 10.073},
#  {'a': '1RKJ_model_004', 'b': '1RKJ_model_013', 'type': 'NMR', 'rmsd': 2.525},
#  {'a': '1VD4_model_005', 'b': '1VD4_model_010', 'type': 'NMR', 'rmsd': 4.188},
#  {'a': '9UJO_model_000', 'b': '9UJO_model_014', 'type': 'NMR', 'rmsd': 2.462},
#  {'a': '8GQO_model_001', 'b': '8GQO_model_004', 'type': 'NMR', 'rmsd': 6.171},
#  {'a': '9CJX_model_001', 'b': '9CJX_model_000', 'type': 'NMR', 'rmsd': 2.564},
#  {'a': '8OIL_model_009', 'b': '8OIL_model_005', 'type': 'NMR', 'rmsd': 6.221},
#  {'a': '9X72_model_002', 'b': '9X72_model_003', 'type': 'NMR', 'rmsd': 2.42},
#  {'a': '1GKN_model_003', 'b': '1GKN_model_020', 'type': 'NMR', 'rmsd': 2.107},
#  {'a': '2KLD_model_003', 'b': '2KLD_model_009', 'type': 'NMR', 'rmsd': 2.265},
#  {'a': '2YUO_model_000', 'b': '2YUO_model_017', 'type': 'NMR', 'rmsd': 2.386},
#  {'a': '5NR6_model_000', 'b': '5NR6_model_024', 'type': 'NMR', 'rmsd': 7.765},
#  {'a': '2MII_model_018', 'b': '2MII_model_013', 'type': 'NMR', 'rmsd': 6.584},
#  {'a': '2M4V_model_003', 'b': '2M4V_model_016', 'type': 'NMR', 'rmsd': 7.286},
#  {'a': '2KN6_model_011', 'b': '2KN6_model_001', 'type': 'NMR', 'rmsd': 5.659},
#  {'a': '2CKU_model_007', 'b': '2CKU_model_012', 'type': 'NMR', 'rmsd': 3.814},
#  {'a': '2DLP_model_002', 'b': '2DLP_model_007', 'type': 'NMR', 'rmsd': 3.15},
#  {'a': '1QGB_model_014', 'b': '1QGB_model_017', 'type': 'NMR', 'rmsd': 3.64},
#  {'a': '1E88_model_012', 'b': '1E88_model_010', 'type': 'NMR', 'rmsd': 3.259},
#  {'a': '2MXW_model_007', 'b': '2MXW_model_018', 'type': 'NMR', 'rmsd': 9.251},
#  {'a': '2KZ8_model_013', 'b': '2KZ8_model_018', 'type': 'NMR', 'rmsd': 6.234},
#  {'a': '6TWE_model_004', 'b': '6TWE_model_003', 'type': 'NMR', 'rmsd': 2.564},
#  {'a': '5T7C_model_009', 'b': '5T7C_model_004', 'type': 'NMR', 'rmsd': 2.081},
#  {'a': '2L26_model_007', 'b': '2L26_model_006', 'type': 'NMR', 'rmsd': 3.558},
#  {'a': '1TTE_model_017', 'b': '1TTE_model_001', 'type': 'NMR', 'rmsd': 2.563},
#  {'a': '2D8Q_model_009', 'b': '2D8Q_model_018', 'type': 'NMR', 'rmsd': 2.318},
#  {'a': '1WJI_model_008', 'b': '1WJI_model_003', 'type': 'NMR', 'rmsd': 2.922},
#  {'a': '2MSY_model_006', 'b': '2MSY_model_013', 'type': 'NMR', 'rmsd': 7.404},
#  {'a': '2RQY_model_009', 'b': '2RQY_model_003', 'type': 'NMR', 'rmsd': 6.024},
#  {'a': '1WFL_model_012', 'b': '1WFL_model_002', 'type': 'NMR', 'rmsd': 6.881},
#  {'a': '4AR0_model_015', 'b': '4AR0_model_010', 'type': 'NMR', 'rmsd': 2.035},
#  {'a': '2KKV_model_010', 'b': '2KKV_model_013', 'type': 'NMR', 'rmsd': 2.004},
#  {'a': '2KPY_model_009', 'b': '2KPY_model_013', 'type': 'NMR', 'rmsd': 7.82},
#  {'a': '1WFL_model_006', 'b': '1WFL_model_017', 'type': 'NMR', 'rmsd': 5.003},
#  {'a': '1HHN_model_017', 'b': '1HHN_model_012', 'type': 'NMR', 'rmsd': 3.244},
#  {'a': '1IRP_model_004', 'b': '1IRP_model_001', 'type': 'NMR', 'rmsd': 2.403},
#  {'a': '1UMQ_model_004', 'b': '1UMQ_model_003', 'type': 'NMR', 'rmsd': 7.808},
#  {'a': '7NF9_model_010', 'b': '7NF9_model_006', 'type': 'NMR', 'rmsd': 7.144},
#  {'a': '2K2X_model_004', 'b': '2K2X_model_002', 'type': 'NMR', 'rmsd': 7.28},
#  {'a': '2KVD_model_006', 'b': '2KVD_model_008', 'type': 'NMR', 'rmsd': 9.378},
#  {'a': '2N8Z_model_009', 'b': '2N8Z_model_005', 'type': 'NMR', 'rmsd': 6.959},
#  {'a': '2HZD_model_001', 'b': '2HZD_model_020', 'type': 'NMR', 'rmsd': 2.031},
#  {'a': '1KN7_model_005', 'b': '1KN7_model_013', 'type': 'NMR', 'rmsd': 6.481},
#  {'a': '1U3N_model_024', 'b': '1U3N_model_014', 'type': 'NMR', 'rmsd': 3.96},
#  {'a': '6CJD_model_010', 'b': '6CJD_model_011', 'type': 'NMR', 'rmsd': 9.835},
#  {'a': '7C36_model_011', 'b': '7C36_model_015', 'type': 'NMR', 'rmsd': 10.082},
#  {'a': '6RWG_model_009', 'b': '6RWG_model_000', 'type': 'NMR', 'rmsd': 11.9},
#  {'a': '2EE8_model_006', 'b': '2EE8_model_018', 'type': 'NMR', 'rmsd': 11.733},
#  {'a': '7TUJ_model_016', 'b': '7TUJ_model_005', 'type': 'NMR', 'rmsd': 7.856},
#  {'a': '2CQY_model_019', 'b': '2CQY_model_002', 'type': 'NMR', 'rmsd': 3.891},
#  {'a': '8GQO_model_002', 'b': '8GQO_model_000', 'type': 'NMR', 'rmsd': 8.804},
#  {'a': '1U3N_model_025', 'b': '1U3N_model_024', 'type': 'NMR', 'rmsd': 3.783},
# ...
#  {'a': '2NCA_model_011', 'b': '2NCA_model_013', 'type': 'NMR', 'rmsd': 3.964},
#  {'a': '2ROQ_model_011', 'b': '2ROQ_model_012', 'type': 'NMR', 'rmsd': 2.029},
#  {'a': '1WGF_model_002', 'b': '1WGF_model_003', 'type': 'NMR', 'rmsd': 4.769},
#  {'a': '2EPA_model_011', 'b': '2EPA_model_009', 'type': 'NMR', 'rmsd': 11.89},
#  {'a': '8JRA_model_004', 'b': '8JRA_model_003', 'type': 'NMR', 'rmsd': 2.17},
#  {'a': '2MR3_model_010', 'b': '2MR3_model_009', 'type': 'NMR', 'rmsd': 4.176},
#  {'a': '2CQY_model_016', 'b': '2CQY_model_008', 'type': 'NMR', 'rmsd': 9.482},
#  {'a': '1WFE_model_005', 'b': '1WFE_model_019', 'type': 'NMR', 'rmsd': 4.915},
#  {'a': '9M2D_model_045', 'b': '9M2D_model_058', 'type': 'NMR', 'rmsd': 10.585},
#  {'a': '1GE9_model_011', 'b': '1GE9_model_012', 'type': 'NMR', 'rmsd': 2.38},
#  {'a': '2MT3_model_001', 'b': '2MT3_model_000', 'type': 'NMR', 'rmsd': 3.444},
#  {'a': '2KUI_model_024', 'b': '2KUI_model_004', 'type': 'NMR', 'rmsd': 11.906},
#  {'a': '2ME8_model_011', 'b': '2ME8_model_017', 'type': 'NMR', 'rmsd': 5.014},
#  {'a': '2N1I_model_001', 'b': '2N1I_model_016', 'type': 'NMR', 'rmsd': 3.853},
#  {'a': '2LYS_model_002', 'b': '2LYS_model_004', 'type': 'NMR', 'rmsd': 2.787},
#  {'a': '6TAZ_model_016', 'b': '6TAZ_model_012', 'type': 'NMR', 'rmsd': 5.697},
#  {'a': '2KO6_model_005', 'b': '2KO6_model_011', 'type': 'NMR', 'rmsd': 10.75},
#  {'a': '1S7E_model_004', 'b': '1S7E_model_016', 'type': 'NMR', 'rmsd': 6.317},
#  {'a': '1Z8S_model_008', 'b': '1Z8S_model_003', 'type': 'NMR', 'rmsd': 2.381},
#  {'a': '2ADZ_model_004', 'b': '2ADZ_model_017', 'type': 'NMR', 'rmsd': 2.539},
#  {'a': '2KLF_model_009', 'b': '2KLF_model_004', 'type': 'NMR', 'rmsd': 2.015},
#  {'a': '6P6C_model_006', 'b': '6P6C_model_007', 'type': 'NMR', 'rmsd': 2.383},
#  {'a': '1VND_model_026', 'b': '1VND_model_010', 'type': 'NMR', 'rmsd': 2.739},
#  {'a': '7P3P_model_001', 'b': '7P3P_model_002', 'type': 'NMR', 'rmsd': 5.451},
#  {'a': '2RQR_model_011', 'b': '2RQR_model_006', 'type': 'NMR', 'rmsd': 2.612},
#  {'a': '2MHL_model_014', 'b': '2MHL_model_008', 'type': 'NMR', 'rmsd': 2.496},
#  {'a': '1K9C_model_005', 'b': '1K9C_model_001', 'type': 'NMR', 'rmsd': 3.337},
#  {'a': '6Z40_model_016', 'b': '6Z40_model_015', 'type': 'NMR', 'rmsd': 2.212},
#  {'a': '5VWL_model_008', 'b': '5VWL_model_000', 'type': 'NMR', 'rmsd': 3.763},
#  {'a': '6U3S_model_004', 'b': '6U3S_model_001', 'type': 'NMR', 'rmsd': 8.425},
#  {'a': '1XU6_model_051', 'b': '1XU6_model_006', 'type': 'NMR', 'rmsd': 4.181},
#  {'a': '1LKJ_model_009', 'b': '1LKJ_model_015', 'type': 'NMR', 'rmsd': 7.186},
#  {'a': '1E9J_model_024', 'b': '1E9J_model_023', 'type': 'NMR', 'rmsd': 6.697},
#  {'a': '2LQ3_model_009', 'b': '2LQ3_model_002', 'type': 'NMR', 'rmsd': 3.953},
#  {'a': '2LUT_model_006', 'b': '2LUT_model_009', 'type': 'NMR', 'rmsd': 9.041},
#  {'a': '2PXG_model_014', 'b': '2PXG_model_000', 'type': 'NMR', 'rmsd': 6.208},
#  {'a': '2ME8_model_008', 'b': '2ME8_model_011', 'type': 'NMR', 'rmsd': 2.685},
#  {'a': '2M1U_model_017', 'b': '2M1U_model_013', 'type': 'NMR', 'rmsd': 3.277},
#  {'a': '2COT_model_010', 'b': '2COT_model_008', 'type': 'NMR', 'rmsd': 6.18},
#  {'a': '2FKX_model_007', 'b': '2FKX_model_014', 'type': 'NMR', 'rmsd': 4.029},
#  {'a': '6HJ7_model_014', 'b': '6HJ7_model_012', 'type': 'NMR', 'rmsd': 2.331},
#  {'a': '3LRI_model_003', 'b': '3LRI_model_001', 'type': 'NMR', 'rmsd': 3.576},
#  {'a': '1WPK_model_016', 'b': '1WPK_model_012', 'type': 'NMR', 'rmsd': 11.026},
#  {'a': '1U3N_model_010', 'b': '1U3N_model_025', 'type': 'NMR', 'rmsd': 2.776},
#  {'a': '2KGO_model_017', 'b': '2KGO_model_000', 'type': 'NMR', 'rmsd': 4.192},
#  {'a': '7SUQ_model_018', 'b': '7SUQ_model_010', 'type': 'NMR', 'rmsd': 5.342},
#  {'a': '2GQJ_model_013', 'b': '2GQJ_model_003', 'type': 'NMR', 'rmsd': 6.265},
#  {'a': '1TXB_model_001', 'b': '1TXB_model_004', 'type': 'NMR', 'rmsd': 2.86},
#  {'a': '8PXW_model_000', 'b': '8PXW_model_004', 'type': 'NMR', 'rmsd': 2.563},
#  {'a': '2L7P_model_005', 'b': '2L7P_model_002', 'type': 'NMR', 'rmsd': 2.372},
#  {'a': '6RSS_model_001', 'b': '6RSS_model_016', 'type': 'NMR', 'rmsd': 10.045},
#  {'a': '1TVT_model_004', 'b': '1TVT_model_000', 'type': 'NMR', 'rmsd': 6.002},
#  {'a': '1UG2_model_019', 'b': '1UG2_model_016', 'type': 'NMR', 'rmsd': 2.78},
#  {'a': '2CS8_model_017', 'b': '2CS8_model_006', 'type': 'NMR', 'rmsd': 8.385},
#  {'a': '2MK4_model_011', 'b': '2MK4_model_007', 'type': 'NMR', 'rmsd': 2.584},
#  {'a': '2L9N_model_013', 'b': '2L9N_model_017', 'type': 'NMR', 'rmsd': 3.998},
#  {'a': '2KOY_model_018', 'b': '2KOY_model_000', 'type': 'NMR', 'rmsd': 2.051},
#  {'a': '7BWO_model_000', 'b': '7BWO_model_005', 'type': 'NMR', 'rmsd': 9.83},
#  {'a': '2K6B_model_009', 'b': '2K6B_model_000', 'type': 'NMR', 'rmsd': 7.648},
#  {'a': '2M5Y_model_002', 'b': '2M5Y_model_008', 'type': 'NMR', 'rmsd': 5.184},
#  {'a': '1X64_model_007', 'b': '1X64_model_015', 'type': 'NMR', 'rmsd': 7.146},
#  {'a': '2M9A_model_000', 'b': '2M9A_model_009', 'type': 'NMR', 'rmsd': 3.283},
#  {'a': '2KZW_model_003', 'b': '2KZW_model_012', 'type': 'NMR', 'rmsd': 9.673},
#  {'a': '2KQ8_model_018', 'b': '2KQ8_model_017', 'type': 'NMR', 'rmsd': 3.215},
#  {'a': '2CTO_model_001', 'b': '2CTO_model_011', 'type': 'NMR', 'rmsd': 2.777},
#  {'a': '2LEJ_model_017', 'b': '2LEJ_model_009', 'type': 'NMR', 'rmsd': 2.348},
#  {'a': '2MKV_model_005', 'b': '2MKV_model_001', 'type': 'NMR', 'rmsd': 6.056},
#  {'a': '6NFW_model_008', 'b': '6NFW_model_001', 'type': 'NMR', 'rmsd': 4.628},
#  {'a': '8TB1_model_005', 'b': '8TB1_model_007', 'type': 'NMR', 'rmsd': 2.014},
#  {'a': '1WYS_model_004', 'b': '1WYS_model_012', 'type': 'NMR', 'rmsd': 4.02},
#  {'a': '2HLW_model_013', 'b': '2HLW_model_001', 'type': 'NMR', 'rmsd': 7.899},
#  {'a': '2F3J_model_010', 'b': '2F3J_model_006', 'type': 'NMR', 'rmsd': 7.889},
#  {'a': '8PUI_model_000', 'b': '8PUI_model_018', 'type': 'NMR', 'rmsd': 9.564},
#  {'a': '2LZN_model_001', 'b': '2LZN_model_011', 'type': 'NMR', 'rmsd': 2.645},
#  {'a': '2MIQ_model_015', 'b': '2MIQ_model_002', 'type': 'NMR', 'rmsd': 9.197},
#  {'a': '2K4T_model_009', 'b': '2K4T_model_004', 'type': 'NMR', 'rmsd': 3.3},
#  {'a': '5Y08_model_014', 'b': '5Y08_model_012', 'type': 'NMR', 'rmsd': 10.433},
#  {'a': '2CTD_model_017', 'b': '2CTD_model_001', 'type': 'NMR', 'rmsd': 6.663},
#  {'a': '2LZN_model_004', 'b': '2LZN_model_019', 'type': 'NMR', 'rmsd': 3.172},
#  {'a': '2KXI_model_009', 'b': '2KXI_model_005', 'type': 'NMR', 'rmsd': 2.018},
#  {'a': '2AQC_model_014', 'b': '2AQC_model_019', 'type': 'NMR', 'rmsd': 9.854},
#  {'a': '5XJK_model_018', 'b': '5XJK_model_008', 'type': 'NMR', 'rmsd': 11.488},
#  {'a': '1WYS_model_017', 'b': '1WYS_model_008', 'type': 'NMR', 'rmsd': 2.87},
#  {'a': '2ECB_model_009', 'b': '2ECB_model_005', 'type': 'NMR', 'rmsd': 2.223},
#  {'a': '8OZZ_model_009', 'b': '8OZZ_model_006', 'type': 'NMR', 'rmsd': 2.105},
#  {'a': '2MYX_model_004', 'b': '2MYX_model_009', 'type': 'NMR', 'rmsd': 4.032},
#  {'a': '6UCK_model_000', 'b': '6UCK_model_012', 'type': 'NMR', 'rmsd': 2.485},
#  {'a': '1DQB_model_004', 'b': '1DQB_model_002', 'type': 'NMR', 'rmsd': 5.377},
#  {'a': '1TBC_model_009', 'b': '1TBC_model_007', 'type': 'NMR', 'rmsd': 2.153},
#  {'a': '2ADR_model_009', 'b': '2ADR_model_008', 'type': 'NMR', 'rmsd': 3.983},
#  {'a': '1JFJ_model_008', 'b': '1JFJ_model_011', 'type': 'NMR', 'rmsd': 5.644},
#  {'a': '1J8I_model_012', 'b': '1J8I_model_013', 'type': 'NMR', 'rmsd': 8.966},
#  {'a': '2JVM_model_005', 'b': '2JVM_model_010', 'type': 'NMR', 'rmsd': 6.121},
#  {'a': '1HHN_model_013', 'b': '1HHN_model_012', 'type': 'NMR', 'rmsd': 5.729},
#  {'a': '2RN9_model_014', 'b': '2RN9_model_012', 'type': 'NMR', 'rmsd': 6.053},
#  {'a': '2DHX_model_017', 'b': '2DHX_model_000', 'type': 'NMR', 'rmsd': 8.849},
#  {'a': '2ADR_model_005', 'b': '2ADR_model_018', 'type': 'NMR', 'rmsd': 7.743},
#  {'a': '5KES_model_013', 'b': '5KES_model_007', 'type': 'NMR', 'rmsd': 10.957},
#  {'a': '3ZBE_model_026', 'b': '3ZBE_model_033', 'type': 'NMR', 'rmsd': 10.215},
#  {'a': '5VWL_model_015', 'b': '5VWL_model_018', 'type': 'NMR', 'rmsd': 3.502},
#  {'a': '1BLQ_model_018', 'b': '1BLQ_model_026', 'type': 'NMR', 'rmsd': 2.342},
#  {'a': '2RSI_model_005', 'b': '2RSI_model_016', 'type': 'NMR', 'rmsd': 4.756},
#  {'a': '1COU_model_017', 'b': '1COU_model_005', 'type': 'NMR', 'rmsd': 2.738},
#  {'a': '2RVH_model_000', 'b': '2RVH_model_010', 'type': 'NMR', 'rmsd': 2.624},
#  {'a': '2K5H_model_014', 'b': '2K5H_model_007', 'type': 'NMR', 'rmsd': 5.628},
#  {'a': '2DMI_model_007', 'b': '2DMI_model_008', 'type': 'NMR', 'rmsd': 10.844},
#  {'a': '1Z9B_model_013', 'b': '1Z9B_model_002', 'type': 'NMR', 'rmsd': 2.732},
#  {'a': '1J2O_model_014', 'b': '1J2O_model_013', 'type': 'NMR', 'rmsd': 3.405},
#  {'a': '9QPF_model_019', 'b': '9QPF_model_015', 'type': 'NMR', 'rmsd': 2.584},
#  {'a': '2LOW_model_023', 'b': '2LOW_model_013', 'type': 'NMR', 'rmsd': 2.148},
#  {'a': '1NYN_model_003', 'b': '1NYN_model_011', 'type': 'NMR', 'rmsd': 7.154},
#  {'a': '6ACV_model_013', 'b': '6ACV_model_003', 'type': 'NMR', 'rmsd': 3.39},
#  {'a': '2RN9_model_002', 'b': '2RN9_model_018', 'type': 'NMR', 'rmsd': 6.394},
#  {'a': '8JPY_model_015', 'b': '8JPY_model_017', 'type': 'NMR', 'rmsd': 10.511},
#  {'a': '1PCP_model_015', 'b': '1PCP_model_003', 'type': 'NMR', 'rmsd': 2.513},
#  {'a': '1E5G_model_035', 'b': '1E5G_model_021', 'type': 'NMR', 'rmsd': 2.066},
#  {'a': '2MK5_model_014', 'b': '2MK5_model_003', 'type': 'NMR', 'rmsd': 10.422},
#  {'a': '2JYU_model_009', 'b': '2JYU_model_004', 'type': 'NMR', 'rmsd': 4.382},
#  {'a': '7TXX_model_000', 'b': '7TXX_model_011', 'type': 'NMR', 'rmsd': 9.166},
#  {'a': '6U3R_model_002', 'b': '6U3R_model_007', 'type': 'NMR', 'rmsd': 10.059},
#  {'a': '1UFF_model_004', 'b': '1UFF_model_003', 'type': 'NMR', 'rmsd': 11.716},
#  {'a': '2K0S_model_001', 'b': '2K0S_model_004', 'type': 'NMR', 'rmsd': 2.309},
#  {'a': '5MS9_model_007', 'b': '5MS9_model_008', 'type': 'NMR', 'rmsd': 2.303},
#  {'a': '1TVT_model_003', 'b': '1TVT_model_005', 'type': 'NMR', 'rmsd': 8.639},
#  {'a': '1DZ7_model_011', 'b': '1DZ7_model_025', 'type': 'NMR', 'rmsd': 2.404},
#  {'a': '7TXX_model_015', 'b': '7TXX_model_018', 'type': 'NMR', 'rmsd': 2.175},
#  {'a': '2M5I_model_012', 'b': '2M5I_model_008', 'type': 'NMR', 'rmsd': 4.786},
#  {'a': '7D8K_model_008', 'b': '7D8K_model_014', 'type': 'NMR', 'rmsd': 2.139},
#  {'a': '2O3D_model_006', 'b': '2O3D_model_018', 'type': 'NMR', 'rmsd': 2.926},
#  {'a': '1EZP_model_005', 'b': '1EZP_model_004', 'type': 'NMR', 'rmsd': 2.215},
#  {'a': '1I16_model_017', 'b': '1I16_model_010', 'type': 'NMR', 'rmsd': 11.416},
#  {'a': '8I26_model_007', 'b': '8I26_model_015', 'type': 'NMR', 'rmsd': 6.302},
#  {'a': '2M1S_model_009', 'b': '2M1S_model_001', 'type': 'NMR', 'rmsd': 7.709},
#  {'a': '1WHX_model_002', 'b': '1WHX_model_006', 'type': 'NMR', 'rmsd': 2.261},
#  {'a': '6GRV_model_011', 'b': '6GRV_model_003', 'type': 'NMR', 'rmsd': 6.061},
#  {'a': '2JQV_model_018', 'b': '2JQV_model_008', 'type': 'NMR', 'rmsd': 2.506},
#  {'a': '1COU_model_005', 'b': '1COU_model_012', 'type': 'NMR', 'rmsd': 2.918},
#  {'a': '1ZR9_model_011', 'b': '1ZR9_model_003', 'type': 'NMR', 'rmsd': 11.147},
#  {'a': '2E6R_model_003', 'b': '2E6R_model_018', 'type': 'NMR', 'rmsd': 2.35},
#  {'a': '7TXX_model_015', 'b': '7TXX_model_017', 'type': 'NMR', 'rmsd': 2.468},
#  {'a': '2M8N_model_027', 'b': '2M8N_model_076', 'type': 'NMR', 'rmsd': 7.695},
#  {'a': '1Q8K_model_000', 'b': '1Q8K_model_013', 'type': 'NMR', 'rmsd': 5.548},
#  {'a': '2JNF_model_009', 'b': '2JNF_model_000', 'type': 'NMR', 'rmsd': 10.534},
#  {'a': '2RVM_model_017', 'b': '2RVM_model_008', 'type': 'NMR', 'rmsd': 5.516},
#  {'a': '2YSQ_model_012', 'b': '2YSQ_model_009', 'type': 'NMR', 'rmsd': 3.6},
#  {'a': '1X6F_model_003', 'b': '1X6F_model_018', 'type': 'NMR', 'rmsd': 9.66},
#  {'a': '2RN7_model_004', 'b': '2RN7_model_000', 'type': 'NMR', 'rmsd': 9.966},
#  {'a': '1EFE_model_015', 'b': '1EFE_model_005', 'type': 'NMR', 'rmsd': 2.469},
#  {'a': '1MUX_model_017', 'b': '1MUX_model_014', 'type': 'NMR', 'rmsd': 10.357},
#  {'a': '2JT0_model_009', 'b': '2JT0_model_004', 'type': 'NMR', 'rmsd': 10.385},
#  {'a': '2N42_model_005', 'b': '2N42_model_010', 'type': 'NMR', 'rmsd': 2.401},
#  {'a': '1GGW_model_011', 'b': '1GGW_model_024', 'type': 'NMR', 'rmsd': 7.999},
#  {'a': '1X59_model_015', 'b': '1X59_model_002', 'type': 'NMR', 'rmsd': 5.588},
#  {'a': '7KW9_model_008', 'b': '7KW9_model_001', 'type': 'NMR', 'rmsd': 10.226},
#  {'a': '2HJQ_model_001', 'b': '2HJQ_model_003', 'type': 'NMR', 'rmsd': 7.75},
#  {'a': '2KZY_model_017', 'b': '2KZY_model_010', 'type': 'NMR', 'rmsd': 3.625},
#  {'a': '2MLH_model_012', 'b': '2MLH_model_009', 'type': 'NMR', 'rmsd': 4.723},
#  {'a': '2JMM_model_003', 'b': '2JMM_model_005', 'type': 'NMR', 'rmsd': 2.567},
#  {'a': '2LM0_model_006', 'b': '2LM0_model_004', 'type': 'NMR', 'rmsd': 2.661},
#  {'a': '4V10_model_010', 'b': '4V10_model_000', 'type': 'NMR', 'rmsd': 6.111},
#  {'a': '6H0I_model_015', 'b': '6H0I_model_004', 'type': 'NMR', 'rmsd': 7.597},
#  {'a': '2LOO_model_010', 'b': '2LOO_model_018', 'type': 'NMR', 'rmsd': 4.399},
#  {'a': '8OIL_model_009', 'b': '8OIL_model_001', 'type': 'NMR', 'rmsd': 9.48},
#  {'a': '1WIV_model_013', 'b': '1WIV_model_018', 'type': 'NMR', 'rmsd': 2.695},
#  {'a': '1VNA_model_011', 'b': '1VNA_model_003', 'type': 'NMR', 'rmsd': 2.17},
#  {'a': '2RN7_model_004', 'b': '2RN7_model_015', 'type': 'NMR', 'rmsd': 11.599},
#  {'a': '2MIQ_model_015', 'b': '2MIQ_model_009', 'type': 'NMR', 'rmsd': 10.642},
#  {'a': '1NWV_model_011', 'b': '1NWV_model_016', 'type': 'NMR', 'rmsd': 2.341},
#  {'a': '2MW5_model_002', 'b': '2MW5_model_008', 'type': 'NMR', 'rmsd': 2.221},
#  {'a': '2M5Y_model_002', 'b': '2M5Y_model_011', 'type': 'NMR', 'rmsd': 5.691},
#  {'a': '2KUI_model_009', 'b': '2KUI_model_004', 'type': 'NMR', 'rmsd': 11.736},
#  {'a': '2KZ3_model_006', 'b': '2KZ3_model_013', 'type': 'NMR', 'rmsd': 7.017},
#  {'a': '2ECB_model_019', 'b': '2ECB_model_018', 'type': 'NMR', 'rmsd': 3.403},
#  {'a': '2MI2_model_010', 'b': '2MI2_model_003', 'type': 'NMR', 'rmsd': 3.472},
#  {'a': '8ALQ_model_000', 'b': '8ALQ_model_005', 'type': 'NMR', 'rmsd': 2.219},
#  {'a': '1QO6_model_034', 'b': '1QO6_model_050', 'type': 'NMR', 'rmsd': 2.01},
#  {'a': '1Q9G_model_001', 'b': '1Q9G_model_003', 'type': 'NMR', 'rmsd': 2.08},
#  {'a': '2K5H_model_002', 'b': '2K5H_model_000', 'type': 'NMR', 'rmsd': 4.485},
#  {'a': '2N1I_model_008', 'b': '2N1I_model_006', 'type': 'NMR', 'rmsd': 5.046},
#  {'a': '5KES_model_007', 'b': '5KES_model_006', 'type': 'NMR', 'rmsd': 10.441},
#  {'a': '2LQ3_model_004', 'b': '2LQ3_model_009', 'type': 'NMR', 'rmsd': 2.658},
#  {'a': '2KZY_model_007', 'b': '2KZY_model_000', 'type': 'NMR', 'rmsd': 3.105},
#  {'a': '2JOR_model_018', 'b': '2JOR_model_006', 'type': 'NMR', 'rmsd': 4.139},
#  {'a': '9FLG_model_006', 'b': '9FLG_model_004', 'type': 'NMR', 'rmsd': 5.053},
#  {'a': '1HN6_model_012', 'b': '1HN6_model_014', 'type': 'NMR', 'rmsd': 6.89},
#  {'a': '2FFW_model_003', 'b': '2FFW_model_000', 'type': 'NMR', 'rmsd': 11.15},
#  {'a': '1ZTR_model_001', 'b': '1ZTR_model_003', 'type': 'NMR', 'rmsd': 3.604},
#  {'a': '1YWL_model_004', 'b': '1YWL_model_002', 'type': 'NMR', 'rmsd': 2.255},
#  {'a': '2LV1_model_003', 'b': '2LV1_model_018', 'type': 'NMR', 'rmsd': 2.804},
#  {'a': '2M8P_model_051', 'b': '2M8P_model_097', 'type': 'NMR', 'rmsd': 10.354},
#  {'a': '1I87_model_004', 'b': '1I87_model_010', 'type': 'NMR', 'rmsd': 2.683},
#  {'a': '4AR0_model_015', 'b': '4AR0_model_007', 'type': 'NMR', 'rmsd': 5.666},
#  {'a': '2LOR_model_012', 'b': '2LOR_model_008', 'type': 'NMR', 'rmsd': 3.273},
#  {'a': '1JJG_model_010', 'b': '1JJG_model_014', 'type': 'NMR', 'rmsd': 2.406},
#  {'a': '2DBK_model_012', 'b': '2DBK_model_011', 'type': 'NMR', 'rmsd': 6.234},
#  {'a': '2COT_model_010', 'b': '2COT_model_003', 'type': 'NMR', 'rmsd': 3.069},
#  {'a': '1ORM_model_013', 'b': '1ORM_model_016', 'type': 'NMR', 'rmsd': 3.511},
#  {'a': '2MK4_model_014', 'b': '2MK4_model_001', 'type': 'NMR', 'rmsd': 3.917},
#  {'a': '2DJ8_model_001', 'b': '2DJ8_model_018', 'type': 'NMR', 'rmsd': 2.316},
#  {'a': '2LBC_model_007', 'b': '2LBC_model_012', 'type': 'NMR', 'rmsd': 7.925},
#  {'a': '2RNB_model_018', 'b': '2RNB_model_006', 'type': 'NMR', 'rmsd': 2.977},
#  {'a': '8JQ1_model_008', 'b': '8JQ1_model_001', 'type': 'NMR', 'rmsd': 6.611},
#  ...]

# %%
results = [item for item in pairs if item.get('type') == 'NMR']
results
# Out:
# [{'a': '4ew2', 'b': '4zz1', 'type': 'Multistate'},
#  {'a': '2fvy', 'b': '2fw0', 'type': 'Multistate'},
#  {'a': '4v38', 'b': '4v3c', 'type': 'Multistate'},
#  {'a': '109l', 'b': '173l', 'type': 'Multistate'},
#  {'a': '1kw0', 'b': '1lrm', 'type': 'Multistate'},
#  {'a': '1cll', 'b': '7pu9', 'type': 'Multistate'},
#  {'a': '1jej', 'b': '1jix', 'type': 'Multistate'},
#  {'a': '1fw0', 'b': '3b6q', 'type': 'Multistate'},
#  {'a': '1i6m', 'b': '1mau', 'type': 'Multistate'},
#  {'a': '2gd8', 'b': '6bbs', 'type': 'Multistate'},
#  {'a': '6aub', 'b': '7yc9', 'type': 'Multistate'},
#  {'a': '3n49', 'b': '4p0v', 'type': 'Multistate'},
#  {'a': '1d9v', 'b': '3od7', 'type': 'Multistate'},
#  {'a': '5z2e', 'b': '5z2f', 'type': 'Multistate'},
#  {'a': '1w82', 'b': '2i0h', 'type': 'Multistate'},
#  {'a': '1lg6', 'b': '6bbs', 'type': 'Multistate'},
#  {'a': '1lag', 'b': '6mkx', 'type': 'Multistate'},
#  {'a': '5x4u', 'b': '8qfh', 'type': 'Multistate'},
#  {'a': '4yus', 'b': '8qfh', 'type': 'Multistate'},
#  {'a': '2qis', 'b': '4qxs', 'type': 'Multistate'},
#  {'a': '3n49', 'b': '5cg6', 'type': 'Multistate'},
#  {'a': '2qcy', 'b': '2z9g', 'type': 'Multistate'},
#  {'a': '4kb4', 'b': '4kc6', 'type': 'Multistate'},
#  {'a': '2ii6', 'b': '2ilv', 'type': 'Multistate'},
#  {'a': '1tn4', 'b': '2tn4', 'type': 'Multistate'},
#  {'a': '2iys', 'b': '3baf', 'type': 'Multistate'},
#  {'a': '2ihj', 'b': '2ii6', 'type': 'Multistate'},
#  {'a': '109l', 'b': '172l', 'type': 'Multistate'},
#  {'a': '1c0c', 'b': '1rha', 'type': 'Multistate'},
#  {'a': '8k4i', 'b': '8k5q', 'type': 'Multistate'},
#  {'a': '2qrj', 'b': '2qrl', 'type': 'Multistate'},
#  {'a': '1wbo', 'b': '2i0h', 'type': 'Multistate'},
#  {'a': '1wqg', 'b': '4kc6', 'type': 'Multistate'},
#  {'a': '2qcy', 'b': '3tns', 'type': 'Multistate'},
#  {'a': '1anf', 'b': '1omp', 'type': 'Multistate'},
#  {'a': '1nnf', 'b': '3od7', 'type': 'Multistate'},
#  {'a': '107l', 'b': '1p7s', 'type': 'Multistate'},
#  {'a': '4km5', 'b': '7fub', 'type': 'Multistate'},
#  {'a': '1zh6', 'b': '5n5u', 'type': 'Multistate'},
#  {'a': '2f14', 'b': '6bbs', 'type': 'Multistate'},
#  {'a': '4ew3', 'b': '5j9f', 'type': 'Multistate'},
#  {'a': '6cwn', 'b': '7sv4', 'type': 'Multistate'},
#  {'a': '6hac', 'b': '6hav', 'type': 'Multistate'},
#  {'a': '7k03', 'b': '7k6f', 'type': 'Multistate'},
#  {'a': '1ezm', 'b': '1u4g', 'type': 'Multistate'},
#  {'a': '6z56', 'b': '6z58', 'type': 'Multistate'},
#  {'a': '1anf', 'b': '1lls', 'type': 'Multistate'},
#  {'a': '1o03', 'b': '5ok0', 'type': 'Multistate'},
#  {'a': '1zgf', 'b': '6bbs', 'type': 'Multistate'},
#  {'a': '1laf', 'b': '6mld', 'type': 'Multistate'},
#  {'a': '2qrj', 'b': '2qrk', 'type': 'Multistate'},
#  {'a': '2gke', 'b': '2q9h', 'type': 'Multistate'},
#  {'a': '1gdj', 'b': '1lh6', 'type': 'Multistate'},
#  {'a': '5l3a', 'b': '5tq8', 'type': 'Multistate'},
#  {'a': '1xbn', 'b': '3iqb', 'type': 'Multistate'},
#  {'a': '1bwj', 'b': '6s7n', 'type': 'Multistate'},
#  {'a': '2x4z', 'b': '5zjw', 'type': 'Multistate'},
#  {'a': '1aki', 'b': '6s7n', 'type': 'Multistate'},
#  {'a': '3b7l', 'b': '4lph', 'type': 'Multistate'},
#  {'a': '2fkg', 'b': '2oy8', 'type': 'Multistate'},
#  {'a': '1anf', 'b': '3kjt', 'type': 'Multistate'},
#  {'a': '3k6u', 'b': '3k6w', 'type': 'Multistate'},
#  {'a': '6e50', 'b': '7mfy', 'type': 'Multistate'},
#  {'a': '1ypc', 'b': '6qiz', 'type': 'Multistate'},
#  {'a': '6xe4', 'b': '7yc9', 'type': 'Multistate'},
#  {'a': '1bxq', 'b': '3app', 'type': 'Multistate'},
#  {'a': '4zh6', 'b': '7mfy', 'type': 'Multistate'},
#  {'a': '2ihz', 'b': '2ii6', 'type': 'Multistate'},
#  {'a': '1gqz', 'b': '2gke', 'type': 'Multistate'},
#  {'a': '5x4t', 'b': '8qff', 'type': 'Multistate'},
#  {'a': '3uv5', 'b': '6fic', 'type': 'Multistate'},
#  {'a': '1mrp', 'b': '1qvs', 'type': 'Multistate'},
#  {'a': '2b0j', 'b': '3f46', 'type': 'Multistate'},
#  {'a': '6x3i', 'b': '8w4m', 'type': 'Multistate'},
#  {'a': '2qcy', 'b': '3szn', 'type': 'Multistate'},
#  {'a': '5f2f', 'b': '5mca', 'type': 'Multistate'},
#  {'a': '5fs5', 'b': '5mca', 'type': 'Multistate'},
#  {'a': '108l', 'b': '1p7s', 'type': 'Multistate'},
#  {'a': '1i6m', 'b': '1m83', 'type': 'Multistate'},
#  {'a': '1gdi', 'b': '2lh6', 'type': 'Multistate'},
#  {'a': '6j47', 'b': '6j49', 'type': 'Multistate'},
#  {'a': '3l6g', 'b': '3l6h', 'type': 'Multistate'},
#  {'a': '2wea', 'b': '3app', 'type': 'Multistate'},
#  {'a': '6y4v', 'b': '8efj', 'type': 'Multistate'},
#  {'a': '7e73', 'b': '8pt1', 'type': 'Multistate'},
#  {'a': '2iyy', 'b': '3baf', 'type': 'Multistate'},
#  {'a': '1lah', 'b': '6mld', 'type': 'Multistate'},
#  {'a': '2qrj', 'b': '3uh1', 'type': 'Multistate'},
#  {'a': '4j12', 'b': '5iw3', 'type': 'Multistate'},
#  {'a': '2wec', 'b': '3app', 'type': 'Multistate'},
#  {'a': '1uwf', 'b': '5mca', 'type': 'Multistate'},
#  {'a': '2dfn', 'b': '3baf', 'type': 'Multistate'},
#  {'a': '3f6y', 'b': '8d0m', 'type': 'Multistate'},
#  {'a': '1gdj', 'b': '1lh1', 'type': 'Multistate'},
#  {'a': '1anf', 'b': '1zjl', 'type': 'Multistate'},
#  {'a': '1anf', 'b': '1zkb', 'type': 'Multistate'},
#  {'a': '1ppk', 'b': '3app', 'type': 'Multistate'},
#  {'a': '1jej', 'b': '1jg6', 'type': 'Multistate'},
#  {'a': '1b0d', 'b': '6s7n', 'type': 'Multistate'},
#  {'a': '2o68', 'b': '3od7', 'type': 'Multistate'},
#  {'a': '2fmz', 'b': '6bbs', 'type': 'Multistate'},
#  {'a': '1w82', 'b': '3gc7', 'type': 'Multistate'},
#  {'a': '3quq', 'b': '3qx7', 'type': 'Multistate'},
#  {'a': '6o5g', 'b': '6os4', 'type': 'Multistate'},
#  {'a': '1w83', 'b': '3u8w', 'type': 'Multistate'},
#  {'a': '4lov', 'b': '5mca', 'type': 'Multistate'},
#  {'a': '7k0d', 'b': '7t36', 'type': 'Multistate'},
#  {'a': '2v02', 'b': '6o5g', 'type': 'Multistate'},
#  {'a': '6y80', 'b': '8efj', 'type': 'Multistate'},
#  {'a': '1s2o', 'b': '2b1q', 'type': 'Multistate'},
#  {'a': '2hkd', 'b': '2oy7', 'type': 'Multistate'},
#  {'a': '2b0j', 'b': '3h65', 'type': 'Multistate'},
#  {'a': '4iy0', 'b': '4iys', 'type': 'Multistate'},
#  {'a': '1i6m', 'b': '7cki', 'type': 'Multistate'},
#  {'a': '1mmk', 'b': '1tg2', 'type': 'Multistate'},
#  {'a': '2wed', 'b': '3app', 'type': 'Multistate'},
#  {'a': '2fvy', 'b': '2qw1', 'type': 'Multistate'},
#  {'a': '1mrp', 'b': '3odb', 'type': 'Multistate'},
#  {'a': '5x0b', 'b': '5x0j', 'type': 'Multistate'},
#  {'a': '3c2s', 'b': '5iw3', 'type': 'Multistate'},
#  {'a': '5c8p', 'b': '5c8q', 'type': 'Multistate'},
#  {'a': '5hn3', 'b': '5hn6', 'type': 'Multistate'},
#  {'a': '2cey', 'b': '2wyp', 'type': 'Multistate'},
#  {'a': '1laf', 'b': '6ml0', 'type': 'Multistate'},
#  {'a': '3ucy', 'b': '5dsu', 'type': 'Multistate'},
#  {'a': '1z15', 'b': '1z17', 'type': 'Multistate'},
#  {'a': '6j47', 'b': '6j48', 'type': 'Multistate'},
#  {'a': '3d8n', 'b': '3d8s', 'type': 'Multistate'},
#  {'a': '1igv', 'b': '3icb', 'type': 'Multistate'},
#  {'a': '5x4u', 'b': '8qff', 'type': 'Multistate'},
#  {'a': '7kxo', 'b': '7yc9', 'type': 'Multistate'},
#  {'a': '1mmk', 'b': '4pah', 'type': 'Multistate'},
#  {'a': '1j8u', 'b': '1kw0', 'type': 'Multistate'},
#  {'a': '5twb', 'b': '5twc', 'type': 'Multistate'},
#  {'a': '2v02', 'b': '7pu9', 'type': 'Multistate'},
#  {'a': '1lbb', 'b': '3b6q', 'type': 'Multistate'},
#  {'a': '6y4v', 'b': '8vwm', 'type': 'Multistate'},
#  {'a': '6joq', 'b': '6k9a', 'type': 'Multistate'},
#  {'a': '1k0l', 'b': '1pxa', 'type': 'Multistate'},
#  {'a': '11qe', 'b': '9u8y', 'type': 'Multistate'},
#  {'a': '1azf', 'b': '6s7n', 'type': 'Multistate'},
#  {'a': '1qw0', 'b': '3od7', 'type': 'Multistate'},
#  {'a': '5kke', 'b': '5lft', 'type': 'Multistate'},
#  {'a': '3n49', 'b': '4ga3', 'type': 'Multistate'},
#  {'a': '1fw0', 'b': '1nnk', 'type': 'Multistate'},
#  {'a': '2cey', 'b': '8cp7', 'type': 'Multistate'},
#  {'a': '4zh6', 'b': '8db2', 'type': 'Multistate'},
#  {'a': '2oyb', 'b': '6j5r', 'type': 'Multistate'},
#  {'a': '6a9w', 'b': '6jon', 'type': 'Multistate'},
#  {'a': '1cll', 'b': '6o5g', 'type': 'Multistate'},
#  {'a': '1jej', 'b': '1nvk', 'type': 'Multistate'},
#  {'a': '4ew3', 'b': '4zz1', 'type': 'Multistate'},
#  {'a': '3zl2', 'b': '5mca', 'type': 'Multistate'},
#  {'a': '2gt8', 'b': '3f9e', 'type': 'Multistate'},
#  {'a': '7k0d', 'b': '7lb0', 'type': 'Multistate'},
#  {'a': '108l', 'b': '189l', 'type': 'Multistate'},
#  {'a': '4zh6', 'b': '8d6h', 'type': 'Multistate'},
#  {'a': '5x4v', 'b': '8qff', 'type': 'Multistate'},
#  {'a': '1k0i', 'b': '1pxb', 'type': 'Multistate'},
#  {'a': '5x4v', 'b': '8qfe', 'type': 'Multistate'},
#  {'a': '7jjh', 'b': '7k03', 'type': 'Multistate'},
#  {'a': '4v38', 'b': '4v3b', 'type': 'Multistate'},
#  {'a': '1sw2', 'b': '3mam', 'type': 'Multistate'},
#  {'a': '1laf', 'b': '6mkx', 'type': 'Multistate'},
#  {'a': '1cke', 'b': '2cmk', 'type': 'Multistate'},
#  {'a': '3quc', 'b': '3quq', 'type': 'Multistate'},
#  {'a': '1zk9', 'b': '1zka', 'type': 'Multistate'},
#  {'a': '5x0b', 'b': '5x0e', 'type': 'Multistate'},
#  {'a': '6y4v', 'b': '8vt6', 'type': 'Multistate'},
#  {'a': '1mmt', 'b': '1tg2', 'type': 'Multistate'},
#  {'a': '3b6t', 'b': '5cbr', 'type': 'Multistate'},
#  {'a': '1we2', 'b': '3baf', 'type': 'Multistate'},
#  {'a': '1o03', 'b': '1zol', 'type': 'Multistate'},
#  {'a': '2f7m', 'b': '4kq5', 'type': 'Multistate'},
#  {'a': '5jeq', 'b': '6yue', 'type': 'Multistate'},
#  {'a': '1f10', 'b': '6s7n', 'type': 'Multistate'},
#  {'a': '5x4u', 'b': '8qfe', 'type': 'Multistate'},
#  {'a': '1o03', 'b': '6ydk', 'type': 'Multistate'},
#  {'a': '6e50', 'b': '8d6n', 'type': 'Multistate'},
#  {'a': '1u4g', 'b': '6f8b', 'type': 'Multistate'},
#  {'a': '2iyv', 'b': '3baf', 'type': 'Multistate'},
#  {'a': '2i08', 'b': '3ucy', 'type': 'Multistate'},
#  {'a': '4auj', 'b': '5mca', 'type': 'Multistate'},
#  {'a': '2ihk', 'b': '3s44', 'type': 'Multistate'},
#  {'a': '4zh6', 'b': '8dn1', 'type': 'Multistate'},
#  {'a': '1o03', 'b': '2wfa', 'type': 'Multistate'},
#  {'a': '5ew9', 'b': '6cpe', 'type': 'Multistate'},
#  {'a': '2geh', 'b': '6bbs', 'type': 'Multistate'},
#  {'a': '1o03', 'b': '6h8z', 'type': 'Multistate'},
#  {'a': '1c0c', 'b': '1rta', 'type': 'Multistate'},
#  {'a': '1lbb', 'b': '1nnk', 'type': 'Multistate'},
#  {'a': '1wbt', 'b': '3gc7', 'type': 'Multistate'},
#  {'a': '4xsj', 'b': '6jg0', 'type': 'Multistate'},
#  {'a': '1jej', 'b': '1nzd', 'type': 'Multistate'},
#  {'a': '2zpc', 'b': '2zpd', 'type': 'Multistate'},
#  {'a': '6cwn', 'b': '7sv6', 'type': 'Multistate'},
#  {'a': '4yus', 'b': '8qfe', 'type': 'Multistate'},
#  {'a': '194l', 'b': '6s7n', 'type': 'Multistate'},
#  {'a': '1wpa', 'b': '1xaw', 'type': 'Multistate'},
#  {'a': '3dlz', 'b': '6z5c', 'type': 'Multistate'},
#  {'a': '1xa5', 'b': '3if7', 'type': 'Multistate'},
#  {'a': '108l', 'b': '151l', 'type': 'Multistate'},
#  {'a': '2qcy', 'b': '3ea9', 'type': 'Multistate'},
#  {'a': '2oyb', 'b': '6j47', 'type': 'Multistate'},
#  {'a': '2d05', 'b': '5hwa', 'type': 'Multistate'},
#  {'a': '1dmw', 'b': '1kw0', 'type': 'Multistate'},
#  {'a': '2b0j', 'b': '3f47', 'type': 'Multistate'},
#  {'a': '109l', 'b': '151l', 'type': 'Multistate'},
#  {'a': '7t8j', 'b': '7u4z', 'type': 'Multistate'},
#  {'a': '1z18', 'b': '2liv', 'type': 'Multistate'},
#  {'a': '1o03', 'b': '6h94', 'type': 'Multistate'},
#  {'a': '107l', 'b': '189l', 'type': 'Multistate'},
#  {'a': '1iwl', 'b': '3ksn', 'type': 'Multistate'},
#  {'a': '1p1n', 'b': '3b6q', 'type': 'Multistate'},
#  {'a': '1ppl', 'b': '3app', 'type': 'Multistate'},
#  {'a': '1gdi', 'b': '2lh5', 'type': 'Multistate'},
#  {'a': '2ihz', 'b': '3s44', 'type': 'Multistate'},
#  {'a': '6z58', 'b': '6z5c', 'type': 'Multistate'},
#  {'a': '3dlz', 'b': '6z56', 'type': 'Multistate'},
#  {'a': '2cey', 'b': '2wx9', 'type': 'Multistate'},
#  {'a': '1z15', 'b': '2liv', 'type': 'Multistate'},
#  {'a': '2qcy', 'b': '3ea8', 'type': 'Multistate'},
#  {'a': '1z15', 'b': '1z16', 'type': 'Multistate'},
#  {'a': '1lag', 'b': '6mld', 'type': 'Multistate'},
#  {'a': '1fw0', 'b': '3b6t', 'type': 'Multistate'},
#  {'a': '2cey', 'b': '2v4c', 'type': 'Multistate'},
#  {'a': '6y80', 'b': '8vwm', 'type': 'Multistate'},
#  {'a': '5h5i', 'b': '5xdv', 'type': 'Multistate'},
#  {'a': '2ihj', 'b': '3s44', 'type': 'Multistate'},
#  {'a': '4x5q', 'b': '5mca', 'type': 'Multistate'},
#  {'a': '6e50', 'b': '8db2', 'type': 'Multistate'},
#  {'a': '6jop', 'b': '6k9a', 'type': 'Multistate'},
#  {'a': '1o03', 'b': '5ojz', 'type': 'Multistate'},
#  {'a': '107l', 'b': '2huk', 'type': 'Multistate'},
#  {'a': '4ehw', 'b': '4itl', 'type': 'Multistate'},
#  {'a': '1si0', 'b': '1si1', 'type': 'Multistate'},
#  {'a': '2g8c', 'b': '6j47', 'type': 'Multistate'},
#  {'a': '1gdi', 'b': '1lh2', 'type': 'Multistate'},
#  {'a': '1s69', 'b': '2hz1', 'type': 'Multistate'},
#  {'a': '1zfk', 'b': '6bbs', 'type': 'Multistate'},
#  {'a': '1j8t', 'b': '1kw0', 'type': 'Multistate'},
#  {'a': '1f2w', 'b': '6bbs', 'type': 'Multistate'},
#  {'a': '2cey', 'b': '2xwo', 'type': 'Multistate'},
#  {'a': '1oq5', 'b': '6bbs', 'type': 'Multistate'},
#  {'a': '7fu8', 'b': '7fub', 'type': 'Multistate'},
#  {'a': '2qrl', 'b': '3uh1', 'type': 'Multistate'},
#  {'a': '1gdi', 'b': '1lh7', 'type': 'Multistate'},
#  {'a': '4ew3', 'b': '4zyv', 'type': 'Multistate'},
#  {'a': '1mmk', 'b': '5pah', 'type': 'Multistate'},
#  {'a': '2oy7', 'b': '2oy8', 'type': 'Multistate'},
#  {'a': '3quc', 'b': '3qut', 'type': 'Multistate'},
#  {'a': '2tgi', 'b': '6i9j', 'type': 'Multistate'},
#  {'a': '1z15', 'b': '1z18', 'type': 'Multistate'},
#  {'a': '1gdi', 'b': '1lh6', 'type': 'Multistate'},
#  {'a': '3v7m', 'b': '4j12', 'type': 'Multistate'},
#  {'a': '5cot', 'b': '6vt3', 'type': 'Multistate'},
#  {'a': '3zyq', 'b': '4avx', 'type': 'Multistate'},
#  {'a': '2ipn', 'b': '2qw1', 'type': 'Multistate'},
#  {'a': '5iji', 'b': '5jeq', 'type': 'Multistate'},
#  {'a': '6y80', 'b': '8vt6', 'type': 'Multistate'},
#  {'a': '2qrk', 'b': '3uh1', 'type': 'Multistate'},
#  {'a': '1o03', 'b': '5o6r', 'type': 'Multistate'},
#  {'a': '1gdi', 'b': '2lh2', 'type': 'Multistate'},
#  {'a': '1bvx', 'b': '6s7n', 'type': 'Multistate'},
#  {'a': '2qcy', 'b': '2zu4', 'type': 'Multistate'},
#  {'a': '2cey', 'b': '2wyk', 'type': 'Multistate'},
#  {'a': '1wbs', 'b': '3gc7', 'type': 'Multistate'},
#  {'a': '4cud', 'b': '4cuf', 'type': 'Multistate'},
#  {'a': '2h15', 'b': '6bbs', 'type': 'Multistate'},
#  {'a': '5b2a', 'b': '6j47', 'type': 'Multistate'},
#  {'a': '3c2s', 'b': '4j12', 'type': 'Multistate'},
#  {'a': '1ls1', 'b': '1ng1', 'type': 'Multistate'},
#  {'a': '1w82', 'b': '3u8w', 'type': 'Multistate'},
#  {'a': '5kke', 'b': '6gd7', 'type': 'Multistate'},
#  {'a': '1anf', 'b': '1dmb', 'type': 'Multistate'},
#  {'a': '1ypb', 'b': '6qiz', 'type': 'Multistate'},
#  {'a': '4ga3', 'b': '5dgn', 'type': 'Multistate'},
#  {'a': '1lah', 'b': '2lao', 'type': 'Multistate'},
#  {'a': '1lbb', 'b': '3b6t', 'type': 'Multistate'},
#  {'a': '4yus', 'b': '8qff', 'type': 'Multistate'},
#  {'a': '2ii6', 'b': '8sv2', 'type': 'Multistate'},
#  {'a': '2fw0', 'b': '2ipn', 'type': 'Multistate'},
#  {'a': '3n49', 'b': '4pvy', 'type': 'Multistate'},
#  {'a': '2cmk', 'b': '2fem', 'type': 'Multistate'},
#  {'a': '6e51', 'b': '8db2', 'type': 'Multistate'},
#  {'a': '107l', 'b': '151l', 'type': 'Multistate'},
#  {'a': '1dpw', 'b': '6s7n', 'type': 'Multistate'},
#  {'a': '6ggp', 'b': '6q3u', 'type': 'Multistate'},
#  {'a': '3smv', 'b': '8yvw', 'type': 'Multistate'},
#  {'a': '2g8c', 'b': '6j5r', 'type': 'Multistate'},
#  {'a': '1w83', 'b': '3gc7', 'type': 'Multistate'},
#  {'a': '1ig5', 'b': '3icb', 'type': 'Multistate'},
#  {'a': '1o03', 'b': '6h8w', 'type': 'Multistate'},
#  {'a': '1jej', 'b': '1jiu', 'type': 'Multistate'},
#  {'a': '3ocs', 'b': '7yc9', 'type': 'Multistate'},
#  {'a': '1lah', 'b': '6ml0', 'type': 'Multistate'},
#  {'a': '1anf', 'b': '1mpb', 'type': 'Multistate'},
#  {'a': '1rzl', 'b': '1uvb', 'type': 'Multistate'},
#  {'a': '1s2o', 'b': '2b1r', 'type': 'Multistate'},
#  {'a': '2qcy', 'b': '2v6n', 'type': 'Multistate'},
#  {'a': '4att', 'b': '5mca', 'type': 'Multistate'},
#  {'a': '1anf', 'b': '1jw5', 'type': 'Multistate'},
#  {'a': '2cey', 'b': '2xwi', 'type': 'Multistate'},
#  {'a': '1gdi', 'b': '2lh1', 'type': 'Multistate'},
#  {'a': '2dfe', 'b': '2dfh', 'type': 'Multistate'},
#  {'a': '3dlz', 'b': '3fmd', 'type': 'Multistate'},
#  {'a': '4j8m', 'b': '5osd', 'type': 'Multistate'},
#  {'a': '1bgi', 'b': '6s7n', 'type': 'Multistate'},
#  {'a': '1lag', 'b': '2lao', 'type': 'Multistate'},
#  {'a': '5kke', 'b': '6rsj', 'type': 'Multistate'},
#  {'a': '1ppm', 'b': '3app', 'type': 'Multistate'},
#  {'a': '4av4', 'b': '5mca', 'type': 'Multistate'},
#  {'a': '3vgl', 'b': '3vgm', 'type': 'Multistate'},
#  {'a': '1wbt', 'b': '2i0h', 'type': 'Multistate'},
#  {'a': '1mmk', 'b': '6pah', 'type': 'Multistate'},
#  {'a': '3k6v', 'b': '3k6w', 'type': 'Multistate'},
#  {'a': '1uha', 'b': '1uln', 'type': 'Multistate'},
#  {'a': '1o03', 'b': '2wf9', 'type': 'Multistate'},
#  {'a': '6qiz', 'b': '7a3m', 'type': 'Multistate'},
#  {'a': '1k0i', 'b': '1pxa', 'type': 'Multistate'},
#  {'a': '193l', 'b': '6s7n', 'type': 'Multistate'},
#  {'a': '2b0j', 'b': '3dag', 'type': 'Multistate'},
#  {'a': '2qk8', 'b': '8ssx', 'type': 'Multistate'},
#  {'a': '2qcy', 'b': '4twy', 'type': 'Multistate'},
#  {'a': '2fkg', 'b': '2hkd', 'type': 'Multistate'},
#  {'a': '1mmt', 'b': '1tdw', 'type': 'Multistate'},
#  {'a': '1laf', 'b': '6mlv', 'type': 'Multistate'},
#  {'a': '7q03', 'b': '7q07', 'type': 'Multistate'},
#  {'a': '1z77', 'b': '2iek', 'type': 'Multistate'},
#  {'a': '5p9h', 'b': '7yc9', 'type': 'Multistate'},
#  {'a': '2fw0', 'b': '8fxt', 'type': 'Multistate'},
#  {'a': '2qcy', 'b': '2zu5', 'type': 'Multistate'},
#  {'a': '1ypa', 'b': '6qiz', 'type': 'Multistate'},
#  {'a': '5yhy', 'b': '5yhz', 'type': 'Multistate'},
#  {'a': '6j47', 'b': '6j5m', 'type': 'Multistate'},
#  {'a': '4kq5', 'b': '4xqr', 'type': 'Multistate'},
#  {'a': '1jej', 'b': '1nzf', 'type': 'Multistate'},
#  {'a': '2i5v', 'b': '6j47', 'type': 'Multistate'},
#  {'a': '6cwn', 'b': '6cwr', 'type': 'Multistate'},
#  {'a': '5fd7', 'b': '5fd9', 'type': 'Multistate'},
#  {'a': '1qgi', 'b': '5hwa', 'type': 'Multistate'},
#  {'a': '9jag', 'b': '9lo6', 'type': 'Multistate'},
#  {'a': '1wbs', 'b': '2i0h', 'type': 'Multistate'},
#  {'a': '1k96', 'b': '1k9p', 'type': 'Multistate'},
#  {'a': '1s2o', 'b': '2d2v', 'type': 'Multistate'},
#  {'a': '1lst', 'b': '2lao', 'type': 'Multistate'},
#  {'a': '1anf', 'b': '1fqb', 'type': 'Multistate'},
#  {'a': '5x4t', 'b': '8qfe', 'type': 'Multistate'},
#  {'a': '1o03', 'b': '2whe', 'type': 'Multistate'},
#  {'a': '107l', 'b': '172l', 'type': 'Multistate'},
#  {'a': '6e51', 'b': '8d6n', 'type': 'Multistate'},
#  {'a': '2b0j', 'b': '3daf', 'type': 'Multistate'},
#  {'a': '5f3f', 'b': '5mca', 'type': 'Multistate'},
#  {'a': '6os4', 'b': '7pu9', 'type': 'Multistate'},
#  {'a': '1anf', 'b': '8etb', 'type': 'Multistate'},
#  {'a': '2qcy', 'b': '3tiu', 'type': 'Multistate'},
#  {'a': '2qcy', 'b': '2qiq', 'type': 'Multistate'},
#  {'a': '2gkj', 'b': '2q9h', 'type': 'Multistate'},
#  {'a': '1mrp', 'b': '2o69', 'type': 'Multistate'},
#  {'a': '1s2o', 'b': '1u2s', 'type': 'Multistate'},
#  {'a': '1z17', 'b': '2liv', 'type': 'Multistate'},
#  {'a': '5x4t', 'b': '8qfh', 'type': 'Multistate'},
#  {'a': '1wbn', 'b': '2i0h', 'type': 'Multistate'},
#  {'a': '4zh6', 'b': '8d6n', 'type': 'Multistate'},
#  {'a': '1f0w', 'b': '6s7n', 'type': 'Multistate'},
#  {'a': '1jej', 'b': '1jiv', 'type': 'Multistate'},
#  {'a': '1s2o', 'b': '1tj5', 'type': 'Multistate'},
#  {'a': '1bwi', 'b': '6s7n', 'type': 'Multistate'},
#  {'a': '1mmk', 'b': '4anp', 'type': 'Multistate'},
#  {'a': '2zpc', 'b': '7z6w', 'type': 'Multistate'},
#  {'a': '2cey', 'b': '6h75', 'type': 'Multistate'},
#  {'a': '1gdi', 'b': '1lh3', 'type': 'Multistate'},
#  {'a': '1mrp', 'b': '2o68', 'type': 'Multistate'},
#  {'a': '4ahl', 'b': '5m9a', 'type': 'Multistate'},
#  {'a': '1anf', 'b': '1mpc', 'type': 'Multistate'},
#  {'a': '1zk9', 'b': '4jhb', 'type': 'Multistate'},
#  {'a': '2cey', 'b': '3b50', 'type': 'Multistate'},
#  {'a': '6qiz', 'b': '7aok', 'type': 'Multistate'},
#  {'a': '4bn4', 'b': '4jsr', 'type': 'Multistate'},
#  {'a': '4dw8', 'b': '4dwo', 'type': 'Multistate'},
#  {'a': '3f6y', 'b': '4ogw', 'type': 'Multistate'},
#  {'a': '4cuf', 'b': '4d0e', 'type': 'Multistate'},
#  {'a': '1s69', 'b': '2hz3', 'type': 'Multistate'},
#  {'a': '2eb8', 'b': '5oja', 'type': 'Multistate'},
#  {'a': '1cll', 'b': '6os4', 'type': 'Multistate'},
#  {'a': '5h5h', 'b': '5h5i', 'type': 'Multistate'},
#  {'a': '2fkg', 'b': '2oy7', 'type': 'Multistate'},
#  {'a': '4zh6', 'b': '8d6l', 'type': 'Multistate'},
#  {'a': '1mmt', 'b': '1pah', 'type': 'Multistate'},
#  {'a': '1wbn', 'b': '3gc7', 'type': 'Multistate'},
#  {'a': '1nnk', 'b': '5cbr', 'type': 'Multistate'},
#  {'a': '5x0f', 'b': '5x0j', 'type': 'Multistate'},
#  {'a': '7jjh', 'b': '7k6f', 'type': 'Multistate'},
#  {'a': '2ilv', 'b': '3s44', 'type': 'Multistate'},
#  {'a': '1z5p', 'b': '4yml', 'type': 'Multistate'},
#  {'a': '1ezm', 'b': '3dbk', 'type': 'Multistate'},
#  {'a': '5x0e', 'b': '5x0f', 'type': 'Multistate'},
#  {'a': '1mrp', 'b': '2o6a', 'type': 'Multistate'},
#  {'a': '1o03', 'b': '6h8y', 'type': 'Multistate'},
#  {'a': '1laf', 'b': '2lao', 'type': 'Multistate'},
#  {'a': '3rye', 'b': '4qxs', 'type': 'Multistate'},
#  {'a': '1c10', 'b': '6s7n', 'type': 'Multistate'},
#  {'a': '1gnq', 'b': '7ogf', 'type': 'Multistate'},
#  {'a': '2i5v', 'b': '6j5r', 'type': 'Multistate'},
#  {'a': '2iyw', 'b': '3baf', 'type': 'Multistate'},
#  {'a': '3n49', 'b': '4p0w', 'type': 'Multistate'},
#  {'a': '2f8c', 'b': '3n49', 'type': 'Multistate'},
#  {'a': '5u5o', 'b': '5u6f', 'type': 'Multistate'},
#  {'a': '1d9v', 'b': '1mrp', 'type': 'Multistate'},
#  {'a': '6qiz', 'b': '7aon', 'type': 'Multistate'},
#  {'a': '6e50', 'b': '8dn1', 'type': 'Multistate'},
#  {'a': '1o03', 'b': '5ok1', 'type': 'Multistate'},
#  {'a': '5bui', 'b': '8psw', 'type': 'Multistate'},
#  {'a': '6e51', 'b': '8d6h', 'type': 'Multistate'},
#  {'a': '1anf', 'b': '1zmg', 'type': 'Multistate'},
#  {'a': '1w83', 'b': '2i0h', 'type': 'Multistate'},
#  {'a': '2qcy', 'b': '3tnt', 'type': 'Multistate'},
#  {'a': '1s69', 'b': '2hz2', 'type': 'Multistate'},
#  {'a': '1wqg', 'b': '4kb4', 'type': 'Multistate'},
#  {'a': '4x5p', 'b': '5mca', 'type': 'Multistate'},
#  {'a': '1ezm', 'b': '6fzx', 'type': 'Multistate'},
#  {'a': '1c0b', 'b': '1rha', 'type': 'Multistate'},
#  {'a': '2cey', 'b': '2xwv', 'type': 'Multistate'},
#  {'a': '5kkw', 'b': '5wjp', 'type': 'Multistate'},
#  {'a': '1el4', 'b': '2f8p', 'type': 'Multistate'},
#  {'a': '6hni', 'b': '6hnk', 'type': 'Multistate'},
#  {'a': '108l', 'b': '173l', 'type': 'Multistate'},
#  {'a': '1mrp', 'b': '3kn8', 'type': 'Multistate'},
#  {'a': '4ew2', 'b': '4zyt', 'type': 'Multistate'},
#  {'a': '3d8r', 'b': '3d8s', 'type': 'Multistate'},
#  {'a': '2qcy', 'b': '4wy3', 'type': 'Multistate'},
#  {'a': '4r72', 'b': '4r75', 'type': 'Multistate'},
#  {'a': '1jej', 'b': '1qkj', 'type': 'Multistate'},
#  {'a': '1lag', 'b': '6mlv', 'type': 'Multistate'},
#  {'a': '1mmk', 'b': '1tdw', 'type': 'Multistate'},
#  {'a': '1zfq', 'b': '6bbs', 'type': 'Multistate'},
#  {'a': '6cwm', 'b': '6cwn', 'type': 'Multistate'},
#  {'a': '1tfg', 'b': '6i9j', 'type': 'Multistate'},
#  {'a': '2cey', 'b': '6h76', 'type': 'Multistate'},
#  {'a': '9jag', 'b': '9lo3', 'type': 'Multistate'},
#  {'a': '1mrp', 'b': '1nnf', 'type': 'Multistate'},
#  {'a': '1kms', 'b': '4m6j', 'type': 'Multistate'},
#  {'a': '4j8m', 'b': '5dn3', 'type': 'Multistate'},
#  {'a': '1mmk', 'b': '3pah', 'type': 'Multistate'},
#  {'a': '5kke', 'b': '6gd6', 'type': 'Multistate'},
#  {'a': '9jac', 'b': '9jag', 'type': 'Multistate'},
#  {'a': '1anf', 'b': '1ziu', 'type': 'Multistate'},
#  {'a': '2iyx', 'b': '3baf', 'type': 'Multistate'},
#  {'a': '6o5g', 'b': '7pu9', 'type': 'Multistate'},
#  {'a': '1mmk', 'b': '1pah', 'type': 'Multistate'},
#  {'a': '1kv1', 'b': '9cj1', 'type': 'Multistate'},
#  {'a': '1iej', 'b': '1tfa', 'type': 'Multistate'},
#  {'a': '1qvs', 'b': '3od7', 'type': 'Multistate'},
#  {'a': '1iej', 'b': '1nft', 'type': 'Multistate'},
#  {'a': '2v02', 'b': '6os4', 'type': 'Multistate'},
#  {'a': '2fmg', 'b': '6bbs', 'type': 'Multistate'},
#  {'a': '2hkk', 'b': '6bbs', 'type': 'Multistate'},
#  {'a': '1z16', 'b': '2liv', 'type': 'Multistate'},
#  {'a': '2fvy', 'b': '2ipn', 'type': 'Multistate'},
#  {'a': '4ew2', 'b': '7jg0', 'type': 'Multistate'},
#  {'a': '1anf', 'b': '1jw4', 'type': 'Multistate'},
#  {'a': '2cg6', 'b': '2cg7', 'type': 'Multistate'},
#  {'a': '3smv', 'b': '9v14', 'type': 'Multistate'},
#  {'a': '6e50', 'b': '8d6h', 'type': 'Multistate'},
#  {'a': '1usg', 'b': '2lbp', 'type': 'Multistate'},
#  {'a': '2x7p', 'b': '2x7q', 'type': 'Multistate'},
#  {'a': '2qw1', 'b': '8fxt', 'type': 'Multistate'},
#  {'a': '4kaw', 'b': '4kc6', 'type': 'Multistate'},
#  {'a': '1coa', 'b': '6qiz', 'type': 'Multistate'},
#  {'a': '1anf', 'b': '1fqa', 'type': 'Multistate'},
#  {'a': '1gqz', 'b': '2gkj', 'type': 'Multistate'},
#  {'a': '2iyt', 'b': '3baf', 'type': 'Multistate'},
#  {'a': '6e50', 'b': '8d6l', 'type': 'Multistate'},
#  {'a': '4cst', 'b': '5mca', 'type': 'Multistate'},
#  {'a': '2cey', 'b': '2xa5', 'type': 'Multistate'},
#  {'a': '1dpx', 'b': '6s7n', 'type': 'Multistate'},
#  {'a': '1mrp', 'b': '3kn7', 'type': 'Multistate'},
#  {'a': '2v01', 'b': '6eeb', 'type': 'Multistate'},
#  {'a': '1lag', 'b': '6ml0', 'type': 'Multistate'},
#  {'a': '1s6a', 'b': '2hz3', 'type': 'Multistate'},
#  {'a': '3d8n', 'b': '3d8r', 'type': 'Multistate'},
#  {'a': '3b6q', 'b': '5cbr', 'type': 'Multistate'},
#  {'a': '3b7l', 'b': '3n49', 'type': 'Multistate'},
#  {'a': '107l', 'b': '173l', 'type': 'Multistate'},
#  {'a': '108l', 'b': '172l', 'type': 'Multistate'},
#  {'a': '3n5j', 'b': '5cg6', 'type': 'Multistate'},
#  {'a': '2qcy', 'b': '2z94', 'type': 'Multistate'},
#  {'a': '3dat', 'b': '8ssx', 'type': 'Multistate'},
#  {'a': '4kaw', 'b': '4kb4', 'type': 'Multistate'},
#  {'a': '3dbk', 'b': '6f8b', 'type': 'Multistate'},
#  {'a': '1wbs', 'b': '3u8w', 'type': 'Multistate'},
#  {'a': '1gdi', 'b': '1lh1', 'type': 'Multistate'},
#  {'a': '6qiz', 'b': '7a1h', 'type': 'Multistate'},
#  {'a': '1fqn', 'b': '6bbs', 'type': 'Multistate'},
#  {'a': '6cwn', 'b': '7sv3', 'type': 'Multistate'},
#  {'a': '4iva', 'b': '5tq4', 'type': 'Multistate'},
#  {'a': '2qcy', 'b': '3tit', 'type': 'Multistate'},
#  {'a': '2iyu', 'b': '3baf', 'type': 'Multistate'},
#  {'a': '2ex1', 'b': '2ii6', 'type': 'Multistate'},
#  {'a': '5x4v', 'b': '8qfh', 'type': 'Multistate'},
#  {'a': '3qut', 'b': '3qx7', 'type': 'Multistate'},
#  {'a': '3n4u', 'b': '3sgc', 'type': 'Multistate'},
#  {'a': '6f8b', 'b': '6fzx', 'type': 'Multistate'},
#  {'a': '1jej', 'b': '1jg7', 'type': 'Multistate'},
#  {'a': '1lah', 'b': '6mkx', 'type': 'Multistate'},
#  {'a': '1gdi', 'b': '2lh7', 'type': 'Multistate'},
#  {'a': '1rtx', 'b': '1s69', 'type': 'Multistate'},
#  {'a': '1gdi', 'b': '2lh3', 'type': 'Multistate'},
#  {'a': '7e73', 'b': '8pt0', 'type': 'Multistate'},
#  {'a': '5kke', 'b': '6rsi', 'type': 'Multistate'},
#  {'a': '3s4j', 'b': '4qxs', 'type': 'Multistate'},
#  {'a': '7k0d', 'b': '7lb2', 'type': 'Multistate'},
#  {'a': '2cey', 'b': '2xxk', 'type': 'Multistate'},
#  {'a': '1gdj', 'b': '1lh2', 'type': 'Multistate'},
#  {'a': '1s6a', 'b': '2hz2', 'type': 'Multistate'},
#  {'a': '4ew2', 'b': '5j9f', 'type': 'Multistate'},
#  {'a': '2web', 'b': '3app', 'type': 'Multistate'},
#  {'a': '2anj', 'b': '4o3c', 'type': 'Multistate'},
#  {'a': '2cey', 'b': '2xwk', 'type': 'Multistate'},
#  {'a': '1gdi', 'b': '1lh5', 'type': 'Multistate'},
#  {'a': '1mrp', 'b': '1qw0', 'type': 'Multistate'},
#  {'a': '108l', 'b': '2huk', 'type': 'Multistate'},
#  {'a': '1bwh', 'b': '6s7n', 'type': 'Multistate'},
#  {'a': '4ew2', 'b': '4zyv', 'type': 'Multistate'},
#  {'a': '1o03', 'b': '6h90', 'type': 'Multistate'},
#  {'a': '7ntn', 'b': '7nto', 'type': 'Multistate'},
#  {'a': '1o03', 'b': '6h8u', 'type': 'Multistate'},
#  {'a': '4ew2', 'b': '4zz2', 'type': 'Multistate'},
#  {'a': '4j8m', 'b': '5os5', 'type': 'Multistate'},
#  {'a': '1bxo', 'b': '3app', 'type': 'Multistate'},
#  {'a': '1fr4', 'b': '6bbs', 'type': 'Multistate'}]

# %%
#!/usr/bin/env python3
import torch
from tqdm import tqdm
import os

# ==========================================
# ⚙️ НАСТРОЙКИ
# ==========================================
PAIRS_PATH = "./train_pairs.pt"
REGISTRY_PATH = "/home/domain/data/aristowi/mlp_dataset_laproteina/latents/registry_with_full_coords.pt"
OUTPUT_PATH = "./train_pairs_clean.pt"
# ==========================================

print("📦 Загружаем данные...")
pairs_data = torch.load(PAIRS_PATH, map_location="cpu")
pairs = pairs_data["pairs"] if isinstance(pairs_data, dict) else pairs_data
registry = torch.load(REGISTRY_PATH, map_location="cpu")

# 1️⃣ Находим все проблемные ID
print("🔍 Ищем белки с несовпадением длин или отсутствием данных...")
bad_ids = set()

for pid in tqdm(registry.keys(), desc="Сканирование registry"):
    item = registry[pid]
    is_bad = False
    
    # Проверка наличия ключа
    if "coords_37" not in item or item["coords_37"] is None:
        is_bad = True
    # Проверка согласованности длин
    else:
        try:
            len_z = item["z"].shape[0]
            len_full = item["coords_37"].shape[0]
            if len_z != len_full:
                is_bad = True
        except Exception:
            is_bad = True
            
    if is_bad:
        bad_ids.add(pid)

# Добавляем ID из пар, которых вообще нет в registry
for p in pairs:
    if p["a"] not in registry or p["b"] not in registry:
        bad_ids.add(p.get("a", "unknown"))
        bad_ids.add(p.get("b", "unknown"))

print(f"🚫 Найдено {len(bad_ids)} проблемных белков")

# 2️⃣ Фильтруем пары
print("🧹 Удаляем пары, содержащие проблемные белки...")
original_count = len(pairs)
clean_pairs = []

for p in tqdm(pairs, desc="Фильтрация пар"):
    # Оставляем только пары, где ОБА белка валидны
    if p["a"] not in bad_ids and p["b"] not in bad_ids:
        clean_pairs.append(p)

removed_count = original_count - len(clean_pairs)
print(f"✅ Осталось чистых пар: {len(clean_pairs)} (удалено {removed_count})")

# 3️⃣ Сохраняем
# Сохраняем в том же формате, что и оригинал (dict или list)
if isinstance(pairs_data, dict):
    pairs_data["pairs"] = clean_pairs
    torch.save(pairs_data, OUTPUT_PATH)
else:
    torch.save({"pairs": clean_pairs}, OUTPUT_PATH)

print(f"💾 Сохранено в: {OUTPUT_PATH}")
print(f"📏 Размер файла: {os.path.getsize(OUTPUT_PATH) / (1024**2):.1f} MB")
print("\n🎉 Готово! Теперь используй этот файл в train_mlp.py")
# Out:
# 📦 Загружаем данные...
# 🔍 Ищем белки с несовпадением длин или отсутствием данных...
# Сканирование registry: 100%|██████████| 181812/181812 [00:00<00:00, 1001172.14it/s]
# 🚫 Найдено 176506 проблемных белков
# 🧹 Удаляем пары, содержащие проблемные белки...
# Фильтрация пар: 100%|██████████| 7450/7450 [00:00<00:00, 1870887.61it/s]
# ✅ Осталось чистых пар: 7413 (удалено 37)
# 💾 Сохранено в: ./train_pairs_clean.pt
# 📏 Размер файла: 0.4 MB
#
# 🎉 Готово! Теперь используй этот файл в train_mlp.py

# %%
multistate_pairs = [p for p in pairs if p['type'] == 'Multistate']
print(f"Всего Multistate пар: {len(multistate_pairs)}")
for p in multistate_pairs[2000:2100]:
    print(f"{p['a']} — {p['b']}")
# Out:
# Всего Multistate пар: 73

# %%
import torch
import numpy as np

registry = torch.load("/home/domain/data/aristowi/mlp_dataset_laproteina/latents/registry.pt", map_location="cpu")

# Возьмите любую структуру
sample = registry["13sj"]
coords = sample["coords"].cpu().numpy()

print(f"Пример координат первого CA-атома: {coords[0]}")
print(f"Диапазон координат: [{coords.min():.3f}, {coords.max():.3f}]")
print(f"Среднее значение: {coords.mean():.3f}")
# Out:
# Пример координат первого CA-атома: [-1.9297001  1.0151    -1.4814   ]
# Диапазон координат: [-3.389, 3.606]
# Среднее значение: 0.203

# %%
from Bio.PDB import PDBParser, Superimposer
import numpy as np

pdb_a = "/home/domain/data/aristowi/mlp_dataset_laproteina/pdb/x-ray/13nj.pdb"
pdb_b = "/home/domain/data/aristowi/mlp_dataset_laproteina/pdb/x-ray/13pj.pdb"

parser = PDBParser(QUIET=True)
s1 = parser.get_structure("a", pdb_a)
s2 = parser.get_structure("b", pdb_b)

# Берём только CA атомы
ca1 = [atom for atom in s1.get_atoms() if atom.get_name() == "CA"]
ca2 = [atom for atom in s2.get_atoms() if atom.get_name() == "CA"]

# Сопоставляем строго по (номер_остатка, цепь)
dict2 = {(atom.parent.id[1], atom.parent.parent.id): atom for atom in ca2}
pair_a, pair_b = [], []
for atom in ca1:
    key = (atom.parent.id[1], atom.parent.parent.id)
    if key in dict2:
        pair_a.append(atom)
        pair_b.append(dict2[key])

print(f"Совпавших CA: {len(pair_a)}")
if len(pair_a) >= 10:
    sup = Superimposer()
    sup.set_atoms(pair_a, pair_b)
    print(f"RMSD (как в PyMOL): {sup.rms:.3f} Å")
else:
    print("Недостаточно общих остатков для выравнивания")
# Out:
# Совпавших CA: 313
# RMSD (как в PyMOL): 0.442 Å
